# %% [markdown]
# ### SUD Box tool: EDA

# %% [markdown]
# ## Goals:
# 1. checking if all tags available on historian server
# 1. Perform exploratory analysis of the data
# 2. Identify data-related issues and ways to address them

# %% [markdown]
# ### TODO
#
# 1.

# %% [markdown]
# ### Questions
# 1.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import pyodbc as pyodbc

import logging
import queries

import sys
import os
import logging
import sys
import argparse
import pytz
from os.path import join, split 

from datetime import datetime, timedelta
from tomlkit import parse, dumps, loads
from typing import List, Tuple

import historian


from sud_tools import *
from sud_utils import *
from tool_utils import *

# %% [markdown]
# ### Reading in the configuration file

# %%
cfg_file_nm = 'etl_config.toml'
cfg_file_path = join(os.getcwd(), cfg_file_nm)
# checking if config file exists
if not os.path.isfile(cfg_file_path):
    raise ValueError(f'No config file was found at: {cfg_file_path}')
else:
    # reading in the config file
    cfg = loads(open(cfg_file_path).read())

# %%
tags_list_path = cfg['job']['path_to_tag_list']
print(f'Path to tag list table: {tags_list_path}')
# Out:
# Path to tag list table: F:\Ecosystem Non-OneDrive\Development Area\MVP048 SUD Box tool\Data\Input\tags_list.xlsx

# %% [markdown]
# ### Setting up the connection to DatalabDB

# %%
# datalab integration
datalab_cfg = cfg['datalab_db'].copy()

# setting up run configuration with parameters from cfg file
datalab_db_conn = get_mssql_conn_string(**datalab_cfg['connection'])
datalab_db_access_url = r"{}".format(datalab_cfg['access_token_url']['access_token_url'])
datalab_db_access_token = get_azure_sql_db_access_token(datalab_db_access_url)
rejects_agg_freq = datalab_cfg['output_tables']['agg_freq']

print(f'Datalab connection parameters: {datalab_db_conn}')
# Out:
# Datalab connection parameters: Server=azpg-sqlserver-fhcenganalyticsdatalab.database.windows.net; Database=DatalabDB; Driver=ODBC Driver 17 for SQL Server;

# %% [markdown]
# ### Fetching the tag list information

# %%
# reading the tag list file
tags_list_path = cfg['job']['path_to_tag_list']
print(f'Path to tag list table: {tags_list_path}')

# cheking if the logs folder exist
if not os.path.exists(tags_list_path):
    print(f'INFO: Didn not find logs folder at {tags_list_path}.')
    raise ValueError('Was not able to file tags list. Aborting...')
else:
    tags_list_df = pd.read_excel(tags_list_path)
    print(f'Shape of the tags list table: {tags_list_df.shape}')
# Out:
# Path to tag list table: F:\Ecosystem Non-OneDrive\Development Area\MVP048 SUD Box tool\Data\Input\tags_list.xlsx
# Shape of the tags list table: (130, 1)

# %%
tags_list_df.head()
# Out:
#                                              TagName
# 0  LXXX_Cover_General_ExtractedCartons_Total_Coun...
# 1  LXXX_Cover_General_ProducedCovers_Total_Counte...
# 2  LXXX_Cover_General_RejectedCovers_0_Counter_Ac...
# 3               LXXX_Cover_Reshipper_good_inserted_n
# 4                LXXX_Cover_Reshipper_bad_rejected_n

# %% [markdown]
# ### site specific config

# %%
site_cd = 'url'
site_cfg = cfg['sites'][site_cd].copy()

site_name = site_cfg['site_name']
site_enabled = site_cfg['enabled']


site_history_buffer_days = site_cfg['history_buffer_days']

site_servers = site_cfg['servers'].copy()
site_lines = site_cfg['lines']['lines']
site_lines_agile = site_cfg['lines']['lines_agile']

site_historian_tags = site_cfg['tags'].copy()

site_tz = site_servers['timezone']
site_dttm_format = site_servers['dttm_format']
site_historian_source = site_servers['historian']['source']
site_history_depth = site_servers['historian']['history_depth_days']
site_days_to_retake = site_history_depth + site_history_buffer_days

# %%
site_tags = tags_list_df.loc[:, 'TagName'].unique()
site_tags = ['_'.join(t.split('_')[1:]) for t in site_tags]
site_tags
# Out:
# ['Cover_General_ExtractedCartons_Total_Counter_Actual_n',
#  'Cover_General_ProducedCovers_Total_Counter_Actual_n',
#  'Cover_General_RejectedCovers_0_Counter_Actual_n',
#  'Cover_Reshipper_good_inserted_n',
#  'Cover_Reshipper_bad_rejected_n',
#  'Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n',
#  'Cover_TransportBelt_CheckExternal_0_0_Rejected_n',
#  'Cover_TransportBelt_CheckInternal_0_0_Rejected_n',
#  'Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n',
#  'Cover_Reshipper_BCR_NotRead_Rejected_n',
#  'Cover_Reshipper_BCR_MisMatch_Rejected_n',
#  'Cover_Reshipper_BCR_NoFeedback_Rejected_n',
#  'Cover_TransportBelt_HoleFlap_0_Check_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_Glue_Dry _0_Rejected_n',
#  'Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_Glue_Dry_0_Rejected_n',
#  'Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Base_Machine_ExtractedCartons_0_Counter_Actual_n',
#  'Base_Machine_ProducedBases_0_Counter_Actual_n',
#  'Base_Machine_RejectedBases_Station1_Counter_Actual_n',
#  'Base_Machine_RejectedBases_Station2_Counter_Actual_n',
#  'Base_Machine_RejectedBases_Station3_Counter_Actual_n',
#  'Base_Machine_RejectedBases_Total_NOT_Extracted_Betw_Holders_n',
#  'Base_Reshipper_good_inserted_n',
#  'Base_Reshipper_bad_rejected_n',
#  'Base_Reshipper_BCR_NotRead_Rejected_n',
#  'Base_Reshipper_BCR_MisMatch_Rejected_n',
#  'Base_Reshipper_BCR_NoFeedback_Rejected_n',
#  'Base_Extraction_Turret_Arm1_CartonsNotExtracted_Actual_n',
#  'Base_Extraction_Turret_Arm2_CartonsNotExtracted_Actual_n',
#  'Base_Extraction_Turret_Arm3_CartonsNotExtracted_Actual_n',
#  'Base_Extraction_Turret_Arm4_CartonsNotExtracted_Actual_n',
#  'Base_Extraction_Bases_Betw_Holders_n',
#  'Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n',
#  'Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n',
#  'Base_CameraTT_2Dcheck_0_NotRead_Rejected_n',
#  'Base_CameraTT_OCR_0_NOK_Rejected_n',
#  'Base_CameraTT_2Dcheck_NoFeedback_Rejected_n',
#  'Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_Forming_Base_Backflap_Open_Rejected_n',
#  'Base_FlapCheck_LowerGlue_Present_0_Rejected_n',
#  'Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n',
#  'Base_Forming_Glue_Dry_Bad_Rejected_n',
#  'Base_filling_Base_0_NotPresent_Rejected_n',
#  'Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n',
#  'Base_Merging_Base_0_NotPresent_Rejected_n',
#  'Base_Merging_00_CoverNotPresentOnBase_Rejected_n',
#  'Base_Merging_base_Merging_Deviation_Rejected_n',
#  'Base_Merging_base_Cover_NotPresent_ Rejected_n',
#  'Base_Merging_MergingEngage_cover_Notpresent_Rejected_n',
#  'Base_Merging_MergingInspection_DS_NOK_Rejected_n',
#  'Base_Merging_MergingInspection_OS_NOK_Rejected_n',
#  'Base_Merging_BackFlapInspection_0_NOK_Rejected_n',
#  'Base_Merging_LaserPrinter0Fail_Rejected_n',
#  'Base_Merging_Merging_External_Check_Rejected_n',
#  'Base_Merging_Merging_Internal_Check_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n',
#  'Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_0_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_1_NotRejected_n',
#  'Upack_BoxCheckweigher_0_Zone_2_NotRejected_n',
#  'Upack_BoxCheckweigher_0_Zone_3_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_4_Rejected_n',
#  'Upack_BoxCheckweigher_0_Extra_Rejected_n',
#  'Secondary_FC11_Dataman_Reads_Result_Bad_n',
#  'Secondary_FC11_Dataman_Reads_Result_Mismatch_n',
#  'Secondary_FC11_Minibea_Reads_Result_Bad_n',
#  'Secondary_FC11_Minibea_Reads_Result_Mismatch_n',
#  'Secondary_FC11_Minibea_Reads_Result_Total_n',
#  'Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n',
#  'Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n',
#  'Upack_OLCP_1DCheck_0_NOKRejected_n',
#  'Upack_CaseCheckweigher_Reject_Case_Weight_Real',
#  'Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n',
#  'Palletizer_Pack_Counter_n',
#  'Upack_Zone10_0_0_CurrentPO_Actual_nb',
#  'Upack_Zone9_0_0_CurrentPO_Actual_nb',
#  'Upack_Zone12_0_0_CurrentPO_Actual_nb',
#  'Upack_Zone13_0_0_CurrentPO_Actual_nb',
#  'Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n',
#  'Upack_PO_PodsCount_Counter_SetPoint_n',
#  'Upack_LineRecipe']

# %%
site_tags=[tag.replace(u'\xa0',u'') for tag in site_tags]
site_tags
# Out:
# ['Cover_General_ExtractedCartons_Total_Counter_Actual_n',
#  'Cover_General_ProducedCovers_Total_Counter_Actual_n',
#  'Cover_General_RejectedCovers_0_Counter_Actual_n',
#  'Cover_Reshipper_good_inserted_n',
#  'Cover_Reshipper_bad_rejected_n',
#  'Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n',
#  'Cover_TransportBelt_CheckExternal_0_0_Rejected_n',
#  'Cover_TransportBelt_CheckInternal_0_0_Rejected_n',
#  'Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n',
#  'Cover_Reshipper_BCR_NotRead_Rejected_n',
#  'Cover_Reshipper_BCR_MisMatch_Rejected_n',
#  'Cover_Reshipper_BCR_NoFeedback_Rejected_n',
#  'Cover_TransportBelt_HoleFlap_0_Check_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_Glue_Dry _0_Rejected_n',
#  'Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_Glue_Dry_0_Rejected_n',
#  'Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Base_Machine_ExtractedCartons_0_Counter_Actual_n',
#  'Base_Machine_ProducedBases_0_Counter_Actual_n',
#  'Base_Machine_RejectedBases_Station1_Counter_Actual_n',
#  'Base_Machine_RejectedBases_Station2_Counter_Actual_n',
#  'Base_Machine_RejectedBases_Station3_Counter_Actual_n',
#  'Base_Machine_RejectedBases_Total_NOT_Extracted_Betw_Holders_n',
#  'Base_Reshipper_good_inserted_n',
#  'Base_Reshipper_bad_rejected_n',
#  'Base_Reshipper_BCR_NotRead_Rejected_n',
#  'Base_Reshipper_BCR_MisMatch_Rejected_n',
#  'Base_Reshipper_BCR_NoFeedback_Rejected_n',
#  'Base_Extraction_Turret_Arm1_CartonsNotExtracted_Actual_n',
#  'Base_Extraction_Turret_Arm2_CartonsNotExtracted_Actual_n',
#  'Base_Extraction_Turret_Arm3_CartonsNotExtracted_Actual_n',
#  'Base_Extraction_Turret_Arm4_CartonsNotExtracted_Actual_n',
#  'Base_Extraction_Bases_Betw_Holders_n',
#  'Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n',
#  'Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n',
#  'Base_CameraTT_2Dcheck_0_NotRead_Rejected_n',
#  'Base_CameraTT_OCR_0_NOK_Rejected_n',
#  'Base_CameraTT_2Dcheck_NoFeedback_Rejected_n',
#  'Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_Forming_Base_Backflap_Open_Rejected_n',
#  'Base_FlapCheck_LowerGlue_Present_0_Rejected_n',
#  'Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n',
#  'Base_Forming_Glue_Dry_Bad_Rejected_n',
#  'Base_filling_Base_0_NotPresent_Rejected_n',
#  'Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n',
#  'Base_Merging_Base_0_NotPresent_Rejected_n',
#  'Base_Merging_00_CoverNotPresentOnBase_Rejected_n',
#  'Base_Merging_base_Merging_Deviation_Rejected_n',
#  'Base_Merging_base_Cover_NotPresent_ Rejected_n',
#  'Base_Merging_MergingEngage_cover_Notpresent_Rejected_n',
#  'Base_Merging_MergingInspection_DS_NOK_Rejected_n',
#  'Base_Merging_MergingInspection_OS_NOK_Rejected_n',
#  'Base_Merging_BackFlapInspection_0_NOK_Rejected_n',
#  'Base_Merging_LaserPrinter0Fail_Rejected_n',
#  'Base_Merging_Merging_External_Check_Rejected_n',
#  'Base_Merging_Merging_Internal_Check_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n',
#  'Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_0_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_1_NotRejected_n',
#  'Upack_BoxCheckweigher_0_Zone_2_NotRejected_n',
#  'Upack_BoxCheckweigher_0_Zone_3_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_4_Rejected_n',
#  'Upack_BoxCheckweigher_0_Extra_Rejected_n',
#  'Secondary_FC11_Dataman_Reads_Result_Bad_n',
#  'Secondary_FC11_Dataman_Reads_Result_Mismatch_n',
#  'Secondary_FC11_Minibea_Reads_Result_Bad_n',
#  'Secondary_FC11_Minibea_Reads_Result_Mismatch_n',
#  'Secondary_FC11_Minibea_Reads_Result_Total_n',
#  'Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n',
#  'Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n',
#  'Upack_OLCP_1DCheck_0_NOKRejected_n',
#  'Upack_CaseCheckweigher_Reject_Case_Weight_Real',
#  'Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n',
#  'Palletizer_Pack_Counter_n',
#  'Upack_Zone10_0_0_CurrentPO_Actual_nb',
#  'Upack_Zone9_0_0_CurrentPO_Actual_nb',
#  'Upack_Zone12_0_0_CurrentPO_Actual_nb',
#  'Upack_Zone13_0_0_CurrentPO_Actual_nb',
#  'Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n',
#  'Upack_PO_PodsCount_Counter_SetPoint_n',
#  'Upack_LineRecipe']

# %%
all_tag_list=get_tags_list(lines=site_lines,sensors=site_tags,sep='_', topic=site_servers['historian']['proficy']['topic'])
#removing PO related tags
all_tag_list=[t for t in all_tag_list if 'CurrentPO' not in t]
print(len(all_tag_list))
#all_tag_list
# Out:
# 126

# %%
all_tag_list
# Out:
# ['URL-PACK.L13_Cover_General_ExtractedCartons_Total_Counter_Actual_n',
#  'URL-PACK.L13_Cover_General_ProducedCovers_Total_Counter_Actual_n',
#  'URL-PACK.L13_Cover_General_RejectedCovers_0_Counter_Actual_n',
#  'URL-PACK.L13_Cover_Reshipper_good_inserted_n',
#  'URL-PACK.L13_Cover_Reshipper_bad_rejected_n',
#  'URL-PACK.L13_Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n',
#  'URL-PACK.L13_Cover_TransportBelt_CheckExternal_0_0_Rejected_n',
#  'URL-PACK.L13_Cover_TransportBelt_CheckInternal_0_0_Rejected_n',
#  'URL-PACK.L13_Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n',
#  'URL-PACK.L13_Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n',
#  'URL-PACK.L13_Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n',
#  'URL-PACK.L13_Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n',
#  'URL-PACK.L13_Cover_Reshipper_BCR_NotRead_Rejected_n',
#  'URL-PACK.L13_Cover_Reshipper_BCR_MisMatch_Rejected_n',
#  'URL-PACK.L13_Cover_Reshipper_BCR_NoFeedback_Rejected_n',
#  'URL-PACK.L13_Cover_TransportBelt_HoleFlap_0_Check_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_Glue_Dry _0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_Glue_Dry_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Base_Machine_ExtractedCartons_0_Counter_Actual_n',
#  'URL-PACK.L13_Base_Machine_ProducedBases_0_Counter_Actual_n',
#  'URL-PACK.L13_Base_Machine_RejectedBases_Station1_Counter_Actual_n',
#  'URL-PACK.L13_Base_Machine_RejectedBases_Station2_Counter_Actual_n',
#  'URL-PACK.L13_Base_Machine_RejectedBases_Station3_Counter_Actual_n',
#  'URL-PACK.L13_Base_Machine_RejectedBases_Total_NOT_Extracted_Betw_Holders_n',
#  'URL-PACK.L13_Base_Reshipper_good_inserted_n',
#  'URL-PACK.L13_Base_Reshipper_bad_rejected_n',
#  'URL-PACK.L13_Base_Reshipper_BCR_NotRead_Rejected_n',
#  'URL-PACK.L13_Base_Reshipper_BCR_MisMatch_Rejected_n',
#  'URL-PACK.L13_Base_Reshipper_BCR_NoFeedback_Rejected_n',
#  'URL-PACK.L13_Base_Extraction_Turret_Arm1_CartonsNotExtracted_Actual_n',
#  'URL-PACK.L13_Base_Extraction_Turret_Arm2_CartonsNotExtracted_Actual_n',
#  'URL-PACK.L13_Base_Extraction_Turret_Arm3_CartonsNotExtracted_Actual_n',
#  'URL-PACK.L13_Base_Extraction_Turret_Arm4_CartonsNotExtracted_Actual_n',
#  'URL-PACK.L13_Base_Extraction_Bases_Betw_Holders_n',
#  'URL-PACK.L13_Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n',
#  'URL-PACK.L13_Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n',
#  'URL-PACK.L13_Base_CameraTT_2Dcheck_0_NotRead_Rejected_n',
#  'URL-PACK.L13_Base_CameraTT_OCR_0_NOK_Rejected_n',
#  'URL-PACK.L13_Base_CameraTT_2Dcheck_NoFeedback_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'URL-PACK.L13_Base_Forming_Base_Backflap_Open_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_LowerGlue_Present_0_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n',
#  'URL-PACK.L13_Base_Forming_Glue_Dry_Bad_Rejected_n',
#  'URL-PACK.L13_Base_filling_Base_0_NotPresent_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n',
#  'URL-PACK.L13_Base_Merging_Base_0_NotPresent_Rejected_n',
#  'URL-PACK.L13_Base_Merging_00_CoverNotPresentOnBase_Rejected_n',
#  'URL-PACK.L13_Base_Merging_base_Merging_Deviation_Rejected_n',
#  'URL-PACK.L13_Base_Merging_base_Cover_NotPresent_ Rejected_n',
#  'URL-PACK.L13_Base_Merging_MergingEngage_cover_Notpresent_Rejected_n',
#  'URL-PACK.L13_Base_Merging_MergingInspection_DS_NOK_Rejected_n',
#  'URL-PACK.L13_Base_Merging_MergingInspection_OS_NOK_Rejected_n',
#  'URL-PACK.L13_Base_Merging_BackFlapInspection_0_NOK_Rejected_n',
#  'URL-PACK.L13_Base_Merging_LaserPrinter0Fail_Rejected_n',
#  'URL-PACK.L13_Base_Merging_Merging_External_Check_Rejected_n',
#  'URL-PACK.L13_Base_Merging_Merging_Internal_Check_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Rejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_1_NotRejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_2_NotRejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_3_Rejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_4_Rejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Extra_Rejected_n',
#  'URL-PACK.L13_Secondary_FC11_Dataman_Reads_Result_Bad_n',
#  'URL-PACK.L13_Secondary_FC11_Dataman_Reads_Result_Mismatch_n',
#  'URL-PACK.L13_Secondary_FC11_Minibea_Reads_Result_Bad_n',
#  'URL-PACK.L13_Secondary_FC11_Minibea_Reads_Result_Mismatch_n',
#  'URL-PACK.L13_Secondary_FC11_Minibea_Reads_Result_Total_n',
#  'URL-PACK.L13_Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n',
#  'URL-PACK.L13_Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n',
#  'URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n',
#  'URL-PACK.L13_Upack_CaseCheckweigher_Reject_Case_Weight_Real',
#  'URL-PACK.L13_Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n',
#  'URL-PACK.L13_Palletizer_Pack_Counter_n',
#  'URL-PACK.L13_Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n',
#  'URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n',
#  'URL-PACK.L13_Upack_LineRecipe']

# %% [markdown]
# ## Checking tag availability

# %%
historian.use_context('REST', 
                    client_id='historian_public_rest_api', 
                    client_password='publicapisecret',
                    app_id='sudanalytics.im', 
                    app_password='phoenix2021SUD', # change to environmental variable
                    port=site_servers['historian']['proficy']['port'],
                    verify_certificate=True)

# %%
all_site_tags_dict=historian.get_tag_names(site_servers['historian']['proficy']['server_name'],    
                        filter_name='*',    
                        filter_description='*',    
                        has_values=False,    
                        guaranteed_sample_before=None,    
                        newer_than=None,    
                        verbose=False)

# %%
all_site_tags_list = list(all_site_tags_dict.keys())
all_site_tags_list
# Out:
# ['URL-CONV.L10_Anvil_ActualPosition',
#  'URL-CONV.L10_Anvil_ActualVelocity',
#  'URL-CONV.L10_Anvil_CommandPosition',
#  'URL-CONV.L10_Anvil_CommandVelocity',
#  'URL-CONV.L10_Anvil_MotorCapacity',
#  'URL-CONV.L10_Anvil_PositionError',
#  'URL-CONV.L10_Anvil_TorqueFeedback',
#  'URL-CONV.L10_Anvil_TorqueFeedback_RMS',
#  'URL-CONV.L10_AnvilPhaseOffset',
#  'URL-CONV.L10_Bottom_Felt_New_Alarm',
#  'URL-CONV.L10_Bottom_Felt_Roll_Pressure_bar',
#  'URL-CONV.L10_Bottom_Heating_1_OP',
#  'URL-CONV.L10_Bottom_Heating_1_PV',
#  'URL-CONV.L10_Bottom_Heating_1_Temp_High_Alarm',
#  'URL-CONV.L10_Bottom_Heating_1_Temp_Low_Alarm',
#  'URL-CONV.L10_Bottom_Heating_2_OP',
#  'URL-CONV.L10_Bottom_Heating_2_PV',
#  'URL-CONV.L10_Bottom_Heating_2_Temp_High_Alarm',
#  'URL-CONV.L10_Bottom_Heating_2_Temp_Low_Alarm',
#  'URL-CONV.L10_Bottom_Heating_3_OP',
#  'URL-CONV.L10_Bottom_Heating_3_PV',
#  'URL-CONV.L10_Bottom_Heating_3_Temp_High_Alarm',
#  'URL-CONV.L10_Bottom_Heating_3_Temp_Low_Alarm',
#  'URL-CONV.L10_Bottom_Heating_4_OP',
#  'URL-CONV.L10_Bottom_Heating_4_PV',
#  'URL-CONV.L10_Bottom_Heating_4_Temp_High_Alarm',
#  'URL-CONV.L10_Bottom_Heating_4_Temp_Low_Alarm',
#  'URL-CONV.L10_Bottom_Heating_SP',
#  'URL-CONV.L10_Bottom_Metering_Draw',
#  'URL-CONV.L10_Bottom_Pump_G1_ActualPosition',
#  'URL-CONV.L10_Bottom_Pump_G1_ActualVelocity',
#  'URL-CONV.L10_Bottom_Pump_G1_CommandPosition',
#  'URL-CONV.L10_Bottom_Pump_G1_CommandVelocity',
#  'URL-CONV.L10_Bottom_Pump_G1_MotorCapacity',
#  'URL-CONV.L10_Bottom_Pump_G1_PositionError',
#  'URL-CONV.L10_Bottom_Pump_G1_TorqueFeedback',
#  'URL-CONV.L10_Bottom_Pump_G1_TorqueFeedback_RMS',
#  'URL-CONV.L10_Bottom_Pump_G2_ActualPosition',
#  'URL-CONV.L10_Bottom_Pump_G2_ActualVelocity',
#  'URL-CONV.L10_Bottom_Pump_G2_CommandPosition',
#  'URL-CONV.L10_Bottom_Pump_G2_CommandVelocity',
#  'URL-CONV.L10_Bottom_Pump_G2_MotorCapacity',
#  'URL-CONV.L10_Bottom_Pump_G2_PositionError',
#  'URL-CONV.L10_Bottom_Pump_G2_TorqueFeedback',
#  'URL-CONV.L10_Bottom_Pump_G2_TorqueFeedback_RMS',
#  'URL-CONV.L10_Bottom_Pump_G3_ActualPosition',
#  'URL-CONV.L10_Bottom_Pump_G3_ActualVelocity',
#  'URL-CONV.L10_Bottom_Pump_G3_CommandPosition',
#  'URL-CONV.L10_Bottom_Pump_G3_CommandVelocity',
#  'URL-CONV.L10_Bottom_Pump_G3_MotorCapacity',
#  'URL-CONV.L10_Bottom_Pump_G3_PositionError',
#  'URL-CONV.L10_Bottom_Pump_G3_TorqueFeedback',
#  'URL-CONV.L10_Bottom_Pump_G3_TorqueFeedback_RMS',
#  'URL-CONV.L10_Bottom_Pump_G4_ActualPosition',
#  'URL-CONV.L10_Bottom_Pump_G4_ActualVelocity',
#  'URL-CONV.L10_Bottom_Pump_G4_CommandPosition',
#  'URL-CONV.L10_Bottom_Pump_G4_CommandVelocity',
#  'URL-CONV.L10_Bottom_Pump_G4_MotorCapacity',
#  'URL-CONV.L10_Bottom_Pump_G4_PositionError',
#  'URL-CONV.L10_Bottom_Pump_G4_TorqueFeedback',
#  'URL-CONV.L10_Bottom_Pump_G4_TorqueFeedback_RMS',
#  'URL-CONV.L10_Bottom_Pump_G5_ActualPosition',
#  'URL-CONV.L10_Bottom_Pump_G5_ActualVelocity',
#  'URL-CONV.L10_Bottom_Pump_G5_CommandPosition',
#  'URL-CONV.L10_Bottom_Pump_G5_CommandVelocity',
#  'URL-CONV.L10_Bottom_Pump_G5_MotorCapacity',
#  'URL-CONV.L10_Bottom_Pump_G5_PositionError',
#  'URL-CONV.L10_Bottom_Pump_G5_TorqueFeedback',
#  'URL-CONV.L10_Bottom_Pump_G5_TorqueFeedback_RMS',
#  'URL-CONV.L10_Bottom_Pump_G6_ActualPosition',
#  'URL-CONV.L10_Bottom_Pump_G6_ActualVelocity',
#  'URL-CONV.L10_Bottom_Pump_G6_CommandPosition',
#  'URL-CONV.L10_Bottom_Pump_G6_CommandVelocity',
#  'URL-CONV.L10_Bottom_Pump_G6_MotorCapacity',
#  'URL-CONV.L10_Bottom_Pump_G6_PositionError',
#  'URL-CONV.L10_Bottom_Pump_G6_TorqueFeedback',
#  'URL-CONV.L10_Bottom_Pump_G6_TorqueFeedback_RMS',
#  'URL-CONV.L10_Bottom_Shuttle_ActualPosition',
#  'URL-CONV.L10_Bottom_Shuttle_ActualVelocity',
#  'URL-CONV.L10_Bottom_Shuttle_CommandPosition',
#  'URL-CONV.L10_Bottom_Shuttle_CommandVelocity',
#  'URL-CONV.L10_Bottom_Shuttle_MotorCapacity',
#  'URL-CONV.L10_Bottom_Shuttle_PositionError',
#  'URL-CONV.L10_Bottom_Shuttle_TimeOverCavity',
#  'URL-CONV.L10_Bottom_shuttle_TimeTotalCycle',
#  'URL-CONV.L10_Bottom_Shuttle_TorqueFeedback',
#  'URL-CONV.L10_Bottom_Shuttle_TorqueFeedback_RMS',
#  'URL-CONV.L10_Bottom_solvent_actualflow',
#  'URL-CONV.L10_Bottom_Solvent_Felt_Kp',
#  'URL-CONV.L10_Bottom_Solvent_Felt_Wid',
#  'URL-CONV.L10_Bottom_Solvent_Flowrate_NotInProcessLimits_Alarm',
#  'URL-CONV.L10_Bottom_solvent_flowsetpoint',
#  'URL-CONV.L10_Bottom_Solvent_Level_High_Alarm',
#  'URL-CONV.L10_Bottom_Solvent_Level_Low_Alarm',
#  'URL-CONV.L10_Bottom_Solvent_Level_NotInProcessLimits_Alarm',
#  'URL-CONV.L10_Bottom_Solvent_Lvl',
#  'URL-CONV.L10_Bottom_Solvent_Lvl_Filt',
#  'URL-CONV.L10_Bottom_Solvent_Roll_ActualPosition',
#  'URL-CONV.L10_Bottom_Solvent_Roll_ActualVelocity',
#  'URL-CONV.L10_Bottom_Solvent_Roll_ActualVelocity_RPM2',
#  'URL-CONV.L10_Bottom_Solvent_Roll_CommandPosition',
#  'URL-CONV.L10_Bottom_Solvent_Roll_CommandVelocity',
#  'URL-CONV.L10_Bottom_Solvent_Roll_MotorCapacity',
#  'URL-CONV.L10_Bottom_Solvent_Roll_PositionError',
#  'URL-CONV.L10_Bottom_Solvent_Roll_RPM_Gain',
#  'URL-CONV.L10_Bottom_Solvent_Roll_RPM_Max',
#  'URL-CONV.L10_Bottom_Solvent_Roll_RPM_Min',
#  'URL-CONV.L10_Bottom_Solvent_Roll_TorqueFeedack',
#  'URL-CONV.L10_Bottom_Solvent_Roll_TorqueFeedack_RMS',
#  'URL-CONV.L10_Bottom_Solvent_STDEV',
#  'URL-CONV.L10_Bottom_solvent_Valveoutput',
#  'URL-CONV.L10_Bottom_Solvent_Valveoutput_%',
#  'URL-CONV.L10_Bottom_Unwinder_Current_Diameter_Left',
#  'URL-CONV.L10_Bottom_Unwinder_Current_Diameter_Right',
#  'URL-CONV.L10_Bottom_Unwinder_Dancer_Position',
#  'URL-CONV.L10_Bottom_Unwinder_Rotary_Speed_Left',
#  'URL-CONV.L10_Bottom_Unwinder_Rotary_Speed_Right',
#  'URL-CONV.L10_Bottom_Unwinder_SpliceInProgress',
#  'URL-CONV.L10_BottomFillTime',
#  'URL-CONV.L10_BottomLiquidBreakTankLevel',
#  'URL-CONV.L10_BottomLiquidDoseVolume',
#  'URL-CONV.L10_BottomLiquidTemp',
#  'URL-CONV.L10_BottomNozzleCloseAdvanceTime',
#  'URL-CONV.L10_BottomNozzleOpenAdvanceTime',
#  'URL-CONV.L10_BottomPumpEnableAll',
#  'URL-CONV.L10_BottomPumpGroup1_DoseAdjustment',
#  'URL-CONV.L10_BottomPumpGroup2_DoseAdjustment',
#  'URL-CONV.L10_BottomPumpGroup3_DoseAdjustment',
#  'URL-CONV.L10_BottomPumpGroup4_DoseAdjustment.',
#  'URL-CONV.L10_BottomPumpGroup5_DoseAdjustment',
#  'URL-CONV.L10_BottomPumpGroup6_DoseAdjustment',
#  'URL-CONV.L10_BottomPumpMaxVel',
#  'URL-CONV.L10_BottomPumpStartAdvanceTime',
#  'URL-CONV.L10_BottomPumpTotalCycleTime',
#  'URL-CONV.L10_BottomRefillDelayTime',
#  'URL-CONV.L10_BottomRefillMaxSpeed',
#  'URL-CONV.L10_BottomRefillTime',
#  'URL-CONV.L10_BottomRollFeltHourTimer',
#  'URL-CONV.L10_BottomShuttlePhaseOffset.',
#  'URL-CONV.L10_BottomSolventCoatWeight',
#  'URL-CONV.L10_BottomSolventLevel_MovingAverage',
#  'URL-CONV.L10_BottomSolventLevel_StandardDeviation',
#  'URL-CONV.L10_BottomSolventPan_LevelControlEnable',
#  'URL-CONV.L10_BottomSolventPumpProcessLimit_Sts_Active',
#  'URL-CONV.L10_BottomUnwindleftspliceactive',
#  'URL-CONV.L10_BottomUnwindrightspliceactive',
#  'URL-CONV.L10_CD_Cutter_ActualPosition',
#  'URL-CONV.L10_CD_Cutter_ActualVelocity',
#  'URL-CONV.L10_CD_Cutter_CommandPosition',
#  'URL-CONV.L10_CD_Cutter_CommandVelocity',
#  'URL-CONV.L10_CD_Cutter_Dwell',
#  'URL-CONV.L10_CD_Cutter_MotorCapacity',
#  'URL-CONV.L10_CD_Cutter_PositionError',
#  'URL-CONV.L10_CD_Cutter_TorqueFeedback',
#  'URL-CONV.L10_CD_Cutter_TorqueFeedback_RMS',
#  'URL-CONV.L10_CD_CutterPhaseOffset',
#  'URL-CONV.L10_Combining_Roll_Pressure_bar',
#  'URL-CONV.L10_Current_Alarm',
#  'URL-CONV.L10_Current_Machine_Speed',
#  'URL-CONV.L10_Current_Mode_Number',
#  'URL-CONV.L10_Current_State_Number',
#  'URL-CONV.L10_Diverter_Position',
#  'URL-CONV.L10_Extraction_Drum_ActualPosition',
#  'URL-CONV.L10_Extraction_Drum_ActualVelocity',
#  'URL-CONV.L10_Extraction_Drum_CommandPosition',
#  'URL-CONV.L10_Extraction_Drum_CommandVelocity',
#  'URL-CONV.L10_Extraction_Drum_MotorCapacity',
#  'URL-CONV.L10_Extraction_Drum_PositionError',
#  'URL-CONV.L10_Extraction_Drum_TorqueFeedback',
#  'URL-CONV.L10_Extraction_Drum_TorqueFeedback_RMS',
#  'URL-CONV.L10_First_Out_Fault_Category',
#  'URL-CONV.L10_First_Out_Fault_ID',
#  'URL-CONV.L10_Hygro_Enclosure',
#  'URL-CONV.L10_MD_Cutter_ActualVelocity',
#  'URL-CONV.L10_MD_Cutter_TorqueFeedback',
#  'URL-CONV.L10_MD_Cutter_TorqueFeedback_RMS',
#  'URL-CONV.L10_Middle_Metering_Draw',
#  'URL-CONV.L10_Middle_Unwinder_Current_Diameter_Left',
#  'URL-CONV.L10_Middle_Unwinder_Current_Diameter_Right',
#  'URL-CONV.L10_Middle_Unwinder_Dancer_Position',
#  'URL-CONV.L10_Middle_Unwinder_Rotary_Speed_Left',
#  'URL-CONV.L10_Middle_Unwinder_Rotary_Speed_Right',
#  'URL-CONV.L10_Middle_Unwinder_SpliceInProgress',
#  'URL-CONV.L10_middleUnwindleftspliceactive',
#  'URL-CONV.L10_MiddleUnwindrightspliceactive',
#  'URL-CONV.L10_nc_VEC_Main_Status_DINT_3',
#  'URL-CONV.L10_Nectar_Drum_ActualPosition',
#  'URL-CONV.L10_Nectar_Drum_ActualVelocity',
#  'URL-CONV.L10_Nectar_Drum_CommandPosition',
#  'URL-CONV.L10_Nectar_Drum_CommandVelocity',
#  'URL-CONV.L10_Nectar_Drum_MotorCapacity',
#  'URL-CONV.L10_Nectar_Drum_PositionError',
#  'URL-CONV.L10_Nectar_Drum_TorqueFeedback',
#  'URL-CONV.L10_Nectar_Drum_TorqueFeedback_RMS',
#  'URL-CONV.L10_NectarDrum_PressureDS_bar',
#  'URL-CONV.L10_NectarDrum_PressureOS_bar',
#  'URL-CONV.L10_NectarDrumPhaseOffset',
#  'URL-CONV.L10_NectarDrumVacFault',
#  'URL-CONV.L10_PackML_Execute',
#  'URL-CONV.L10_Platen_Chain_ActualPosition',
#  'URL-CONV.L10_Platen_Chain_ActualVelocity',
#  'URL-CONV.L10_Platen_Chain_CommandPosition',
#  'URL-CONV.L10_Platen_Chain_CommandVelocity',
#  'URL-CONV.L10_Platen_Chain_MotorCapacity',
#  'URL-CONV.L10_Platen_Chain_PositionError',
#  'URL-CONV.L10_Platen_Chain_TorqueFeedback',
#  'URL-CONV.L10_Platen_Chain_TorqueFeedback_RMS',
#  'URL-CONV.L10_PouchesDosedCount',
#  'URL-CONV.L10_Powdering_Extrac_Pump_Speed',
#  'URL-CONV.L10_PP_Actual_Ink_Flow_forward_Pump_Black',
#  'URL-CONV.L10_PP_Actual_Ink_Flow_forward_Pump_Red',
#  'URL-CONV.L10_PP_Actual_Ink_Flow_forward_Pump_White',
#  'URL-CONV.L10_PP_Actual_Stroke_Frequency_forward_Pump_Black',
#  'URL-CONV.L10_PP_Actual_Stroke_Frequency_forward_Pump_Red',
#  'URL-CONV.L10_PP_Actual_Stroke_Frequency_forward_Pump_White',
#  'URL-CONV.L10_PP_anilox1_ActualPosition',
#  'URL-CONV.L10_PP_anilox1_ActualVelocity',
#  'URL-CONV.L10_PP_anilox1_MotorCapacity',
#  'URL-CONV.L10_PP_anilox1_PositionError',
#  'URL-CONV.L10_PP_anilox1_TorqueFeedback',
#  'URL-CONV.L10_PP_anilox2_ActualPosition',
#  'URL-CONV.L10_PP_anilox2_ActualVelocity',
#  'URL-CONV.L10_PP_anilox2_MotorCapacity',
#  'URL-CONV.L10_PP_anilox2_PositionError',
#  'URL-CONV.L10_PP_anilox2_TorqueFeedback',
#  'URL-CONV.L10_PP_anilox3_ActualPosition',
#  'URL-CONV.L10_PP_anilox3_ActualVelocity',
#  'URL-CONV.L10_PP_anilox3_MotorCapacity',
#  'URL-CONV.L10_PP_anilox3_PositionError',
#  'URL-CONV.L10_PP_anilox3_TorqueFeedback',
#  'URL-CONV.L10_PP_Cliche1_ActualPosition',
#  'URL-CONV.L10_PP_Cliche1_ActualVelocity',
#  'URL-CONV.L10_PP_Cliche1_MotorCapacity',
#  'URL-CONV.L10_PP_Cliche1_PositionError',
#  'URL-CONV.L10_PP_Cliche1_RFID_1',
#  'URL-CONV.L10_PP_Cliche1_RFID_2',
#  'URL-CONV.L10_PP_Cliche1_TorqueFeedback',
#  'URL-CONV.L10_PP_Cliche2_ActualPosition',
#  'URL-CONV.L10_PP_Cliche2_ActualVelocity',
#  'URL-CONV.L10_PP_Cliche2_MotorCapacity',
#  'URL-CONV.L10_PP_Cliche2_PositionError',
#  'URL-CONV.L10_PP_Cliche2_RFID_1',
#  'URL-CONV.L10_PP_Cliche2_RFID_2',
#  'URL-CONV.L10_PP_Cliche2_TorqueFeedback',
#  'URL-CONV.L10_PP_Cliche3_ActualPosition',
#  'URL-CONV.L10_PP_Cliche3_ActualVelocity',
#  'URL-CONV.L10_PP_Cliche3_MotorCapacity',
#  'URL-CONV.L10_PP_Cliche3_PositionError',
#  'URL-CONV.L10_PP_Cliche3_RFID_1',
#  'URL-CONV.L10_PP_Cliche3_RFID_2',
#  'URL-CONV.L10_PP_Cliche3_TorqueFeedback',
#  'URL-CONV.L10_PP_Commanded_Impression_Drum_Draw',
#  'URL-CONV.L10_PP_Commanded_Outfeed_Omega_Draw',
#  'URL-CONV.L10_PP_drv_Infeedaxis_Gear.InRatio',
#  'URL-CONV.L10_PP_General_MasterEncoder_General_Velocity_Actual_rows/s',
#  'URL-CONV.L10_PP_General_PLC_PouchPrinterPLC_Version_Actual_#',
#  'URL-CONV.L10_PP_General_Status_Registration_Active_State_#',
#  'URL-CONV.L10_PP_General_Status_Registration_PositionControl_Disabled_#',
#  'URL-CONV.L10_PP_General_Status_Registration_Status_Enabled_#',
#  'URL-CONV.L10_PP_General_VirutalMaster_BottomMetering_Compensation_Actual_rows/s',
#  'URL-CONV.L10_PP_General_VirutalMaster_Encoder_VelocityControl_Active_#',
#  'URL-CONV.L10_PP_General_VirutalMaster_General_Velocity_Actual_rows/s',
#  'URL-CONV.L10_PP_General_VirutalMaster_MainSetpoint_VelocityControl_Active_#',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_DS_Interference_Black',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_DS_Interference_Red',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_DS_Interference_White',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_DS_torque_Black',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_DS_torque_Red',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_DS_torque_White',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_OS_Interference_Black',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_OS_Interference_Red',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_OS_Interference_White',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_OS_torque_Black',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_OS_torque_Red',
#  'URL-CONV.L10_PP_IDP_anilox_cliche_OS_torque_White',
#  'URL-CONV.L10_PP_IDP_cliche_drum_DS_Interference_Black',
#  'URL-CONV.L10_PP_IDP_cliche_drum_DS_Interference_Red',
#  'URL-CONV.L10_PP_IDP_cliche_drum_DS_Interference_White',
#  'URL-CONV.L10_PP_IDP_cliche_drum_DS_torque_Black',
#  'URL-CONV.L10_PP_IDP_cliche_drum_DS_torque_Red',
#  'URL-CONV.L10_PP_IDP_cliche_drum_DS_torque_White',
#  'URL-CONV.L10_PP_IDP_cliche_drum_OS_Interference_Black',
#  'URL-CONV.L10_PP_IDP_cliche_drum_OS_Interference_Red',
#  'URL-CONV.L10_PP_IDP_cliche_drum_OS_Interference_White',
#  'URL-CONV.L10_PP_IDP_cliche_drum_OS_torque_Black',
#  'URL-CONV.L10_PP_IDP_cliche_drum_OS_torque_Red',
#  'URL-CONV.L10_PP_IDP_cliche_drum_OS_torque_White',
#  'URL-CONV.L10_PP_Impression_Drum_Motor_torque',
#  'URL-CONV.L10_PP_Infeed_Actual_Tension',
#  'URL-CONV.L10_PP_Infeed_Omega_Roll_Motor_torque',
#  'URL-CONV.L10_PP_Infeed_Tension_Control_Status',
#  'URL-CONV.L10_PP_Ink_Chamber_Pressure_Black',
#  'URL-CONV.L10_PP_Ink_Chamber_Pressure_Red',
#  'URL-CONV.L10_PP_Ink_Chamber_Pressure_White',
#  'URL-CONV.L10_PP_Ink_Flow_Return_Pump_Black',
#  'URL-CONV.L10_PP_Ink_Flow_Return_Pump_Red',
#  'URL-CONV.L10_PP_Ink_Flow_Return_Pump_White',
#  'URL-CONV.L10_PP_Modulus_Infeed',
#  'URL-CONV.L10_PP_Modulus_Outfeed',
#  'URL-CONV.L10_PP_Outfeed_Actual_Tension',
#  'URL-CONV.L10_PP_Outfeed_Omega_Roll_Motor_torque',
#  'URL-CONV.L10_PP_Print_cliche_draw_Black',
#  'URL-CONV.L10_PP_Print_cliche_draw_Red',
#  'URL-CONV.L10_PP_Print_cliche_draw_White',
#  'URL-CONV.L10_PP_registration_actual_value',
#  'URL-CONV.L10_PP_registration_photocell_Setpoint',
#  'URL-CONV.L10_PP_s_wrap_high_Limit',
#  'URL-CONV.L10_PP_s_wrap_low_Limit',
#  'URL-CONV.L10_PP_SetPoint_Cliché_Phasing_position_Black',
#  'URL-CONV.L10_PP_SetPoint_Cliché_Phasing_position_Red',
#  'URL-CONV.L10_PP_SetPoint_Cliché_Phasing_position_White',
#  'URL-CONV.L10_PP_SetPoint_Ink_Chamber_Pressure_Black',
#  'URL-CONV.L10_PP_SetPoint_Ink_Chamber_Pressure_Red',
#  'URL-CONV.L10_PP_Setpoint_Ink_Chamber_Pressure_White',
#  'URL-CONV.L10_PP_SetPoint_Ink_Flow_forward_Pump_Black',
#  'URL-CONV.L10_PP_SetPoint_Ink_Flow_forward_Pump_Red',
#  'URL-CONV.L10_PP_SetPoint_Ink_Flow_forward_Pump_White',
#  'URL-CONV.L10_PP_Stroke_Frequency_Return_Pump_Black',
#  'URL-CONV.L10_PP_Stroke_Frequency_Return_Pump_Red',
#  'URL-CONV.L10_PP_Stroke_Frequency_Return_Pump_White',
#  'URL-CONV.L10_PP_Washing_cycle_started_Black',
#  'URL-CONV.L10_PP_Washing_cycle_started_Red',
#  'URL-CONV.L10_PP_Washing_cycle_started_White',
#  'URL-CONV.L10_RecipeControl_Sts_CurrentRecipe',
#  'URL-CONV.L10_Reject_Drum_ActualPosition',
#  'URL-CONV.L10_Reject_Drum_ActualVelocity',
#  'URL-CONV.L10_Reject_Drum_CommandPosition',
#  'URL-CONV.L10_Reject_Drum_CommandVelocity',
#  'URL-CONV.L10_Reject_Drum_MotorCapacity',
#  'URL-CONV.L10_Reject_Drum_PositionError',
#  'URL-CONV.L10_Reject_Drum_TorqueFeedback',
#  'URL-CONV.L10_Reject_Drum_TorqueFeedback_RMS',
#  'URL-CONV.L10_RejectDrumPhaseOffset',
#  'URL-CONV.L10_RejectStartupRows',
#  'URL-CONV.L10_Splice_StopDosingRows',
#  'URL-CONV.L10_Temp_Enclosure',
#  'URL-CONV.L10_Top_Felt_New_Alarm',
#  'URL-CONV.L10_Top_Heater_OP',
#  'URL-CONV.L10_Top_Heater_PV',
#  'URL-CONV.L10_Top_Heater_SP',
#  'URL-CONV.L10_Top_Heating_Roll_Draw',
#  'URL-CONV.L10_Top_Heating_Temp_High_Alarm',
#  'URL-CONV.L10_Top_Heating_Temp_Low_Alarm',
#  'URL-CONV.L10_Top_Metering_ActualVelocity',
#  'URL-CONV.L10_Top_Metering_Draw',
#  'URL-CONV.L10_Top_Metering_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color1_G1_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G1_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G1_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G1_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G1_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color1_G1_PositionError',
#  'URL-CONV.L10_Top_Pump_Color1_G1_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color1_G1_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color1_G2_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G2_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G2_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G2_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G2_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color1_G2_PositionError',
#  'URL-CONV.L10_Top_Pump_Color1_G2_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color1_G2_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color1_G3_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G3_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G3_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G3_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G3_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color1_G3_PositionError',
#  'URL-CONV.L10_Top_Pump_Color1_G3_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color1_G3_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color1_G4_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G4_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G4_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G4_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G4_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color1_G4_PositionError',
#  'URL-CONV.L10_Top_Pump_Color1_G4_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color1_G4_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color1_G5_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G5_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G5_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G5_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G5_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color1_G5_PositionError',
#  'URL-CONV.L10_Top_Pump_Color1_G5_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color1_G5_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color1_G6_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G6_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G6_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color1_G6_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color1_G6_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color1_G6_PositionError',
#  'URL-CONV.L10_Top_Pump_Color1_G6_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color1_G6_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color2_G1_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G1_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G1_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G1_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G1_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color2_G1_PositionError',
#  'URL-CONV.L10_Top_Pump_Color2_G1_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color2_G1_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color2_G2_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G2_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G2_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G2_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G2_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color2_G2_PositionError',
#  'URL-CONV.L10_Top_Pump_Color2_G2_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color2_G2_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color2_G3_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G3_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G3_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G3_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G3_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color2_G3_PositionError',
#  'URL-CONV.L10_Top_Pump_Color2_G3_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color2_G3_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color2_G4_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G4_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G4_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G4_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G4_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color2_G4_PositionError',
#  'URL-CONV.L10_Top_Pump_Color2_G4_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color2_G4_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color2_G5_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G5_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G5_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G5_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G5_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color2_G5_PositionError',
#  'URL-CONV.L10_Top_Pump_Color2_G5_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color2_G5_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Pump_Color2_G6_ActualPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G6_ActualVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G6_CommandPosition',
#  'URL-CONV.L10_Top_Pump_Color2_G6_CommandVelocity',
#  'URL-CONV.L10_Top_Pump_Color2_G6_MotorCapacity',
#  'URL-CONV.L10_Top_Pump_Color2_G6_PositionError',
#  'URL-CONV.L10_Top_Pump_Color2_G6_TorqueFeedback',
#  'URL-CONV.L10_Top_Pump_Color2_G6_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_Shuttle_ActualPosition',
#  'URL-CONV.L10_Top_Shuttle_ActualVelocity',
#  'URL-CONV.L10_Top_Shuttle_CommandPosition',
#  'URL-CONV.L10_Top_Shuttle_CommandVelocity',
#  'URL-CONV.L10_Top_Shuttle_MotorCapacity',
#  'URL-CONV.L10_Top_Shuttle_PositionError',
#  'URL-CONV.L10_Top_Shuttle_TimeOverCavity',
#  'URL-CONV.L10_Top_Shuttle_TimeTotalCycle',
#  'URL-CONV.L10_Top_Shuttle_TorqueFeedback',
#  'URL-CONV.L10_Top_Shuttle_TorqueFeedback_RMS',
#  'URL-CONV.L10_Top_solvent_actualflow',
#  'URL-CONV.L10_Top_Solvent_Coat_SP',
#  'URL-CONV.L10_Top_Solvent_Felt_Kp',
#  'URL-CONV.L10_Top_Solvent_Felt_Wid',
#  'URL-CONV.L10_Top_Solvent_Flowrate_NotInProcessLimits_Alarm',
#  'URL-CONV.L10_Top_solvent_flowsetpoint',
#  'URL-CONV.L10_Top_Solvent_Halarm_SP',
#  'URL-CONV.L10_Top_Solvent_Lalarm_SP',
#  'URL-CONV.L10_Top_Solvent_Level_High_Alarm',
#  'URL-CONV.L10_Top_Solvent_Level_Low_Alarm',
#  'URL-CONV.L10_Top_Solvent_Level_NotInProcessLimits_Alarm',
#  'URL-CONV.L10_Top_Solvent_Lvl',
#  'URL-CONV.L10_Top_Solvent_Lvl_Filt',
#  'URL-CONV.L10_Top_Solvent_Roll_ActualPosition',
#  'URL-CONV.L10_Top_Solvent_Roll_ActualVelocity',
#  'URL-CONV.L10_Top_Solvent_Roll_ActualVelocity_RPM',
#  'URL-CONV.L10_Top_Solvent_Roll_CommandPosition',
#  'URL-CONV.L10_Top_Solvent_Roll_CommandVelocity',
#  'URL-CONV.L10_Top_Solvent_Roll_MotorCapacity',
#  'URL-CONV.L10_Top_Solvent_Roll_PositionError',
#  'URL-CONV.L10_Top_Solvent_Roll_RPM_Gain',
#  'URL-CONV.L10_Top_Solvent_Roll_RPM_Max',
#  'URL-CONV.L10_Top_Solvent_Roll_RPM_Min',
#  'URL-CONV.L10_Top_Solvent_Roll_TorqueFeedack',
#  'URL-CONV.L10_Top_Solvent_Roll_TorqueFeedack_RMS',
#  'URL-CONV.L10_Top_Solvent_STDEV',
#  'URL-CONV.L10_Top_solvent_Valveoutput',
#  'URL-CONV.L10_Top_Solvent_Valveoutput_%',
#  'URL-CONV.L10_Top_Unwinder_Current_Diameter_Left',
#  'URL-CONV.L10_Top_Unwinder_Current_Diameter_Right',
#  'URL-CONV.L10_Top_Unwinder_Dancer_Position',
#  'URL-CONV.L10_Top_Unwinder_Rotary_Speed_Left',
#  'URL-CONV.L10_Top_Unwinder_Rotary_Speed_Right',
#  'URL-CONV.L10_Top_Unwinder_SpliceInProgress',
#  'URL-CONV.L10_TopColor1ActualSuckBackAmount',
#  'URL-CONV.L10_TopColor1FillMaxSpeed',
#  'URL-CONV.L10_TopColor1LiquidDoseVolume',
#  'URL-CONV.L10_TopColor1MaxVel',
#  'URL-CONV.L10_TopColor1PumpCycleTime',
#  'URL-CONV.L10_TopColor1PumpEnableAll',
#  'URL-CONV.L10_TopColor1PumpGroup1_DoseAdjustment',
#  'URL-CONV.L10_TopColor1PumpGroup2_DoseAdjustment',
#  'URL-CONV.L10_TopColor1PumpGroup3_DoseAdjustment',
#  'URL-CONV.L10_TopColor1PumpGroup4_DoseAdjustment',
#  'URL-CONV.L10_TopColor1PumpGroup5_DoseAdjustment',
#  'URL-CONV.L10_TopColor1PumpGroup6_DoseAdjustment',
#  'URL-CONV.L10_TopColor1PurgeSpeed',
#  'URL-CONV.L10_TopColor1StartAdvanceTime',
#  'URL-CONV.L10_TopColor1SuckBackDecelStartTime',
#  'URL-CONV.L10_TopColor1SuckBackMaxSpeed',
#  'URL-CONV.L10_TopColor2ActualSuckBackAmount',
#  'URL-CONV.L10_TopColor2FillMaxSpeed',
#  'URL-CONV.L10_TopColor2LiquidDoseVolume',
#  'URL-CONV.L10_TopColor2MaxVel',
#  'URL-CONV.L10_TopColor2PumpCycleTime',
#  'URL-CONV.L10_TopColor2PumpEnableAll',
#  'URL-CONV.L10_TopColor2PumpGroup1_DoseAdjustment',
#  'URL-CONV.L10_TopColor2PumpGroup2_DoseAdjustment',
#  'URL-CONV.L10_TopColor2PumpGroup3_DoseAdjustment',
#  'URL-CONV.L10_TopColor2PumpGroup4_DoseAdjustment',
#  'URL-CONV.L10_TopColor2PumpGroup5_DoseAdjustment',
#  'URL-CONV.L10_TopColor2PumpGroup6_DoseAdjustment',
#  'URL-CONV.L10_TopColor2PurgeSpeed',
#  'URL-CONV.L10_TopColor2StartAdvanceTime',
#  'URL-CONV.L10_TopColor2SuckBackDecelStartTime',
#  'URL-CONV.L10_TopColor2SuckBackMaxSpeed',
#  'URL-CONV.L10_TopFelt_EngagedMeters',
#  'URL-CONV.L10_TopLiquidColor1_Temp',
#  'URL-CONV.L10_TopLiquidColor2_Temp',
#  'URL-CONV.L10_TopRollFeltHourTimer',
#  'URL-CONV.L10_TopShuttlePhaseOffset',
#  'URL-CONV.L10_TopSolventCoatWeight',
#  'URL-CONV.L10_TopSolventLevel_StandardDeviation',
#  'URL-CONV.L10_TopSolventLevel_StandardDeviation_Average',
#  'URL-CONV.L10_TopSolventPan_LevelControlEnable',
#  'URL-CONV.L10_TopSolventPumpProcessLimit_Sts_Active',
#  'URL-CONV.L10_TopUnwindleftspliceactive',
#  'URL-CONV.L10_TopUnwindrightspliceactive',
#  'URL-CONV.L10_TrimChopper_OutputCurrent',
#  'URL-CONV.L10_U30581_PhaseACurrent',
#  'URL-CONV.L10_VacuumAnvilDS',
#  'URL-CONV.L10_VacuumAnvilOS',
#  'URL-CONV.L10_VacuumConverterInfeed',
#  'URL-CONV.L10_VacuumDeformation',
#  'URL-CONV.L10_VacuumExtractionDrum',
#  'URL-CONV.L10_VacuumInfeedChain1',
#  'URL-CONV.L10_VacuumInfeedChain2',
#  'URL-CONV.L10_VacuumNectarDrumDS',
#  'URL-CONV.L10_VacuumNectarDrumMid',
#  'URL-CONV.L10_VacuumNectarDrumOS',
#  'URL-CONV.L10_VacuumOutfeedChain1',
#  'URL-CONV.L10_VacuumOutfeedChain2',
#  'URL-CONV.L10_VacuumPreDeformation',
#  'URL-CONV.L10_VacuumRejectDRum',
#  'URL-CONV.L10_VEC_CuttingTransfer_Anvil_0_TorqueRMS_Actual_%',
#  'URL-CONV.L10_VEC_CuttingTransfer_Cutter_CD_TorqueRMS_Actual_%',
#  'URL-CONV.L10_VEC_CuttingTransfer_Cutter_MD_TorqueRMS_Actual_%',
#  'URL-CONV.L10_VEC_CuttingTransfer_Extraction_Drum_TorqueRMS_Actual_%',
#  'URL-CONV.L10_VEC_CuttingTransfer_Reject_Drum_TorqueRMS_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPD_Buffer_AvailableLevel_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPD_Buffer_LatchedFastStop_State_#',
#  'URL-CONV.L10_VEC_Distribution_VEPD_Buffer_MinRequiredLevel_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPD_Buffer_StopActive_State_#',
#  'URL-CONV.L10_VEC_Distribution_VEPDA_Buffer_AvailableLevel_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPDA_Buffer_LowLimitLevel_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPDA_Buffer_MinRequiredLevel_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPDA_Buffer_RestartLevel_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPDB_Buffer_AvailableLevel_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPDB_Buffer_LowLimitLevel_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPDB_Buffer_MinRequiredLevel_Actual_%',
#  'URL-CONV.L10_VEC_Distribution_VEPDB_Buffer_RestartLevel_Actual_%',
#  'URL-CONV.L10_VEC_Dosing_Bottom_CamProfile_BottomFillMaxSpeed_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Dosing_Bottom_CamProfile_DoseVolume_Delta_ml',
#  'URL-CONV.L10_VEC_Dosing_Bottom_CamProfile_DoseVolume_Remote_ml',
#  'URL-CONV.L10_VEC_Dosing_Bottom_CamProfile_MaximumVelocity_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Dosing_Bottom_CamProfile_RefillMaxSpeed_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Dosing_Bottom_Liquid_GCAS_Actual_#',
#  'URL-CONV.L10_VEC_Dosing_Bottom_Shuttle_Dwell_Setpoint_mm',
#  'URL-CONV.L10_VEC_Dosing_TopColor1_Bottom_Pressure_Actual_bar',
#  'URL-CONV.L10_VEC_Dosing_TopColor1_CamProfile_MaximumVelocity_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Dosing_TopColor1_Liquid_GCAS_Actual_#',
#  'URL-CONV.L10_VEC_Dosing_TopColor2_Bottom_Pressure_Actual_bar',
#  'URL-CONV.L10_VEC_Dosing_TopColor2_CamProfile_MaximumVelocity_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Dosing_TopColor2_Liquid_GCAS_Actual_#',
#  'URL-CONV.L10_VEC_General_Air_MainSupply_Pressure_Actual_bar',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event00_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event01_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event02_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event03_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event04_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event05_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event06_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event07_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event08_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event09_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event10_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event11_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event12_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event13_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event14_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event15_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event16_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event17_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event18_0',
#  'URL-CONV.L10_VEC_General_Alarm_Report_EventInfo_Event19_0',
#  'URL-CONV.L10_VEC_General_BottomDosingPumps_State_PumpsDisabled',
#  'URL-CONV.L10_VEC_General_Chain_0_TorqueRMS_Actual_%',
#  'URL-CONV.L10_VEC_General_Main_HMI_Screen_Active_#',
#  'URL-CONV.L10_VEC_General_MainVacuum_Pump_PhaseACurrent_Actual_A',
#  'URL-CONV.L10_VEC_General_PackML_Dosing_Mode_Actual_#',
#  'URL-CONV.L10_VEC_General_PackML_Dosing_State_Actual_#',
#  'URL-CONV.L10_VEC_General_PLC_MainPLC_Version_Actual_#',
#  'URL-CONV.L10_VEC_General_RCO_LPD_VecRunFinishedAllowed_State_#',
#  'URL-CONV.L10_VEC_General_RCO_LPD_VecRunFinishedPressed_State_#',
#  'URL-CONV.L10_VEC_General_RCO_TimeEstimation_LPDAllowRunFilm_State_#',
#  'URL-CONV.L10_VEC_General_RCO_TimeEstimation_LPDRemainingCOTime_Actual_s',
#  'URL-CONV.L10_VEC_General_RCO_TimeEstimation_NotAllowPreConditioningFilm_State_#',
#  'URL-CONV.L10_VEC_General_RCO_TimeEstimation_RequiredPreConditioningTime_Actual_s',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Current_Actual_Rows',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Optimal_Actual_Rows',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range1End_Actual_Rows',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range1Found_State_#',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range1Start_Actual_Rows',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range2End_Actual_Rows',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range2Found_State_#',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range2Start_Actual_Rows',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range3End_Actual_Rows',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range3Found_State_#',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range3Start_Actual_Rows',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range4End_Actual_Rows',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range4Found_State_#',
#  'URL-CONV.L10_VEC_General_ShiftRegister_UpdatePosition_Range4Start_Actual_Rows',
#  'URL-CONV.L10_VEC_General_TopColor1DosingPumps_State_PumpsDisabled',
#  'URL-CONV.L10_VEC_General_TopColor2DosingPumps_State_PumpsDisabled',
#  'URL-CONV.L10_VEC_HMI_RcoStatus_RecipeChange_Request',
#  'URL-CONV.L10_VEC_MachineSpeed_Setpoint_m_min',
#  'URL-CONV.L10_VEC_NectarDrum_Kilometers',
#  'URL-CONV.L10_VEC_Powdering_Air_Supply_Pressure_Actual_bar',
#  'URL-CONV.L10_VEC_Powdering_Extraction_Fan_Speed_Setpoint_Hz',
#  'URL-CONV.L10_VEC_Powdering_PowderGun_Dilution_Pressure_Actual_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderGun_Dilution_Pressure_Command_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderGun_Dilution_Pressure_Setpoint_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderGun_Injector_Pressure_Actual_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderGun_Injector_Pressure_Command_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderGun_Injector_Pressure_Setpoint_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderTank_Fluidizer_AirFlow_Command_Actual_L/min',
#  'URL-CONV.L10_VEC_Powdering_PowderTank_Fluidizer_Pressure_Actual_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderTank_Fluidizer_Pressure_Command_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderTank_Fluidizer_Pressure_Setpoint_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderTank_Vibrator_Pressure_Actual_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderTank_Vibrator_Pressure_Command_bar',
#  'URL-CONV.L10_VEC_Powdering_PowderTank_Vibrator_Pressure_Setpoint_bar',
#  'URL-CONV.L10_VEC_Purging_Bottom_CamProfile_DosedVolume_Setpoint_ml',
#  'URL-CONV.L10_VEC_Purging_Bottom_CamProfile_FillTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_Bottom_CamProfile_MaximumVelocity_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Purging_Bottom_CamProfile_NozzleCloseAdvanceTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_Bottom_CamProfile_NozzleOpenAdvanceTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_Bottom_CamProfile_RefillDelayTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_Bottom_CamProfile_RefillMaxSpeed_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Purging_Bottom_CamProfile_RefillTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_Bottom_CamProfile_TotalCycleTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_TopColor1_CamProfile_DosedVolume_Setpoint_ml',
#  'URL-CONV.L10_VEC_Purging_TopColor1_CamProfile_MaximumVelocity_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Purging_TopColor1_CamProfile_PumpCycleTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_TopColor1_CamProfile_SuckBack_Setpoint_ml',
#  'URL-CONV.L10_VEC_Purging_TopColor1_CamProfile_SuckBackDecelStartTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_TopColor1_CamProfile_SuckBackMaxSpeed_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Purging_TopColor1_CamProfile_TotalCycleTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_TopColor2_CamProfile_DosedVolume_Setpoint_ml',
#  'URL-CONV.L10_VEC_Purging_TopColor2_CamProfile_MaximumVelocity_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Purging_TopColor2_CamProfile_PumpCycleTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_TopColor2_CamProfile_SuckBack_Setpoint_ml',
#  'URL-CONV.L10_VEC_Purging_TopColor2_CamProfile_SuckBackDecelStartTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Purging_TopColor2_CamProfile_SuckBackMaxSpeed_Setpoint_ml/s',
#  'URL-CONV.L10_VEC_Purging_TopColor2_CamProfile_TotalCycleTime_Setpoint_ms',
#  'URL-CONV.L10_VEC_Sealing_Bottom_Felt_Density_Setpoint_gsm/mm',
#  'URL-CONV.L10_VEC_Sealing_Bottom_Felt_PieceNumber_Setpoint_#',
#  'URL-CONV.L10_VEC_Sealing_Bottom_Felt_Thickness_Setpoint_mm',
#  'URL-CONV.L10_VEC_Sealing_Bottom_NectarDrum_TorqueRMS_Actual_%',
#  'URL-CONV.L10_VEC_Sealing_Bottom_NectarShell_Age_Actual_hr',
#  'URL-CONV.L10_VEC_Sealing_Bottom_NectarShell_Age_Actual_km',
#  'URL-CONV.L10_VEC_Sealing_Bottom_SolventRoll_Engaged_Actual_hr',
#  'URL-CONV.L10_VEC_Sealing_Bottom_SolventRoll_Engaged_Actual_m',
#  'URL-CONV.L10_VEC_Sealing_Bottom_SolventRoll_PredictedSpeed_Actual_rpm',
#  'URL-CONV.L10_VEC_Sealing_Bottom_SolventRoll_PredictedSpeed_Delta_rpm',
#  'URL-CONV.L10_VEC_Sealing_Bottom_SolventRoll_SteadyState_State_0',
#  'URL-CONV.L10_VEC_Sealing_Top_Felt_Density_Setpoint_gsm/mm',
#  'URL-CONV.L10_VEC_Sealing_Top_Felt_PieceNumber_Setpoint_#',
#  'URL-CONV.L10_VEC_Sealing_Top_Felt_Thickness_Setpoint_mm',
#  'URL-CONV.L10_VEC_Sealing_Top_SolventRoll_Engaged_Actual_hr',
#  'URL-CONV.L10_VEC_Sealing_Top_SolventRoll_Engaged_Actual_m',
#  'URL-CONV.L10_VEC_Sealing_Top_SolventRoll_PredictedSpeed_Actual_rpm',
#  'URL-CONV.L10_VEC_Sealing_Top_SolventRoll_PredictedSpeed_Delta_rpm',
#  'URL-CONV.L10_VEC_Sealing_Top_SolventRoll_SteadyState_State_0',
#  'URL-CONV.L10_VEC_Thermoforming_Bottom_HeatingUnit_LampGroup1Disabled_State_#',
#  'URL-CONV.L10_VEC_Thermoforming_Top_Film_BlowOffTempSensorDS_Actual_L/min',
#  'URL-CONV.L10_VEC_Thermoforming_Top_Film_BlowOffTempSensorMid_Actual_L/min',
#  'URL-CONV.L10_VEC_Thermoforming_Top_Film_BlowOffTempSensorOS_Actual_L/min',
#  'URL-CONV.L10_VEC_Thermoforming_Top_HeatedRoll_DS_Actual_C',
#  'URL-CONV.L10_VEC_Thermoforming_Top_HeatedRoll_MID_Actual_C',
#  'URL-CONV.L10_VEC_Thermoforming_Top_HeatedRoll_OS_Actual_C',
#  'URL-CONV.L10_VEC_WebHandling_Bottom_Dancer_HighBuffer_State_#',
#  'URL-CONV.L10_VEC_WebHandling_Bottom_PVA_GCAS_Actual_#',
#  'URL-CONV.L10_VEC_WebHandling_Bottom_PVA_Roll_Actual_#',
#  'URL-CONV.L10_VEC_WebHandling_Bottom_Splice_Reason_Number_#',
#  'URL-CONV.L10_VEC_WebHandling_BottomLeft_PVA_NoRead_State_#',
#  'URL-CONV.L10_VEC_WebHandling_BottomRight_PVA_NoRead_State_#',
#  'URL-CONV.L10_VEC_WebHandling_Middle_Dancer_HighBuffer_State_#',
#  'URL-CONV.L10_VEC_WebHandling_Middle_PVA_GCAS_Actual_#',
#  'URL-CONV.L10_VEC_WebHandling_Middle_PVA_Roll_Actual_#',
#  'URL-CONV.L10_VEC_WebHandling_Middle_Splice_Reason_Number_#',
#  'URL-CONV.L10_VEC_WebHandling_MiddleLeft_PVA_NoRead_State_#',
#  'URL-CONV.L10_VEC_WebHandling_MiddleRight_PVA_NoRead_State_#',
#  'URL-CONV.L10_VEC_WebHandling_Top_Dancer_HighBuffer_State_#',
#  'URL-CONV.L10_VEC_WebHandling_Top_PVA_GCAS_Actual_#',
#  'URL-CONV.L10_VEC_WebHandling_Top_PVA_Roll_Actual_#',
#  'URL-CONV.L10_VEC_WebHandling_Top_Splice_Reason_Number_#',
#  'URL-CONV.L10_VEC_WebHandling_TopLeft_PVA_NoRead_State_#',
#  'URL-CONV.L10_VEC_WebHandling_TopRight_PVA_NoRead_State_#',
#  'URL-CONV.L10_VEPD_ASide_Primary_Infeed_Torque_Actual_%',
#  'URL-CONV.L10_VEPD_ASide_Primary_Outfeed_Torque_Actual_%',
#  'URL-CONV.L10_VEPD_ASide_Secondary_1_Torque_Actual_%',
#  'URL-CONV.L10_VEPD_ASide_Secondary_2_Torque_Actual_%',
#  'URL-CONV.L10_VEPD_BSide_Primary_Infeed_Torque_Actual_%',
#  'URL-CONV.L10_VEPD_BSide_Primary_Outfeed_Torque_Actual_%',
#  'URL-CONV.L10_VEPD_BSide_Secondary_1_Torque_Actual_%',
#  'URL-CONV.L10_VEPD_BSide_Secondary_2_Torque_Actual_%',
#  'URL-CONV.L10_VEPD_Distribution_Diverter_Position_AutoManControl_State_#',
#  'URL-CONV.L10_VEPD_Distribution_Diverter_Position_Split_Actual_%',
#  'URL-CONV.L10_VEPDA_Inspected_First_Vision',
#  'URL-CONV.L10_VEPDA_Inspected_Second_Vision',
#  'URL-CONV.L10_VEPDA_Primary_BucketID_AtInfeedChute',
#  'URL-CONV.L10_VEPDA_Primary_BucketID_AtPrimaryReject',
#  'URL-CONV.L10_VEPDA_Primary_BufferLevel',
#  'URL-CONV.L10_VEPDA_Primary_Rejected_Bucket',
#  'URL-CONV.L10_VEPDA_Products_Per_Bucket',
#  'URL-CONV.L10_VEPDA_Rejected_First_Vision_Inner_Cavity',
#  'URL-CONV.L10_VEPDA_Rejected_First_Vision_Outer_Cavity',
#  'URL-CONV.L10_VEPDA_Rejected_first_Vision_Percentage_Long',
#  'URL-CONV.L10_VEPDA_Rejected_first_Vision_Percentage_Short',
#  'URL-CONV.L10_VEPDA_Rejected_Second_Vision_Inner_Cavity',
#  'URL-CONV.L10_VEPDA_Rejected_Second_Vision_Outer_Cavity',
#  'URL-CONV.L10_VEPDA_Rejected_second_Vision_Percentage_Long',
#  'URL-CONV.L10_VEPDA_Rejected_second_Vision_Percentage_Short',
#  'URL-CONV.L10_VEPDB_Inspected_First_Vision',
#  'URL-CONV.L10_VEPDB_Inspected_Second_Vision',
#  'URL-CONV.L10_VEPDB_Primary_BucketID_AtInfeedChute',
#  'URL-CONV.L10_VEPDB_Primary_BucketID_AtPrimaryReject',
#  'URL-CONV.L10_VEPDB_Primary_BufferLevel',
#  'URL-CONV.L10_VEPDB_Primary_Rejected_Bucket',
#  'URL-CONV.L10_VEPDB_Products_Per_Bucket',
#  'URL-CONV.L10_VEPDB_Rejected_First_Vision_Inner_Cavity',
#  'URL-CONV.L10_VEPDB_Rejected_First_Vision_Outer_Cavity',
#  'URL-CONV.L10_VEPDB_Rejected_first_Vision_Percentage_Long',
#  'URL-CONV.L10_VEPDB_Rejected_first_Vision_Percentage_Short',
#  'URL-CONV.L10_VEPDB_Rejected_Second_Vision_Inner_Cavity',
#  'URL-CONV.L10_VEPDB_Rejected_Second_Vision_Outer_Cavity',
#  'URL-CONV.L10_VEPDB_Rejected_second_Vision_Percentage_Long',
#  'URL-CONV.L10_VEPDB_Rejected_second_Vision_Percentage_Short',
#  'URL-CONV.L11_Anvil_ActualPosition',
#  'URL-CONV.L11_Anvil_ActualVelocity',
#  'URL-CONV.L11_Anvil_CommandPosition',
#  'URL-CONV.L11_Anvil_CommandVelocity',
#  'URL-CONV.L11_Anvil_MotorCapacity',
#  'URL-CONV.L11_Anvil_PositionError',
#  'URL-CONV.L11_Anvil_TorqueFeedback',
#  'URL-CONV.L11_Anvil_TorqueFeedback_RMS',
#  'URL-CONV.L11_AnvilPhaseOffset',
#  'URL-CONV.L11_Bottom_Felt_New_Alarm',
#  'URL-CONV.L11_Bottom_Felt_Roll_Pressure_bar',
#  'URL-CONV.L11_Bottom_Heating_1_OP',
#  'URL-CONV.L11_Bottom_Heating_1_PV',
#  'URL-CONV.L11_Bottom_Heating_1_Temp_High_Alarm',
#  'URL-CONV.L11_Bottom_Heating_1_Temp_Low_Alarm',
#  'URL-CONV.L11_Bottom_Heating_2_OP',
#  'URL-CONV.L11_Bottom_Heating_2_PV',
#  'URL-CONV.L11_Bottom_Heating_2_Temp_High_Alarm',
#  'URL-CONV.L11_Bottom_Heating_2_Temp_Low_Alarm',
#  'URL-CONV.L11_Bottom_Heating_3_OP',
#  'URL-CONV.L11_Bottom_Heating_3_PV',
#  'URL-CONV.L11_Bottom_Heating_3_Temp_High_Alarm',
#  'URL-CONV.L11_Bottom_Heating_3_Temp_Low_Alarm',
#  'URL-CONV.L11_Bottom_Heating_4_OP',
#  'URL-CONV.L11_Bottom_Heating_4_PV',
#  'URL-CONV.L11_Bottom_Heating_4_Temp_High_Alarm',
#  'URL-CONV.L11_Bottom_Heating_4_Temp_Low_Alarm',
#  'URL-CONV.L11_Bottom_Heating_SP',
#  'URL-CONV.L11_Bottom_Metering_Draw',
#  'URL-CONV.L11_Bottom_Pump_G1_ActualPosition',
#  'URL-CONV.L11_Bottom_Pump_G1_ActualVelocity',
#  'URL-CONV.L11_Bottom_Pump_G1_CommandPosition',
#  'URL-CONV.L11_Bottom_Pump_G1_CommandVelocity',
#  'URL-CONV.L11_Bottom_Pump_G1_MotorCapacity',
#  'URL-CONV.L11_Bottom_Pump_G1_PositionError',
#  'URL-CONV.L11_Bottom_Pump_G1_TorqueFeedback',
#  'URL-CONV.L11_Bottom_Pump_G1_TorqueFeedback_RMS',
#  'URL-CONV.L11_Bottom_Pump_G2_ActualPosition',
#  'URL-CONV.L11_Bottom_Pump_G2_ActualVelocity',
#  'URL-CONV.L11_Bottom_Pump_G2_CommandPosition',
#  'URL-CONV.L11_Bottom_Pump_G2_CommandVelocity',
#  'URL-CONV.L11_Bottom_Pump_G2_MotorCapacity',
#  'URL-CONV.L11_Bottom_Pump_G2_PositionError',
#  'URL-CONV.L11_Bottom_Pump_G2_TorqueFeedback',
#  'URL-CONV.L11_Bottom_Pump_G2_TorqueFeedback_RMS',
#  'URL-CONV.L11_Bottom_Pump_G3_ActualPosition',
#  'URL-CONV.L11_Bottom_Pump_G3_ActualVelocity',
#  'URL-CONV.L11_Bottom_Pump_G3_CommandPosition',
#  'URL-CONV.L11_Bottom_Pump_G3_CommandVelocity',
#  'URL-CONV.L11_Bottom_Pump_G3_MotorCapacity',
#  'URL-CONV.L11_Bottom_Pump_G3_PositionError',
#  'URL-CONV.L11_Bottom_Pump_G3_TorqueFeedback',
#  'URL-CONV.L11_Bottom_Pump_G3_TorqueFeedback_RMS',
#  'URL-CONV.L11_Bottom_Pump_G4_ActualPosition',
#  'URL-CONV.L11_Bottom_Pump_G4_ActualVelocity',
#  'URL-CONV.L11_Bottom_Pump_G4_CommandPosition',
#  'URL-CONV.L11_Bottom_Pump_G4_CommandVelocity',
#  'URL-CONV.L11_Bottom_Pump_G4_MotorCapacity',
#  'URL-CONV.L11_Bottom_Pump_G4_PositionError',
#  'URL-CONV.L11_Bottom_Pump_G4_TorqueFeedback',
#  'URL-CONV.L11_Bottom_Pump_G4_TorqueFeedback_RMS',
#  'URL-CONV.L11_Bottom_Pump_G5_ActualPosition',
#  'URL-CONV.L11_Bottom_Pump_G5_ActualVelocity',
#  'URL-CONV.L11_Bottom_Pump_G5_CommandPosition',
#  'URL-CONV.L11_Bottom_Pump_G5_CommandVelocity',
#  'URL-CONV.L11_Bottom_Pump_G5_MotorCapacity',
#  'URL-CONV.L11_Bottom_Pump_G5_PositionError',
#  'URL-CONV.L11_Bottom_Pump_G5_TorqueFeedback',
#  'URL-CONV.L11_Bottom_Pump_G5_TorqueFeedback_RMS',
#  'URL-CONV.L11_Bottom_Pump_G6_ActualPosition',
#  'URL-CONV.L11_Bottom_Pump_G6_ActualVelocity',
#  'URL-CONV.L11_Bottom_Pump_G6_CommandPosition',
#  'URL-CONV.L11_Bottom_Pump_G6_CommandVelocity',
#  'URL-CONV.L11_Bottom_Pump_G6_MotorCapacity',
#  'URL-CONV.L11_Bottom_Pump_G6_PositionError',
#  'URL-CONV.L11_Bottom_Pump_G6_TorqueFeedback',
#  'URL-CONV.L11_Bottom_Pump_G6_TorqueFeedback_RMS',
#  'URL-CONV.L11_Bottom_Shuttle_ActualPosition',
#  'URL-CONV.L11_Bottom_Shuttle_ActualVelocity',
#  'URL-CONV.L11_Bottom_Shuttle_CommandPosition',
#  'URL-CONV.L11_Bottom_Shuttle_CommandVelocity',
#  'URL-CONV.L11_Bottom_Shuttle_MotorCapacity',
#  'URL-CONV.L11_Bottom_Shuttle_PositionError',
#  'URL-CONV.L11_Bottom_Shuttle_TimeOverCavity',
#  'URL-CONV.L11_Bottom_shuttle_TimeTotalCycle',
#  'URL-CONV.L11_Bottom_Shuttle_TorqueFeedback',
#  'URL-CONV.L11_Bottom_Shuttle_TorqueFeedback_RMS',
#  'URL-CONV.L11_Bottom_solvent_actualflow',
#  'URL-CONV.L11_Bottom_Solvent_Felt_Kp',
#  'URL-CONV.L11_Bottom_Solvent_Felt_Wid',
#  'URL-CONV.L11_Bottom_Solvent_Flowrate_NotInProcessLimits_Alarm',
#  'URL-CONV.L11_Bottom_solvent_flowsetpoint',
#  'URL-CONV.L11_Bottom_Solvent_Level_High_Alarm',
#  'URL-CONV.L11_Bottom_Solvent_Level_Low_Alarm',
#  'URL-CONV.L11_Bottom_Solvent_Level_NotInProcessLimits_Alarm',
#  'URL-CONV.L11_Bottom_Solvent_Lvl',
#  'URL-CONV.L11_Bottom_Solvent_Lvl_Filt',
#  'URL-CONV.L11_Bottom_Solvent_Roll_ActualPosition',
#  'URL-CONV.L11_Bottom_Solvent_Roll_ActualVelocity',
#  'URL-CONV.L11_Bottom_Solvent_Roll_ActualVelocity_RPM2',
#  'URL-CONV.L11_Bottom_Solvent_Roll_CommandPosition',
#  'URL-CONV.L11_Bottom_Solvent_Roll_CommandVelocity',
#  'URL-CONV.L11_Bottom_Solvent_Roll_MotorCapacity',
#  'URL-CONV.L11_Bottom_Solvent_Roll_PositionError',
#  'URL-CONV.L11_Bottom_Solvent_Roll_RPM_Gain',
#  'URL-CONV.L11_Bottom_Solvent_Roll_RPM_Max',
#  'URL-CONV.L11_Bottom_Solvent_Roll_RPM_Min',
#  'URL-CONV.L11_Bottom_Solvent_Roll_TorqueFeedack',
#  'URL-CONV.L11_Bottom_Solvent_Roll_TorqueFeedack_RMS',
#  'URL-CONV.L11_Bottom_Solvent_STDEV',
#  'URL-CONV.L11_Bottom_solvent_Valveoutput',
#  'URL-CONV.L11_Bottom_Solvent_Valveoutput_%',
#  'URL-CONV.L11_Bottom_Unwinder_Current_Diameter_Left',
#  'URL-CONV.L11_Bottom_Unwinder_Current_Diameter_Right',
#  'URL-CONV.L11_Bottom_Unwinder_Dancer_Position',
#  'URL-CONV.L11_Bottom_Unwinder_Rotary_Speed_Left',
#  'URL-CONV.L11_Bottom_Unwinder_Rotary_Speed_Right',
#  'URL-CONV.L11_Bottom_Unwinder_SpliceInProgress',
#  'URL-CONV.L11_BottomFillTime',
#  'URL-CONV.L11_BottomLiquidBreakTankLevel',
#  'URL-CONV.L11_BottomLiquidDoseVolume',
#  'URL-CONV.L11_BottomLiquidTemp',
#  'URL-CONV.L11_BottomNozzleCloseAdvanceTime',
#  'URL-CONV.L11_BottomNozzleOpenAdvanceTime',
#  'URL-CONV.L11_BottomPumpEnableAll',
#  'URL-CONV.L11_BottomPumpGroup1_DoseAdjustment',
#  'URL-CONV.L11_BottomPumpGroup2_DoseAdjustment',
#  'URL-CONV.L11_BottomPumpGroup3_DoseAdjustment',
#  'URL-CONV.L11_BottomPumpGroup4_DoseAdjustment.',
#  'URL-CONV.L11_BottomPumpGroup5_DoseAdjustment',
#  'URL-CONV.L11_BottomPumpGroup6_DoseAdjustment',
#  'URL-CONV.L11_BottomPumpMaxVel',
#  'URL-CONV.L11_BottomPumpStartAdvanceTime',
#  'URL-CONV.L11_BottomPumpTotalCycleTime',
#  'URL-CONV.L11_BottomRefillDelayTime',
#  'URL-CONV.L11_BottomRefillMaxSpeed',
#  'URL-CONV.L11_BottomRefillTime',
#  'URL-CONV.L11_BottomRollFeltHourTimer',
#  'URL-CONV.L11_BottomShuttlePhaseOffset.',
#  'URL-CONV.L11_BottomSolventCoatWeight',
#  'URL-CONV.L11_BottomSolventLevel_MovingAverage',
#  'URL-CONV.L11_BottomSolventLevel_StandardDeviation',
#  'URL-CONV.L11_BottomSolventPan_LevelControlEnable',
#  'URL-CONV.L11_BottomSolventPumpProcessLimit_Sts_Active',
#  'URL-CONV.L11_BottomUnwindleftspliceactive',
#  'URL-CONV.L11_BottomUnwindrightspliceactive',
#  'URL-CONV.L11_CD_Cutter_ActualPosition',
#  'URL-CONV.L11_CD_Cutter_ActualVelocity',
#  'URL-CONV.L11_CD_Cutter_CommandPosition',
#  'URL-CONV.L11_CD_Cutter_CommandVelocity',
#  'URL-CONV.L11_CD_Cutter_Dwell',
#  'URL-CONV.L11_CD_Cutter_MotorCapacity',
#  'URL-CONV.L11_CD_Cutter_PositionError',
#  'URL-CONV.L11_CD_Cutter_TorqueFeedback',
#  'URL-CONV.L11_CD_Cutter_TorqueFeedback_RMS',
#  'URL-CONV.L11_CD_CutterPhaseOffset',
#  'URL-CONV.L11_Combining_Roll_Pressure_bar',
#  'URL-CONV.L11_Current_Alarm',
#  'URL-CONV.L11_Current_Machine_Speed',
#  'URL-CONV.L11_Current_Mode_Number',
#  'URL-CONV.L11_Current_State_Number',
#  'URL-CONV.L11_Diverter_Position',
#  'URL-CONV.L11_Extraction_Drum_ActualPosition',
#  'URL-CONV.L11_Extraction_Drum_ActualVelocity',
#  'URL-CONV.L11_Extraction_Drum_CommandPosition',
#  'URL-CONV.L11_Extraction_Drum_CommandVelocity',
#  'URL-CONV.L11_Extraction_Drum_MotorCapacity',
#  'URL-CONV.L11_Extraction_Drum_PositionError',
#  'URL-CONV.L11_Extraction_Drum_TorqueFeedback',
#  'URL-CONV.L11_Extraction_Drum_TorqueFeedback_RMS',
#  'URL-CONV.L11_First_Out_Fault_Category',
#  'URL-CONV.L11_First_Out_Fault_ID',
#  'URL-CONV.L11_Hygro_Enclosure',
#  'URL-CONV.L11_MD_Cutter_ActualVelocity',
#  'URL-CONV.L11_MD_Cutter_TorqueFeedback',
#  'URL-CONV.L11_MD_Cutter_TorqueFeedback_RMS',
#  'URL-CONV.L11_Middle_Metering_Draw',
#  'URL-CONV.L11_Middle_Unwinder_Current_Diameter_Left',
#  'URL-CONV.L11_Middle_Unwinder_Current_Diameter_Right',
#  'URL-CONV.L11_Middle_Unwinder_Dancer_Position',
#  'URL-CONV.L11_Middle_Unwinder_Rotary_Speed_Left',
#  'URL-CONV.L11_Middle_Unwinder_Rotary_Speed_Right',
#  'URL-CONV.L11_Middle_Unwinder_SpliceInProgress',
#  'URL-CONV.L11_middleUnwindleftspliceactive',
#  'URL-CONV.L11_MiddleUnwindrightspliceactive',
#  'URL-CONV.L11_nc_VEC_Main_Status_DINT_3',
#  'URL-CONV.L11_Nectar_Drum_ActualPosition',
#  'URL-CONV.L11_Nectar_Drum_ActualVelocity',
#  'URL-CONV.L11_Nectar_Drum_CommandPosition',
#  'URL-CONV.L11_Nectar_Drum_CommandVelocity',
#  'URL-CONV.L11_Nectar_Drum_MotorCapacity',
#  'URL-CONV.L11_Nectar_Drum_PositionError',
#  'URL-CONV.L11_Nectar_Drum_TorqueFeedback',
#  'URL-CONV.L11_Nectar_Drum_TorqueFeedback_RMS',
#  'URL-CONV.L11_NectarDrum_PressureDS_bar',
#  'URL-CONV.L11_NectarDrum_PressureOS_bar',
#  'URL-CONV.L11_NectarDrumPhaseOffset',
#  'URL-CONV.L11_NectarDrumVacFault',
#  'URL-CONV.L11_PackML_Execute',
#  'URL-CONV.L11_Platen_Chain_ActualPosition',
#  'URL-CONV.L11_Platen_Chain_ActualVelocity',
#  'URL-CONV.L11_Platen_Chain_CommandPosition',
#  'URL-CONV.L11_Platen_Chain_CommandVelocity',
#  'URL-CONV.L11_Platen_Chain_MotorCapacity',
#  'URL-CONV.L11_Platen_Chain_PositionError',
#  'URL-CONV.L11_Platen_Chain_TorqueFeedback',
#  'URL-CONV.L11_Platen_Chain_TorqueFeedback_RMS',
#  'URL-CONV.L11_PouchesDosedCount',
#  'URL-CONV.L11_Powdering_Extrac_Pump_Speed',
#  'URL-CONV.L11_PP_Actual_Ink_Flow_forward_Pump_Black',
#  'URL-CONV.L11_PP_Actual_Ink_Flow_forward_Pump_Red',
#  'URL-CONV.L11_PP_Actual_Ink_Flow_forward_Pump_White',
#  'URL-CONV.L11_PP_Actual_Stroke_Frequency_forward_Pump_Black',
#  'URL-CONV.L11_PP_Actual_Stroke_Frequency_forward_Pump_Red',
#  'URL-CONV.L11_PP_Actual_Stroke_Frequency_forward_Pump_White',
#  'URL-CONV.L11_PP_anilox1_ActualPosition',
#  'URL-CONV.L11_PP_anilox1_ActualVelocity',
#  'URL-CONV.L11_PP_anilox1_MotorCapacity',
#  'URL-CONV.L11_PP_anilox1_PositionError',
#  'URL-CONV.L11_PP_anilox1_TorqueFeedback',
#  'URL-CONV.L11_PP_anilox2_ActualPosition',
#  'URL-CONV.L11_PP_anilox2_ActualVelocity',
#  'URL-CONV.L11_PP_anilox2_MotorCapacity',
#  'URL-CONV.L11_PP_anilox2_PositionError',
#  'URL-CONV.L11_PP_anilox2_TorqueFeedback',
#  'URL-CONV.L11_PP_anilox3_ActualPosition',
#  'URL-CONV.L11_PP_anilox3_ActualVelocity',
#  'URL-CONV.L11_PP_anilox3_MotorCapacity',
#  'URL-CONV.L11_PP_anilox3_PositionError',
#  'URL-CONV.L11_PP_anilox3_TorqueFeedback',
#  'URL-CONV.L11_PP_Cliche1_ActualPosition',
#  'URL-CONV.L11_PP_Cliche1_ActualVelocity',
#  'URL-CONV.L11_PP_Cliche1_MotorCapacity',
#  'URL-CONV.L11_PP_Cliche1_PositionError',
#  'URL-CONV.L11_PP_Cliche1_RFID_1',
#  'URL-CONV.L11_PP_Cliche1_RFID_2',
#  'URL-CONV.L11_PP_Cliche1_TorqueFeedback',
#  'URL-CONV.L11_PP_Cliche2_ActualPosition',
#  'URL-CONV.L11_PP_Cliche2_ActualVelocity',
#  'URL-CONV.L11_PP_Cliche2_MotorCapacity',
#  'URL-CONV.L11_PP_Cliche2_PositionError',
#  'URL-CONV.L11_PP_Cliche2_RFID_1',
#  'URL-CONV.L11_PP_Cliche2_RFID_2',
#  'URL-CONV.L11_PP_Cliche2_TorqueFeedback',
#  'URL-CONV.L11_PP_Cliche3_ActualPosition',
#  'URL-CONV.L11_PP_Cliche3_ActualVelocity',
#  'URL-CONV.L11_PP_Cliche3_MotorCapacity',
#  'URL-CONV.L11_PP_Cliche3_PositionError',
#  'URL-CONV.L11_PP_Cliche3_RFID_1',
#  ...]

# %%
available_tags=[t for t in all_tag_list if t in all_site_tags_list]
missing_tags=[t for t in all_tag_list if t not in available_tags]
print(len(available_tags),len(missing_tags))
# Out:
# 126 0

# %%
missing_tags
# Out:
# []

# %% [markdown]
# ## high level check of tag values(min, max, negative values, etc.)
# ### extracting data for short timespan

# %%
start_time = pd.to_datetime('2022-05-23 12:00:00')
end_time = pd.to_datetime('2022-05-23 14:00:00')
print(f'Extracting data between: {start_time} and {end_time}')
# Out:
# Extracting data between: 2022-05-23 12:00:00 and 2022-05-23 14:00:00

# %%
historian_extract_df = historian.get_tag_values(
                    site_servers['historian']['proficy']['server_name'],
                    start_time=start_time,
                    end_time=end_time,
                    filter_name=list(all_tag_list))
print(f'Shape of data extract: {historian_extract_df.shape}')
# Out:
# Shape of data extract: (202, 2)

# %%
historian_extract_df
# Out:
#                                                                                     Value  \
# Tag                                                Timestamp
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Rej... 2022-05-23 12:54:22.672000+00:00     0
#                                                    2022-05-23 12:53:44.295000+00:00     0
#                                                    2022-05-23 12:53:36.075000+00:00     0
#                                                    2022-05-23 12:52:36.416000+00:00     0
#                                                    2022-05-23 12:52:27.072000+00:00     0
# ...                                                                                   ...
# URL-PACK.L13_Upack_LineRecipe                      2022-05-23 12:45:17.049000+00:00     0
#                                                    2022-05-23 12:44:17.529000+00:00    22
#                                                    2022-05-23 12:43:47.121000+00:00     0
#                                                    2022-05-23 12:43:41.059000+00:00     0
#                                                    2022-05-23 12:42:41.617000+00:00     0
#
#                                                                                     Quality
# Tag                                                Timestamp
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Rej... 2022-05-23 12:54:22.672000+00:00       3
#                                                    2022-05-23 12:53:44.295000+00:00       0
#                                                    2022-05-23 12:53:36.075000+00:00       0
#                                                    2022-05-23 12:52:36.416000+00:00       0
#                                                    2022-05-23 12:52:27.072000+00:00       0
# ...                                                                                     ...
# URL-PACK.L13_Upack_LineRecipe                      2022-05-23 12:45:17.049000+00:00       0
#                                                    2022-05-23 12:44:17.529000+00:00       3
#                                                    2022-05-23 12:43:47.121000+00:00       0
#                                                    2022-05-23 12:43:41.059000+00:00       0
#                                                    2022-05-23 12:42:41.617000+00:00       0
#
# [202 rows x 2 columns]

# %%
### flatten data
extract_df=historian_extract_df.reset_index()
extract_df
# Out:
#                                                    Tag  \
# 0    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# 1    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# 2    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# 3    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# 4    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# ..                                                 ...
# 197                      URL-PACK.L13_Upack_LineRecipe
# 198                      URL-PACK.L13_Upack_LineRecipe
# 199                      URL-PACK.L13_Upack_LineRecipe
# 200                      URL-PACK.L13_Upack_LineRecipe
# 201                      URL-PACK.L13_Upack_LineRecipe
#
#                            Timestamp Value Quality
# 0   2022-05-23 12:54:22.672000+00:00     0       3
# 1   2022-05-23 12:53:44.295000+00:00     0       0
# 2   2022-05-23 12:53:36.075000+00:00     0       0
# 3   2022-05-23 12:52:36.416000+00:00     0       0
# 4   2022-05-23 12:52:27.072000+00:00     0       0
# ..                               ...   ...     ...
# 197 2022-05-23 12:45:17.049000+00:00     0       0
# 198 2022-05-23 12:44:17.529000+00:00    22       3
# 199 2022-05-23 12:43:47.121000+00:00     0       0
# 200 2022-05-23 12:43:41.059000+00:00     0       0
# 201 2022-05-23 12:42:41.617000+00:00     0       0
#
# [202 rows x 4 columns]

# %%
extract_df=extract_df.assign(Value=(pd.to_numeric(extract_df['Value'])))
extract_df
# Out:
#                                                    Tag  \
# 0    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# 1    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# 2    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# 3    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# 4    URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Re...
# ..                                                 ...
# 197                      URL-PACK.L13_Upack_LineRecipe
# 198                      URL-PACK.L13_Upack_LineRecipe
# 199                      URL-PACK.L13_Upack_LineRecipe
# 200                      URL-PACK.L13_Upack_LineRecipe
# 201                      URL-PACK.L13_Upack_LineRecipe
#
#                            Timestamp  Value Quality
# 0   2022-05-23 12:54:22.672000+00:00      0       3
# 1   2022-05-23 12:53:44.295000+00:00      0       0
# 2   2022-05-23 12:53:36.075000+00:00      0       0
# 3   2022-05-23 12:52:36.416000+00:00      0       0
# 4   2022-05-23 12:52:27.072000+00:00      0       0
# ..                               ...    ...     ...
# 197 2022-05-23 12:45:17.049000+00:00      0       0
# 198 2022-05-23 12:44:17.529000+00:00     22       3
# 199 2022-05-23 12:43:47.121000+00:00      0       0
# 200 2022-05-23 12:43:41.059000+00:00      0       0
# 201 2022-05-23 12:42:41.617000+00:00      0       0
#
# [202 rows x 4 columns]

# %%
extract_df.groupby('Tag').describe()
# Out:
#                                                    Value               \
#                                                    count         mean
# Tag
# URL-PACK.L13_Secondary_FC11_Dataman_Reads_Resul...   9.0    16.666667
# URL-PACK.L13_Secondary_FC11_Dataman_Reads_Resul...   9.0     0.000000
# URL-PACK.L13_Secondary_FC11_Minibea_Reads_Resul...   9.0     0.444444
# URL-PACK.L13_Secondary_FC11_Minibea_Reads_Resul...   9.0     7.555556
# URL-PACK.L13_Secondary_FC11_Minibea_Reads_Resul...   9.0  1538.666667
# URL-PACK.L13_Upack_BoxCheckweigher_0_Extra_Reje...  14.0     0.000000
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Rej...  14.0     0.000000
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_1_Not...  14.0     0.000000
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_2_Not...  14.0     0.000000
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_3_Rej...  14.0     0.000000
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_4_Rej...  14.0     0.000000
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Case...   9.0     0.000000
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Exte...   9.0     0.000000
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Leak...   9.0     0.000000
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Weig...   9.0     0.000000
# URL-PACK.L13_Upack_LineRecipe                       14.0     6.285714
# URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n      9.0     0.000000
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n  14.0     6.285714
#
#                                                                            \
#                                                             std  min  25%
# Tag
# URL-PACK.L13_Secondary_FC11_Dataman_Reads_Resul...    33.071891  0.0  0.0
# URL-PACK.L13_Secondary_FC11_Dataman_Reads_Resul...     0.000000  0.0  0.0
# URL-PACK.L13_Secondary_FC11_Minibea_Reads_Resul...     0.881917  0.0  0.0
# URL-PACK.L13_Secondary_FC11_Minibea_Reads_Resul...    14.992591  0.0  0.0
# URL-PACK.L13_Secondary_FC11_Minibea_Reads_Resul...  3053.197013  0.0  0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Extra_Reje...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Rej...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_1_Not...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_2_Not...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_3_Rej...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_4_Rej...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Case...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Exte...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Leak...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Weig...     0.000000  0.0  0.0
# URL-PACK.L13_Upack_LineRecipe                         10.313759  0.0  0.0
# URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n        0.000000  0.0  0.0
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n    10.313759  0.0  0.0
#
#
#                                                     50%   75%     max
# Tag
# URL-PACK.L13_Secondary_FC11_Dataman_Reads_Resul...  0.0   0.0    75.0
# URL-PACK.L13_Secondary_FC11_Dataman_Reads_Resul...  0.0   0.0     0.0
# URL-PACK.L13_Secondary_FC11_Minibea_Reads_Resul...  0.0   0.0     2.0
# URL-PACK.L13_Secondary_FC11_Minibea_Reads_Resul...  0.0   0.0    34.0
# URL-PACK.L13_Secondary_FC11_Minibea_Reads_Resul...  0.0   0.0  6924.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Extra_Reje...  0.0   0.0     0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Rej...  0.0   0.0     0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_1_Not...  0.0   0.0     0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_2_Not...  0.0   0.0     0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_3_Rej...  0.0   0.0     0.0
# URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_4_Rej...  0.0   0.0     0.0
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Case...  0.0   0.0     0.0
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Exte...  0.0   0.0     0.0
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Leak...  0.0   0.0     0.0
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Weig...  0.0   0.0     0.0
# URL-PACK.L13_Upack_LineRecipe                       0.0  16.5    22.0
# URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n     0.0   0.0     0.0
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n  0.0  16.5    22.0

# %%
extract_df.groupby('Tag').describe().describe()
# Out:
#            Value                                                         \
#            count         mean          std   min   25%   50%        75%
# count  18.000000    18.000000    18.000000  18.0  18.0  18.0  18.000000
# mean   11.222222    87.550265   173.487274   0.0   0.0   0.0   1.833333
# std     2.556550   362.177915   718.731850   0.0   0.0   0.0   5.335784
# min     9.000000     0.000000     0.000000   0.0   0.0   0.0   0.000000
# 25%     9.000000     0.000000     0.000000   0.0   0.0   0.0   0.000000
# 50%     9.000000     0.000000     0.000000   0.0   0.0   0.0   0.000000
# 75%    14.000000     4.825397     7.955799   0.0   0.0   0.0   0.000000
# max    14.000000  1538.666667  3053.197013   0.0   0.0   0.0  16.500000
#
#
#                max
# count    18.000000
# mean    393.277778
# std    1629.967802
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%      17.000000
# max    6924.000000

# %%
#checking if Value contains negative values
(extract_df['Value']<0).any()
# Out:
# False

# %% [markdown]
# ### Increasing timespan of data extraction for 2 day

# %%
## extracting data
start_dttm = datetime.now() - timedelta(days=1)
#start_dttm = start_dttm - timedelta(days=site_days_to_retake)
start_time = start_dttm
end_time = datetime.now()
print(f'Extracting data between: {start_time} and {end_time}')
# Out:
# Extracting data between: 2022-06-07 07:55:45.501470 and 2022-06-08 07:55:45.501470

# %%
historian_extract_df_new = historian.get_tag_values(
                    site_servers['historian']['proficy']['server_name'],
                    start_time=start_time,
                    end_time=end_time,
                    filter_name=list(all_tag_list))
print(f'Shape of data extract: {historian_extract_df_new.shape}')
# Out:
# Shape of data extract: (65, 2)

# %%
historian_extract_df_new
# Out:
#                                                                                      Value  \
# Tag                                                Timestamp
# URL-PACK.L13_Cover_General_ExtractedCartons_Tot... 2022-06-03 09:37:18.241000+00:00  20276
#                                                    2022-06-03 09:37:17.225000+00:00  20274
#                                                    2022-06-03 09:37:16.240000+00:00  20272
#                                                    2022-06-03 09:37:15.225000+00:00  20269
#                                                    2022-06-03 09:37:14.240000+00:00  20267
# ...                                                                                    ...
# URL-PACK.L13_Base_Checkweigher_Washcount_Check_... 2022-06-02 12:03:38.570000+00:00      1
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n 2022-06-03 05:10:01.674000+00:00     19
#                                                    2022-06-02 19:52:09.532000+00:00      0
#                                                    2022-06-02 06:29:27.883000+00:00     15
# URL-PACK.L13_Upack_LineRecipe                      2022-06-02 06:29:29.883000+00:00     13
#
#                                                                                     Quality
# Tag                                                Timestamp
# URL-PACK.L13_Cover_General_ExtractedCartons_Tot... 2022-06-03 09:37:18.241000+00:00       3
#                                                    2022-06-03 09:37:17.225000+00:00       3
#                                                    2022-06-03 09:37:16.240000+00:00       3
#                                                    2022-06-03 09:37:15.225000+00:00       3
#                                                    2022-06-03 09:37:14.240000+00:00       3
# ...                                                                                     ...
# URL-PACK.L13_Base_Checkweigher_Washcount_Check_... 2022-06-02 12:03:38.570000+00:00       3
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n 2022-06-03 05:10:01.674000+00:00       3
#                                                    2022-06-02 19:52:09.532000+00:00       3
#                                                    2022-06-02 06:29:27.883000+00:00       3
# URL-PACK.L13_Upack_LineRecipe                      2022-06-02 06:29:29.883000+00:00       3
#
# [108212 rows x 2 columns]

# %%
extract_df_new=historian_extract_df_new.reset_index()
extract_df_new.head()
# Out:
#                                                  Tag  \
# 0  URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 1  URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 2  URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 3  URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 4  URL-PACK.L13_Cover_General_ExtractedCartons_To...
#
#                          Timestamp  Value Quality
# 0 2022-06-03 09:37:18.241000+00:00  20276       3
# 1 2022-06-03 09:37:17.225000+00:00  20274       3
# 2 2022-06-03 09:37:16.240000+00:00  20272       3
# 3 2022-06-03 09:37:15.225000+00:00  20269       3
# 4 2022-06-03 09:37:14.240000+00:00  20267       3

# %%
extract_df_new=extract_df_new.assign(Value_num=(pd.to_numeric(extract_df_new['Value'])))
extract_df_new.head()
# Out:
#                                                  Tag  \
# 0  URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 1  URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 2  URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 3  URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 4  URL-PACK.L13_Cover_General_ExtractedCartons_To...
#
#                          Timestamp  Value Quality  Value_num
# 0 2022-06-03 09:37:18.241000+00:00  20276       3    20276.0
# 1 2022-06-03 09:37:17.225000+00:00  20274       3    20274.0
# 2 2022-06-03 09:37:16.240000+00:00  20272       3    20272.0
# 3 2022-06-03 09:37:15.225000+00:00  20269       3    20269.0
# 4 2022-06-03 09:37:14.240000+00:00  20267       3    20267.0

# %%
extract_df_new.groupby('Tag').describe().describe()
# Out:
#           Value_num                                                     \
#               count          mean          std        min          25%
# count     87.000000     87.000000    80.000000  87.000000    87.000000
# mean    1243.816092    867.464061   575.112013   0.183908   424.605287
# std     4124.760939   3104.913948  1961.050100   1.402064  1527.418762
# min        1.000000      0.000000     0.577350   0.000000     0.000000
# 25%        3.500000      1.200000     1.112697   0.000000     0.500000
# 50%       11.000000      3.500000     2.836039   0.000000     1.750000
# 75%       51.000000     16.758571    15.328926   0.000000     7.750000
# max    19030.000000  14036.296479  8571.569619  13.000000  6870.250000
#
#
#                 50%           75%           max
# count     87.000000     87.000000     87.000000
# mean     844.392069   1258.984023   1955.889425
# std     3029.463418   4500.853991   6986.556685
# min        0.000000      0.000000      0.000000
# 25%        1.000000      1.875000      2.000000
# 50%        3.000000      5.250000      8.000000
# 75%       15.500000     26.250000     40.000000
# max    13557.000000  20284.500000  32049.000000

# %%
extract_df_new.groupby('Tag').describe()
# Out:
#                                                    Value_num             \
#                                                        count       mean
# Tag
# URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_Ti...       8.0   2.250000
# URL-PACK.L13_Base_Checkweigher_Base_2Dcheck_Not...       2.0   0.500000
# URL-PACK.L13_Base_Checkweigher_Cover_2Dcheck_No...       6.0   2.500000
# URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_N...       6.0   4.500000
# URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_T...       2.0   0.500000
# ...                                                      ...        ...
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Exte...       7.0   3.000000
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Weig...       3.0   0.666667
# URL-PACK.L13_Upack_LineRecipe                            1.0  13.000000
# URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n         12.0   3.500000
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n       3.0  11.333333
#
#                                                                             \
#                                                           std   min    25%
# Tag
# URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_Ti...   1.669046   0.0   1.00
# URL-PACK.L13_Base_Checkweigher_Base_2Dcheck_Not...   0.707107   0.0   0.25
# URL-PACK.L13_Base_Checkweigher_Cover_2Dcheck_No...   1.870829   0.0   1.25
# URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_N...   3.885872   0.0   2.00
# URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_T...   0.707107   0.0   0.25
# ...                                                       ...   ...    ...
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Exte...   2.160247   0.0   1.50
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Weig...   0.577350   0.0   0.50
# URL-PACK.L13_Upack_LineRecipe                             NaN  13.0  13.00
# URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n      2.540580   0.0   1.75
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n  10.016653   0.0   7.50
#
#
#                                                      50%    75%   max
# Tag
# URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_Ti...   2.0   3.25   5.0
# URL-PACK.L13_Base_Checkweigher_Base_2Dcheck_Not...   0.5   0.75   1.0
# URL-PACK.L13_Base_Checkweigher_Cover_2Dcheck_No...   2.5   3.75   5.0
# URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_N...   3.5   7.25  10.0
# URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_T...   0.5   0.75   1.0
# ...                                                  ...    ...   ...
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Exte...   3.0   4.50   6.0
# URL-PACK.L13_Upack_CaseCheckweigher_Reject_Weig...   1.0   1.00   1.0
# URL-PACK.L13_Upack_LineRecipe                       13.0  13.00  13.0
# URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n      3.0   5.25   8.0
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n  15.0  17.00  19.0
#
# [87 rows x 8 columns]

# %%
# checking if Value contains negative
(extract_df_new['Value_num']<0).any()
# Out:
# False

# %% [markdown]
# ## checking counters validity

# %% [markdown]
# ### reject counter tags

# %%
tags_to_extract=[t for t in all_tag_list if ('CaseCheckweigher_Reject_Case_Weight_Real' not in t) & ('LineRecipe' not in t)]
print(len(tags_to_extract))
# Out:
# 124

# %% [markdown]
# ### Extracting 2 day data for all reject counter tags

# %%
## defining timeframe for extracting data
start_dttm = datetime.now() - timedelta(days=2)
#start_dttm = start_dttm - timedelta(days=site_days_to_retake)
start_time = start_dttm
end_time = datetime.now()
print(f'Extracting data between: {start_time} and {end_time}')
# Out:
# Extracting data between: 2022-06-01 09:43:55.680492 and 2022-06-03 09:43:55.680492

# %%
historian_extract = historian.get_tag_values(
                    site_servers['historian']['proficy']['server_name'],
                    start_time=start_time,
                    end_time=end_time,
                    filter_name=list(tags_to_extract))
print(f'Shape of data extract: {historian_extract.shape}')
# Out:
# Shape of data extract: (89760, 2)

# %%
historian_extract
# Out:
#                                                                                      Value  \
# Tag                                                Timestamp
# URL-PACK.L13_Cover_General_ExtractedCartons_Tot... 2022-06-03 09:37:18.241000+00:00  20276
#                                                    2022-06-03 09:37:17.225000+00:00  20274
#                                                    2022-06-03 09:37:16.240000+00:00  20272
#                                                    2022-06-03 09:37:15.225000+00:00  20269
#                                                    2022-06-03 09:37:14.240000+00:00  20267
# ...                                                                                    ...
# URL-PACK.L13_Base_Checkweigher_Washcount_Check_... 2022-06-02 16:53:08.164000+00:00      2
#                                                    2022-06-02 12:03:38.570000+00:00      1
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n 2022-06-03 05:10:01.674000+00:00     19
#                                                    2022-06-02 19:52:09.532000+00:00      0
#                                                    2022-06-02 06:29:27.883000+00:00     15
#
#                                                                                     Quality
# Tag                                                Timestamp
# URL-PACK.L13_Cover_General_ExtractedCartons_Tot... 2022-06-03 09:37:18.241000+00:00       3
#                                                    2022-06-03 09:37:17.225000+00:00       3
#                                                    2022-06-03 09:37:16.240000+00:00       3
#                                                    2022-06-03 09:37:15.225000+00:00       3
#                                                    2022-06-03 09:37:14.240000+00:00       3
# ...                                                                                     ...
# URL-PACK.L13_Base_Checkweigher_Washcount_Check_... 2022-06-02 16:53:08.164000+00:00       3
#                                                    2022-06-02 12:03:38.570000+00:00       3
# URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoint_n 2022-06-03 05:10:01.674000+00:00       3
#                                                    2022-06-02 19:52:09.532000+00:00       3
#                                                    2022-06-02 06:29:27.883000+00:00       3
#
# [89760 rows x 2 columns]

# %%
#flatten the table
historian_extract=historian_extract.reset_index()
historian_extract_dfn=historian_extract[['Tag','Timestamp','Value']]
historian_extract_dfn
# Out:
#                                                      Tag  \
# 0      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 1      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 2      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 3      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 4      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# ...                                                  ...
# 89755  URL-PACK.L13_Base_Checkweigher_Washcount_Check...
# 89756  URL-PACK.L13_Base_Checkweigher_Washcount_Check...
# 89757  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89758  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89759  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
#
#                              Timestamp  Value
# 0     2022-06-03 09:37:18.241000+00:00  20276
# 1     2022-06-03 09:37:17.225000+00:00  20274
# 2     2022-06-03 09:37:16.240000+00:00  20272
# 3     2022-06-03 09:37:15.225000+00:00  20269
# 4     2022-06-03 09:37:14.240000+00:00  20267
# ...                                ...    ...
# 89755 2022-06-02 16:53:08.164000+00:00      2
# 89756 2022-06-02 12:03:38.570000+00:00      1
# 89757 2022-06-03 05:10:01.674000+00:00     19
# 89758 2022-06-02 19:52:09.532000+00:00      0
# 89759 2022-06-02 06:29:27.883000+00:00     15
#
# [89760 rows x 3 columns]

# %%
# converting timestamp and value column
historian_extract_dfn=historian_extract_dfn.assign(Timestamp = historian_extract_dfn['Timestamp'].dt.tz_convert(site_tz).dt.tz_localize(None),
                                            Value = (pd.to_numeric(historian_extract_dfn['Value'])))
historian_extract_dfn
# Out:
#                                                      Tag  \
# 0      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 1      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 2      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 3      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 4      URL-PACK.L13_Cover_General_ExtractedCartons_To...
# ...                                                  ...
# 89755  URL-PACK.L13_Base_Checkweigher_Washcount_Check...
# 89756  URL-PACK.L13_Base_Checkweigher_Washcount_Check...
# 89757  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89758  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89759  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
#
#                     Timestamp  Value
# 0     2022-06-03 11:37:18.241  20276
# 1     2022-06-03 11:37:17.225  20274
# 2     2022-06-03 11:37:16.240  20272
# 3     2022-06-03 11:37:15.225  20269
# 4     2022-06-03 11:37:14.240  20267
# ...                       ...    ...
# 89755 2022-06-02 18:53:08.164      2
# 89756 2022-06-02 14:03:38.570      1
# 89757 2022-06-03 07:10:01.674     19
# 89758 2022-06-02 21:52:09.532      0
# 89759 2022-06-02 08:29:27.883     15
#
# [89760 rows x 3 columns]

# %%
historian_extract_dfn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89760 entries, 0 to 89759
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Tag        89760 non-null  object
#  1   Timestamp  89760 non-null  datetime64[ns]
#  2   Value      89760 non-null  int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 2.1+ MB

# %%
#sort by tag name and time
historian_extract_dfn=historian_extract_dfn.sort_values(['Tag','Timestamp'],ascending=[False,True])
historian_extract_dfn
# Out:
#                                                      Tag  \
# 89759  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89758  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89757  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 86682    URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n
# 86681    URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n
# ...                                                  ...
# 72337  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72336  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72335  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72334  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72333  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
#
#                     Timestamp  Value
# 89759 2022-06-02 08:29:27.883     15
# 89758 2022-06-02 21:52:09.532      0
# 89757 2022-06-03 07:10:01.674     19
# 86682 2022-06-02 11:15:02.224      1
# 86681 2022-06-02 13:13:52.462      2
# ...                       ...    ...
# 72337 2022-06-02 13:19:28.479      4
# 72336 2022-06-02 16:40:49.888      5
# 72335 2022-06-02 21:52:06.532      0
# 72334 2022-06-03 07:25:59.712      1
# 72333 2022-06-03 07:26:05.712      2
#
# [89760 rows x 3 columns]

# %%
mask_rm = historian_extract_dfn['Value'].isnull() | (historian_extract_dfn['Value'] < 0)
counters_df = historian_extract_dfn.loc[~mask_rm].copy()
    
print(f'TRANSFORM: # removed records {sum(mask_rm)}')
print(f'TRANSFORM: Shape after step: {counters_df.shape}')
# Out:
# TRANSFORM: # removed records 0
# TRANSFORM: Shape after step: (89760, 3)

# %%
#calculating number of rejects
group_by = ['Tag']
counters_df = counters_df.assign(reject_qty=(counters_df.groupby(group_by)['Value'].diff().values))
counters_df
# Out:
#                                                      Tag  \
# 89759  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89758  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89757  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 86682    URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n
# 86681    URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n
# ...                                                  ...
# 72337  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72336  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72335  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72334  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72333  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
#
#                     Timestamp  Value  reject_qty
# 89759 2022-06-02 08:29:27.883     15         NaN
# 89758 2022-06-02 21:52:09.532      0       -15.0
# 89757 2022-06-03 07:10:01.674     19        19.0
# 86682 2022-06-02 11:15:02.224      1         NaN
# 86681 2022-06-02 13:13:52.462      2         1.0
# ...                       ...    ...         ...
# 72337 2022-06-02 13:19:28.479      4         1.0
# 72336 2022-06-02 16:40:49.888      5         1.0
# 72335 2022-06-02 21:52:06.532      0        -5.0
# 72334 2022-06-03 07:25:59.712      1         1.0
# 72333 2022-06-03 07:26:05.712      2         1.0
#
# [89760 rows x 4 columns]

# %%
## defining the counter reset
mask_reset = (counters_df['reject_qty'] < 0) & ((counters_df['Value'] == 0)
            )
counters_df = counters_df.assign(reset_flag = mask_reset)
counters_df
# Out:
#                                                      Tag  \
# 89759  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89758  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 89757  URL-PACK.L13_Upack_PO_PodsCount_Counter_SetPoi...
# 86682    URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n
# 86681    URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n
# ...                                                  ...
# 72337  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72336  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72335  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72334  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
# 72333  URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_T...
#
#                     Timestamp  Value  reject_qty  prev_value  next_value  \
# 89759 2022-06-02 08:29:27.883     15         NaN         NaN         0.0
# 89758 2022-06-02 21:52:09.532      0       -15.0        15.0        19.0
# 89757 2022-06-03 07:10:01.674     19        19.0         0.0         NaN
# 86682 2022-06-02 11:15:02.224      1         NaN         NaN         2.0
# 86681 2022-06-02 13:13:52.462      2         1.0         1.0         3.0
# ...                       ...    ...         ...         ...         ...
# 72337 2022-06-02 13:19:28.479      4         1.0         3.0         5.0
# 72336 2022-06-02 16:40:49.888      5         1.0         4.0         0.0
# 72335 2022-06-02 21:52:06.532      0        -5.0         5.0         1.0
# 72334 2022-06-03 07:25:59.712      1         1.0         0.0         2.0
# 72333 2022-06-03 07:26:05.712      2         1.0         1.0         NaN
#
#        reset_flag
# 89759       False
# 89758        True
# 89757       False
# 86682       False
# 86681       False
# ...           ...
# 72337       False
# 72336       False
# 72335        True
# 72334       False
# 72333       False
#
# [89760 rows x 7 columns]

# %%
## defining the counter not reset
mask_resetn = (counters_df['reject_qty'] < 0) & ((counters_df['Value'] != 0)
             )
counter_not_reset_df = counters_df.loc[mask_resetn]
counter_not_reset_df
# Out:
#                                                      Tag  \
# 24776  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 24581  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 24362  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 24270  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 23970  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 20633  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 20581  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 20579  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 20578  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 20577  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 20576  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 18110  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 18109  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17634  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17631  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17630  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17628  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17627  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17626  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17624  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17623  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17622  URL-PACK.L13_Cover_General_ProducedCovers_Tota...
# 17578  URL-PACK.L13_Cover_General_ExtractedCartons_To...
# 63118  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 63117  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 63116  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 61189  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59554  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59504  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59503  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59501  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59500  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59499  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59467  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59466  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59319  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59318  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 59317  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 56244  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 56243  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 56203  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 56196  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 56189  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 55898  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 55896  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 54413  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 54410  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 54101  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 53086  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 53084  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 52121  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 52120  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 47248  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 47242  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 46761  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 46472  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 45322  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
# 44401  URL-PACK.L13_Base_Machine_ProducedBases_0_Coun...
#
#                     Timestamp  Value  reject_qty  prev_value  next_value  \
# 24776 2022-06-02 08:29:28.851     41        -2.0        43.0        49.0
# 24581 2022-06-02 11:46:31.290   1365        -1.0      1366.0      1373.0
# 24362 2022-06-02 12:07:47.336   2862        -1.0      2863.0      2870.0
# 24270 2022-06-02 12:11:51.332   3523        -1.0      3524.0      3527.0
# 23970 2022-06-02 12:36:53.379   5730        -1.0      5731.0      5738.0
# 20633 2022-06-02 21:27:03.487  28844        -1.0     28845.0     28848.0
# 20581 2022-06-02 21:34:03.497  29187        -1.0     29188.0     29192.0
# 20579 2022-06-02 21:34:06.498  29190        -2.0     29192.0     29187.0
# 20578 2022-06-02 21:34:07.498  29187        -3.0     29190.0     29185.0
# 20577 2022-06-02 21:34:10.482  29185        -2.0     29187.0     29183.0
# 20576 2022-06-02 21:34:11.498  29183        -2.0     29185.0         0.0
# 18110 2022-06-03 11:02:32.171  17279        -1.0     17280.0     17278.0
# 18109 2022-06-03 11:02:33.171  17278        -1.0     17279.0     17286.0
# 17634 2022-06-03 11:40:06.237  20233        -3.0     20236.0     20235.0
# 17631 2022-06-03 11:40:09.237  20233        -3.0     20236.0     20232.0
# 17630 2022-06-03 11:40:10.237  20232        -1.0     20233.0     20233.0
# 17628 2022-06-03 11:40:13.237  20232        -1.0     20233.0     20229.0
# 17627 2022-06-03 11:40:14.237  20229        -3.0     20232.0     20228.0
# 17626 2022-06-03 11:40:16.237  20228        -1.0     20229.0     20230.0
# 17624 2022-06-03 11:40:18.237  20228        -2.0     20230.0     20226.0
# 17623 2022-06-03 11:40:19.237  20226        -2.0     20228.0     20225.0
# 17622 2022-06-03 11:40:23.237  20225        -1.0     20226.0         NaN
# 17578 2022-06-02 11:13:43.221    101        -1.0       102.0       102.0
# 63118 2022-06-02 11:13:40.220     24        -1.0        25.0        23.0
# 63117 2022-06-02 11:13:45.221     23        -1.0        24.0        22.0
# 63116 2022-06-02 11:13:46.205     22        -1.0        23.0        24.0
# 61189 2022-06-02 12:33:28.382   5527        -1.0      5528.0      5529.0
# 59554 2022-06-02 13:19:28.479  10082        -2.0     10084.0     10083.0
# 59504 2022-06-02 13:23:09.467  10195        -1.0     10196.0     10194.0
# 59503 2022-06-02 13:23:10.483  10194        -1.0     10195.0     10195.0
# 59501 2022-06-02 13:24:05.492  10194        -1.0     10195.0     10192.0
# 59500 2022-06-02 13:24:08.493  10192        -2.0     10194.0     10191.0
# 59499 2022-06-02 13:24:10.493  10191        -1.0     10192.0     10193.0
# 59467 2022-06-02 13:36:44.516  10270        -1.0     10271.0     10269.0
# 59466 2022-06-02 13:55:23.559  10269        -1.0     10270.0     10270.0
# 59319 2022-06-02 14:03:36.570  10680        -2.0     10682.0     10677.0
# 59318 2022-06-02 14:03:37.570  10677        -3.0     10680.0     10674.0
# 59317 2022-06-02 14:03:38.570  10674        -3.0     10677.0     10677.0
# 56244 2022-06-02 17:01:40.934  19149        -1.0     19150.0     19148.0
# 56243 2022-06-02 17:01:41.934  19148        -1.0     19149.0     19149.0
# 56203 2022-06-02 18:19:26.094  19230        -1.0     19231.0     19231.0
# 56196 2022-06-02 18:22:32.107  19235        -1.0     19236.0     19236.0
# 56189 2022-06-02 18:25:40.102  19239        -2.0     19241.0     19240.0
# 55898 2022-06-02 18:53:08.164  19960        -1.0     19961.0     19961.0
# 55896 2022-06-02 18:53:20.164  19960        -1.0     19961.0     19961.0
# 54413 2022-06-02 19:40:28.288  23873        -2.0     23875.0     23874.0
# 54410 2022-06-02 19:41:26.307  23874        -1.0     23875.0     23875.0
# 54101 2022-06-02 20:42:04.375  24574        -1.0     24575.0     24575.0
# 53086 2022-06-02 21:11:17.462  27127        -2.0     27129.0     27129.0
# 53084 2022-06-02 21:12:24.453  27128        -1.0     27129.0     27129.0
# 52121 2022-06-03 07:25:59.712     82        -1.0        83.0        81.0
# 52120 2022-06-03 07:26:05.712     81        -1.0        82.0        84.0
# 47248 2022-06-03 09:49:13.015  13200        -1.0     13201.0     13201.0
# 47242 2022-06-03 09:49:32.001  13208        -1.0     13209.0     13211.0
# 46761 2022-06-03 10:04:38.022  14303        -1.0     14304.0     14304.0
# 46472 2022-06-03 10:25:54.094  14943        -1.0     14944.0     14945.0
# 45322 2022-06-03 11:13:04.189  17709        -2.0     17711.0     17711.0
# 44401 2022-06-03 11:39:38.235  20070        -1.0     20071.0         NaN
#
#        reset_flag
# 24776       False
# 24581       False
# 24362       False
# 24270       False
# 23970       False
# 20633       False
# 20581       False
# 20579       False
# 20578       False
# 20577       False
# 20576       False
# 18110       False
# 18109       False
# 17634       False
# 17631       False
# 17630       False
# 17628       False
# 17627       False
# 17626       False
# 17624       False
# 17623       False
# 17622       False
# 17578       False
# 63118       False
# 63117       False
# 63116       False
# 61189       False
# 59554       False
# 59504       False
# 59503       False
# 59501       False
# 59500       False
# 59499       False
# 59467       False
# 59466       False
# 59319       False
# 59318       False
# 59317       False
# 56244       False
# 56243       False
# 56203       False
# 56196       False
# 56189       False
# 55898       False
# 55896       False
# 54413       False
# 54410       False
# 54101       False
# 53086       False
# 53084       False
# 52121       False
# 52120       False
# 47248       False
# 47242       False
# 46761       False
# 46472       False
# 45322       False
# 44401       False

# %%
len(counter_not_reset_df)
# Out:
# 58

# %%
counter_not_reset_df['Tag'].unique()
# Out:
# array(['URL-PACK.L13_Cover_General_ProducedCovers_Total_Counter_Actual_n',
#        'URL-PACK.L13_Cover_General_ExtractedCartons_Total_Counter_Actual_n',
#        'URL-PACK.L13_Base_Machine_ProducedBases_0_Counter_Actual_n'],
#       dtype=object)

# %% [markdown]
# ## new ETL process

# %% [markdown]
# ### tags for extracting reject data

# %%
reject_cause_dim_path = cfg['job']['path_to_reject_cause_dim']
print(f'Path to reject cause dimension table: {reject_cause_dim_path}')

# cheking if the reject cause dimension path exist
if not os.path.exists(reject_cause_dim_path):
    print(f'INFO: Didn not find reject cause table at {reject_cause_dim_path}.')
    raise ValueError('Was not able to find reject cause table. Aborting...')
else:
    reject_cause_df = pd.read_excel(reject_cause_dim_path)
    print(f'Shape of the reject cause table: {reject_cause_df.shape}')
# Out:
# Path to reject cause dimension table: F:\Ecosystem Non-OneDrive\Development Area\MVP048 SUD Box tool\Data\initial loading\REJECT_CAUSE_DIM.xlsx
# Shape of the reject cause table: (97, 6)

# %%
reject_cause_df.head()
# Out:
#    id                                             tag_nm  \
# 0  1   Cover_Extraction_Turret_CartonsNotExtracted_0_...
# 1  2   Cover_TransportBelt_CheckExternal_0_0_Rejected_n
# 2  3   Cover_TransportBelt_CheckInternal_0_0_Rejected_n
# 3  4   Cover_TransportBelt_RobotTrack_Skipped_0_Rejec...
# 4  5   Cover_Forming_PatchErectionCheck_Bad_Counter_R...
#
#                         cause           reason  \
# 0              Not extracted    Not extracted
# 1             Check External   Transport belt
# 2             Check Internal   Transport belt
# 3                Robot track   Transport belt
# 4  Patch  Erection Check Bad     Patch reject
#
#                                station    type
# 0  Cover Transport Belt RejectsBlanks   Cover
# 1  Cover Transport Belt RejectsBlanks   Cover
# 2  Cover Transport Belt RejectsBlanks   Cover
# 3  Cover Transport Belt RejectsBlanks   Cover
# 4    Cover Patch Control RejectsPatch   Cover

# %%
reject_tags = reject_cause_df.loc[:, 'tag_nm'].unique()
reject_tags = ['_'.join(t.split('_')) for t in reject_tags]
reject_tags
# Out:
# ['Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n\xa0',
#  'Cover_TransportBelt_CheckExternal_0_0_Rejected_n\xa0',
#  'Cover_TransportBelt_CheckInternal_0_0_Rejected_n\xa0',
#  'Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n\xa0',
#  'Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n\xa0',
#  'Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n\xa0',
#  'Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n\xa0',
#  'Cover_TransportBelt_HoleFlap_0_Check_Rejected_n\xa0',
#  'Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'Cover_Former1_ Glue_Dry _0_Rejected_n\xa0',
#  'Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n\xa0',
#  'Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n\xa0',
#  'Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n\xa0',
#  'Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n\xa0',
#  'Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n\xa0',
#  'Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n\xa0',
#  'Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n\xa0',
#  'Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n\xa0',
#  'Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'Cover_Former2_Glue_Dry_0_Rejected_n\xa0',
#  'Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n\xa0',
#  'Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n\xa0',
#  'Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n\xa0',
#  'Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n\xa0',
#  'Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n\xa0',
#  'Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n\xa0',
#  'Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n\xa0',
#  'Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n\xa0',
#  'Base_Machine_RejectedBases_Total_NOT_Extracted_Betw_Holders_n\xa0',
#  'Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n\xa0',
#  'Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n\xa0',
#  'Base_CameraTT_2Dcheck_0_NotRead_Rejected_n\xa0',
#  'Base_CameraTT_OCR_0_NOK_Rejected_n\xa0',
#  'Base_CameraTT_2Dcheck_NoFeedback_Rejected_n\xa0',
#  'Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'Base_Forming_Base_Backflap_Open_Rejected_n\xa0',
#  'Base_FlapCheck_LowerGlue_Present_0_Rejected_n\xa0',
#  'Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n\xa0',
#  'Base_Forming_Glue_Dry_Bad_Rejected_n\xa0',
#  'Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n\xa0',
#  'Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n\xa0',
#  'Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n\xa0',
#  'Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n\xa0',
#  'Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n\xa0',
#  'Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n\xa0',
#  'Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n\xa0',
#  'Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n\xa0',
#  'Base_Merging_Base_0_NotPresent_Rejected_n\xa0',
#  'Base_Merging_00_CoverNotPresentOnBase_Rejected_n\xa0',
#  'Base_Merging_base_Merging_Deviation_Rejected_n\xa0',
#  'Base_Merging_base_Cover_NotPresent_ Rejected_n\xa0',
#  'Base_Merging_MergingEngage_cover_Notpresent_Rejected_n\xa0',
#  'Base_Merging_MergingInspection_DS_NOK_Rejected_n\xa0',
#  'Base_Merging_MergingInspection_OS_NOK_Rejected_n\xa0',
#  'Base_Merging_BackFlapInspection_0_NOK_Rejected_n\xa0',
#  'Base_Merging_LaserPrinter0Fail_Rejected_n\xa0',
#  'Base_Merging_Merging_External_Check_Rejected_n\xa0',
#  'Base_Merging_Merging_Internal_Check_Rejected_n\xa0',
#  'Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n\xa0',
#  'Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n\xa0',
#  'Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n\xa0',
#  'Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n\xa0',
#  'Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n\xa0',
#  'Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n\xa0',
#  'Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n\xa0',
#  'Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n\xa0',
#  'Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n\xa0',
#  'Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n\xa0',
#  'Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n\xa0',
#  'Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n\xa0',
#  'Upack_BoxCheckweigher_0_Zone_0_Rejected_n\xa0',
#  'Upack_BoxCheckweigher_0_Zone_3_Rejected_n\xa0',
#  'Upack_BoxCheckweigher_0_Zone_4_Rejected_n\xa0',
#  'Upack_BoxCheckweigher_0_Extra_Rejected_n\xa0',
#  'Secondary_FC11_Dataman_Reads_Result_Bad_n\xa0',
#  'Secondary_FC11_Dataman_Reads_Result_Mismatch_n\xa0',
#  'Secondary_FC11_Minibea_Reads_Result_Bad_n\xa0',
#  'Secondary_FC11_Minibea_Reads_Result_Mismatch_n\xa0',
#  'Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n\xa0',
#  'Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n\xa0',
#  'Upack_OLCP_1DCheck_0_NOKRejected_n\xa0',
#  'Upack_CaseCheckweigher_Reject_Case_Weight_Real\xa0',
#  'Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n\xa0',
#  'Palletizer_Pack_Counter_n\xa0']

# %%
reject_tags = [tag.replace(u'\xa0','') for tag in reject_tags]
reject_tags
# Out:
# ['Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n',
#  'Cover_TransportBelt_CheckExternal_0_0_Rejected_n',
#  'Cover_TransportBelt_CheckInternal_0_0_Rejected_n',
#  'Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n',
#  'Cover_TransportBelt_HoleFlap_0_Check_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_ Glue_Dry _0_Rejected_n',
#  'Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_Glue_Dry_0_Rejected_n',
#  'Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Base_Machine_RejectedBases_Total_NOT_Extracted_Betw_Holders_n',
#  'Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n',
#  'Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n',
#  'Base_CameraTT_2Dcheck_0_NotRead_Rejected_n',
#  'Base_CameraTT_OCR_0_NOK_Rejected_n',
#  'Base_CameraTT_2Dcheck_NoFeedback_Rejected_n',
#  'Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_Forming_Base_Backflap_Open_Rejected_n',
#  'Base_FlapCheck_LowerGlue_Present_0_Rejected_n',
#  'Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n',
#  'Base_Forming_Glue_Dry_Bad_Rejected_n',
#  'Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n',
#  'Base_Merging_Base_0_NotPresent_Rejected_n',
#  'Base_Merging_00_CoverNotPresentOnBase_Rejected_n',
#  'Base_Merging_base_Merging_Deviation_Rejected_n',
#  'Base_Merging_base_Cover_NotPresent_ Rejected_n',
#  'Base_Merging_MergingEngage_cover_Notpresent_Rejected_n',
#  'Base_Merging_MergingInspection_DS_NOK_Rejected_n',
#  'Base_Merging_MergingInspection_OS_NOK_Rejected_n',
#  'Base_Merging_BackFlapInspection_0_NOK_Rejected_n',
#  'Base_Merging_LaserPrinter0Fail_Rejected_n',
#  'Base_Merging_Merging_External_Check_Rejected_n',
#  'Base_Merging_Merging_Internal_Check_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n',
#  'Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_0_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_3_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_4_Rejected_n',
#  'Upack_BoxCheckweigher_0_Extra_Rejected_n',
#  'Secondary_FC11_Dataman_Reads_Result_Bad_n',
#  'Secondary_FC11_Dataman_Reads_Result_Mismatch_n',
#  'Secondary_FC11_Minibea_Reads_Result_Bad_n',
#  'Secondary_FC11_Minibea_Reads_Result_Mismatch_n',
#  'Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n',
#  'Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n',
#  'Upack_OLCP_1DCheck_0_NOKRejected_n',
#  'Upack_CaseCheckweigher_Reject_Case_Weight_Real',
#  'Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n',
#  'Palletizer_Pack_Counter_n']

# %%
tags_to_extract=get_tags_list(lines=site_lines,sensors=reject_tags,sep='_', topic=site_servers['historian']['proficy']['topic'])
tags_to_extract=[t for t in tags_to_extract if 'CaseCheckweigher_Reject_Case_Weight_Real' not in t]
tags_to_extract
# Out:
# ['URL-PACK.L13_Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n',
#  'URL-PACK.L13_Cover_TransportBelt_CheckExternal_0_0_Rejected_n',
#  'URL-PACK.L13_Cover_TransportBelt_CheckInternal_0_0_Rejected_n',
#  'URL-PACK.L13_Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n',
#  'URL-PACK.L13_Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n',
#  'URL-PACK.L13_Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n',
#  'URL-PACK.L13_Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n',
#  'URL-PACK.L13_Cover_TransportBelt_HoleFlap_0_Check_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_ Glue_Dry _0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_Glue_Dry_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n',
#  'URL-PACK.L13_Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n',
#  'URL-PACK.L13_Base_Machine_RejectedBases_Total_NOT_Extracted_Betw_Holders_n',
#  'URL-PACK.L13_Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n',
#  'URL-PACK.L13_Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n',
#  'URL-PACK.L13_Base_CameraTT_2Dcheck_0_NotRead_Rejected_n',
#  'URL-PACK.L13_Base_CameraTT_OCR_0_NOK_Rejected_n',
#  'URL-PACK.L13_Base_CameraTT_2Dcheck_NoFeedback_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'URL-PACK.L13_Base_Forming_Base_Backflap_Open_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_LowerGlue_Present_0_Rejected_n',
#  'URL-PACK.L13_Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n',
#  'URL-PACK.L13_Base_Forming_Glue_Dry_Bad_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n',
#  'URL-PACK.L13_Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n',
#  'URL-PACK.L13_Base_Merging_Base_0_NotPresent_Rejected_n',
#  'URL-PACK.L13_Base_Merging_00_CoverNotPresentOnBase_Rejected_n',
#  'URL-PACK.L13_Base_Merging_base_Merging_Deviation_Rejected_n',
#  'URL-PACK.L13_Base_Merging_base_Cover_NotPresent_ Rejected_n',
#  'URL-PACK.L13_Base_Merging_MergingEngage_cover_Notpresent_Rejected_n',
#  'URL-PACK.L13_Base_Merging_MergingInspection_DS_NOK_Rejected_n',
#  'URL-PACK.L13_Base_Merging_MergingInspection_OS_NOK_Rejected_n',
#  'URL-PACK.L13_Base_Merging_BackFlapInspection_0_NOK_Rejected_n',
#  'URL-PACK.L13_Base_Merging_LaserPrinter0Fail_Rejected_n',
#  'URL-PACK.L13_Base_Merging_Merging_External_Check_Rejected_n',
#  'URL-PACK.L13_Base_Merging_Merging_Internal_Check_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n',
#  'URL-PACK.L13_Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_0_Rejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_3_Rejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Zone_4_Rejected_n',
#  'URL-PACK.L13_Upack_BoxCheckweigher_0_Extra_Rejected_n',
#  'URL-PACK.L13_Secondary_FC11_Dataman_Reads_Result_Bad_n',
#  'URL-PACK.L13_Secondary_FC11_Dataman_Reads_Result_Mismatch_n',
#  'URL-PACK.L13_Secondary_FC11_Minibea_Reads_Result_Bad_n',
#  'URL-PACK.L13_Secondary_FC11_Minibea_Reads_Result_Mismatch_n',
#  'URL-PACK.L13_Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n',
#  'URL-PACK.L13_Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n',
#  'URL-PACK.L13_Upack_OLCP_1DCheck_0_NOKRejected_n',
#  'URL-PACK.L13_Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n',
#  'URL-PACK.L13_Palletizer_Pack_Counter_n']

# %% [markdown]
# ### extracting 3 weeks data

# %%
start_dttm = datetime.now() - timedelta(days=21)
#start_dttm = start_dttm - timedelta(days=site_days_to_retake)
start_time = start_dttm
end_time = datetime.now()
print(f'Extracting data between: {start_time} and {end_time}')
# Out:
# Extracting data between: 2022-05-18 14:12:56.630402 and 2022-06-08 14:12:56.630402

# %%
reject_historian_extract_df = historian.get_tag_values(
                    site_servers['historian']['proficy']['server_name'],
                    start_time=start_time,
                    end_time=end_time,
                    filter_name=tags_to_extract)
print(f'Shape of data extract: {reject_historian_extract_df.shape}')
# Out:
# Shape of data extract: (310174, 2)

# %%
# process historian extract 
box_rejects_df = transform_counters_extract(reject_historian_extract_df, site_name=site_name, local_tz=site_tz)
box_rejects_df
# Out:
# TRANSFORM: Shape of original paking rejects data: (310174, 3)
# TRANSFORM: Step 1 - Removing cases where the counter values were not logged (NaNs) or negative
# TRANSFORM: # removed records 0
# TRANSFORM: Shape after step: (310174, 3)
# TRANSFORM: Step 2 - Removing cases, where counter has dropped down in between two resets (historian outage issue)
# TRANSFORM: # removed records 0
# TRANSFORM: Shape after step: (310174, 4)
# TRANSFORM: Step 3 - Removing cases where the counter was not changing
# TRANSFORM: # removed records 0
# TRANSFORM: Shape after step: (310174, 5)
# TRANSFORM: Step 4 - Removing cases where the counter reports zero
# TRANSFORM: # removed records 267575
# TRANSFORM: Shape after step: (42599, 5)
# TRANSFORM: Shape after addition of columns: (42599, 6)
#                       DateTime  Value  rejects_qty line  \
# 219846 2022-05-19 08:47:58.484      1          1.0  L13
# 219845 2022-05-19 08:48:05.484      2          1.0  L13
# 219843 2022-05-19 09:56:09.397      1          1.0  L13
# 219842 2022-05-19 09:56:24.397      2          1.0  L13
# 219841 2022-05-19 10:17:46.437      4          2.0  L13
# ...                        ...    ...          ...  ...
# 277570 2022-06-02 20:50:42.418      8          1.0  L13
# 277568 2022-06-03 07:26:31.714      1          1.0  L13
# 277567 2022-06-03 07:27:34.717      2          1.0  L13
# 277566 2022-06-03 08:17:32.821      3          1.0  L13
# 277564 2022-06-03 12:37:22.366      1          1.0  L13
#
#                                                   tag    site
# 219846  Checkweigher_Base _2Dcheck_TimeOut_Rejected_n  Urlati
# 219845  Checkweigher_Base _2Dcheck_TimeOut_Rejected_n  Urlati
# 219843  Checkweigher_Base _2Dcheck_TimeOut_Rejected_n  Urlati
# 219842  Checkweigher_Base _2Dcheck_TimeOut_Rejected_n  Urlati
# 219841  Checkweigher_Base _2Dcheck_TimeOut_Rejected_n  Urlati
# ...                                               ...     ...
# 277570                   OLCP_1DCheck_0_NOKRejected_n  Urlati
# 277568                   OLCP_1DCheck_0_NOKRejected_n  Urlati
# 277567                   OLCP_1DCheck_0_NOKRejected_n  Urlati
# 277566                   OLCP_1DCheck_0_NOKRejected_n  Urlati
# 277564                   OLCP_1DCheck_0_NOKRejected_n  Urlati
#
# [42599 rows x 6 columns]

# %% [markdown]
# ### getting line recipe tag info

# %%
line_recipe_tags_to_extract = [t for t in all_tag_list if '_'.join(t.split('_')[1:]) in site_historian_tags['tags_index']]
line_recipe_tags_to_extract
# Out:
# ['URL-PACK.L13_Upack_LineRecipe']

# %%
historian_line_recipe_extract_df = historian.get_tag_values(
                    site_servers['historian']['proficy']['server_name'],
                    start_time=start_time - timedelta(days=1),
                    end_time=end_time,
                    filter_name=list(line_recipe_tags_to_extract))
print(f'Shape of data extract: {historian_line_recipe_extract_df.shape}')
# Out:
# Shape of data extract: (215, 2)

# %%
historian_line_recipe_extract_df
# Out:
#                                                                Value  Quality
# Tag                           Timestamp
# URL-PACK.L13_Upack_LineRecipe 2022-06-03 10:30:13.391000+00:00    52        3
#                               2022-06-02 06:29:29.883000+00:00    13        3
#                               2022-05-31 09:56:36.214000+00:00    52        3
#                               2022-05-30 10:14:33.234000+00:00    42        3
#                               2022-05-30 05:48:13+00:00            0        0
# ...                                                              ...      ...
#                               2022-05-23 05:20:42.445000+00:00     0        0
#                               2022-05-23 05:19:42.661000+00:00     0        0
#                               2022-05-23 05:19:34.441000+00:00     0        0
#                               2022-05-23 05:18:34.656000+00:00     0        0
#                               2022-05-23 05:18:26.436000+00:00     0        0
#
# [215 rows x 2 columns]

# %%
line_recipe_status_df = put_to_wonderware_format(historian_line_recipe_extract_df, inplace=False)
line_recipe_status_df = line_recipe_status_df.assign(DateTime = line_recipe_status_df['DateTime'].dt.tz_convert(site_tz).dt.tz_localize(None))
line_recipe_status_df = add_site_line_tag(line_recipe_status_df, site=site_name)
line_recipe_status_df
# Out:
# TRANSFORM: Shape after addition of columns: (215, 5)
#                    DateTime Value line         tag    site
# 214 2022-05-23 07:18:26.436     0  L13  LineRecipe  Urlati
# 213 2022-05-23 07:18:34.656     0  L13  LineRecipe  Urlati
# 212 2022-05-23 07:19:34.441     0  L13  LineRecipe  Urlati
# 211 2022-05-23 07:19:42.661     0  L13  LineRecipe  Urlati
# 210 2022-05-23 07:20:42.445     0  L13  LineRecipe  Urlati
# ..                      ...   ...  ...         ...     ...
# 4   2022-05-30 07:48:13.000     0  L13  LineRecipe  Urlati
# 3   2022-05-30 12:14:33.234    42  L13  LineRecipe  Urlati
# 2   2022-05-31 11:56:36.214    52  L13  LineRecipe  Urlati
# 1   2022-06-02 08:29:29.883    13  L13  LineRecipe  Urlati
# 0   2022-06-03 12:30:13.391    52  L13  LineRecipe  Urlati
#
# [215 rows x 5 columns]

# %% [markdown]
# ### map transformed reject data to line recipe

# %%
## add line recipe
box_rejects_df = add_dim_key_time(fact_df=box_rejects_df, 
                                            dim_df=line_recipe_status_df.rename(columns={'Value':'Line_recipe'}), 
                                            dim_id='Line_recipe', fact_dttm='DateTime', dim_dttm='DateTime', 
                                            group_by=['site', 'line'])
box_rejects_df
# Out:
#                      DateTime   Value  rejects_qty line  \
# 17396 2022-05-18 16:12:59.412  3197.0       3197.0  L13
# 17397 2022-05-18 16:13:03.413  3198.0          1.0  L13
# 17398 2022-05-18 16:13:05.413  3200.0          2.0  L13
# 17399 2022-05-18 16:13:10.414  3202.0          2.0  L13
# 17400 2022-05-18 16:13:12.414  3204.0          2.0  L13
# ...                       ...     ...          ...  ...
# 41574 2022-06-06 07:00:16.739     5.0          2.0  L13
# 41989 2022-06-06 09:37:19.093     2.0          2.0  L13
# 42011 2022-06-06 09:37:19.093     3.0          3.0  L13
# 42374 2022-06-06 09:37:19.093    81.0         81.0  L13
# 42391 2022-06-06 09:37:19.093     1.0          1.0  L13
#
#                                        tag    site Line_recipe
# 17396                       Pack_Counter_n  Urlati         NaN
# 17397                       Pack_Counter_n  Urlati         NaN
# 17398                       Pack_Counter_n  Urlati         NaN
# 17399                       Pack_Counter_n  Urlati         NaN
# 17400                       Pack_Counter_n  Urlati         NaN
# ...                                    ...     ...         ...
# 41574      FC11_Dataman_Reads_Result_Bad_n  Urlati          52
# 41989   BoxCheckweigher_0_Extra_Rejected_n  Urlati          52
# 42011  BoxCheckweigher_0_Zone_0_Rejected_n  Urlati          52
# 42374  BoxCheckweigher_0_Zone_3_Rejected_n  Urlati          52
# 42391  BoxCheckweigher_0_Zone_4_Rejected_n  Urlati          52
#
# [42599 rows x 7 columns]

# %% [markdown]
# ### extract agile flag and project flag

# %%
agile_tags = [t for t in reject_tags if t in site_historian_tags['tags_agile']]

# %%
#site_agile_tags = get_tags_list(lines=site_lines_agile, sensors=agile_tags, sep='_', 
                                                #topic=site_servers['historian']['proficy']['topic'])

# %%
#print(f'Extracting data between: {start_time} and {end_time}')
#agile_extract_df = historian.get_tag_values(site_servers['historian']['proficy']['server_name'], 
#                                                                        start_time=start_time - timedelta(days=1),
#                                                                        end_time=end_time,
#                                                                        filter_name=site_agile_tags)
#logging.info(f'Shape of agile flag extract: {agile_extract_df.shape}')

# %%
# assign agile flaf and project flag = 0
box_rejects_df = box_rejects_df.assign(agile_flag = 0, project_flag = 0)
box_rejects_df
# Out:
#                      DateTime   Value  rejects_qty line  \
# 17396 2022-05-18 16:12:59.412  3197.0       3197.0  L13
# 17397 2022-05-18 16:13:03.413  3198.0          1.0  L13
# 17398 2022-05-18 16:13:05.413  3200.0          2.0  L13
# 17399 2022-05-18 16:13:10.414  3202.0          2.0  L13
# 17400 2022-05-18 16:13:12.414  3204.0          2.0  L13
# ...                       ...     ...          ...  ...
# 41574 2022-06-06 07:00:16.739     5.0          2.0  L13
# 41989 2022-06-06 09:37:19.093     2.0          2.0  L13
# 42011 2022-06-06 09:37:19.093     3.0          3.0  L13
# 42374 2022-06-06 09:37:19.093    81.0         81.0  L13
# 42391 2022-06-06 09:37:19.093     1.0          1.0  L13
#
#                                        tag    site Line_recipe  agile_flag  \
# 17396                       Pack_Counter_n  Urlati         NaN           0
# 17397                       Pack_Counter_n  Urlati         NaN           0
# 17398                       Pack_Counter_n  Urlati         NaN           0
# 17399                       Pack_Counter_n  Urlati         NaN           0
# 17400                       Pack_Counter_n  Urlati         NaN           0
# ...                                    ...     ...         ...         ...
# 41574      FC11_Dataman_Reads_Result_Bad_n  Urlati          52           0
# 41989   BoxCheckweigher_0_Extra_Rejected_n  Urlati          52           0
# 42011  BoxCheckweigher_0_Zone_0_Rejected_n  Urlati          52           0
# 42374  BoxCheckweigher_0_Zone_3_Rejected_n  Urlati          52           0
# 42391  BoxCheckweigher_0_Zone_4_Rejected_n  Urlati          52           0
#
#        project_flag
# 17396             0
# 17397             0
# 17398             0
# 17399             0
# 17400             0
# ...             ...
# 41574             0
# 41989             0
# 42011             0
# 42374             0
# 42391             0
#
# [42599 rows x 9 columns]

# %% [markdown]
# ### aggregating data

# %%
## aggregating
box_rejects_df = box_rejects_df.assign(DateTimeMin = box_rejects_df['DateTime'].dt.floor(rejects_agg_freq))

groupby_cols = ['site', 'line', 'DateTimeMin', 'tag', 
                              'agile_flag', 'project_flag', 'Line_recipe']
agg_dict = {'rejects_qty':'sum', 'DateTime':'min'}

box_rejects_agg_df = box_rejects_df.groupby(groupby_cols).agg(agg_dict).reset_index()
box_rejects_agg_df
# Out:
#         site line         DateTimeMin  \
# 0     Urlati  L13 2022-05-23 07:30:00
# 1     Urlati  L13 2022-05-23 07:30:00
# 2     Urlati  L13 2022-05-23 07:30:00
# 3     Urlati  L13 2022-05-23 07:30:00
# 4     Urlati  L13 2022-05-23 07:30:00
# ...      ...  ...                 ...
# 1771  Urlati  L13 2022-06-06 07:00:00
# 1772  Urlati  L13 2022-06-06 09:30:00
# 1773  Urlati  L13 2022-06-06 09:30:00
# 1774  Urlati  L13 2022-06-06 09:30:00
# 1775  Urlati  L13 2022-06-06 09:30:00
#
#                                                     tag  agile_flag  \
# 0      Extraction_Turret_CartonsNotExtracted_0_Actual_n           0
# 1           Former1_ExternalGlueCamera_Bad_0_Rejected_n           0
# 2           Former1_InternalGlueCamera_Bad_0_Rejected_n           0
# 3     Former1_InternalGlueCamera_NoFeedback_0_Reject...           0
# 4            Former1_RobotHead4_FlapCheck2_0_Rejected_n           0
# ...                                                 ...         ...
# 1771                    FC11_Dataman_Reads_Result_Bad_n           0
# 1772                 BoxCheckweigher_0_Extra_Rejected_n           0
# 1773                BoxCheckweigher_0_Zone_0_Rejected_n           0
# 1774                BoxCheckweigher_0_Zone_3_Rejected_n           0
# 1775                BoxCheckweigher_0_Zone_4_Rejected_n           0
#
#       project_flag Line_recipe  rejects_qty                DateTime
# 0                0           0         18.0 2022-05-23 07:51:15.641
# 1                0           0          2.0 2022-05-23 07:51:15.641
# 2                0           0          1.0 2022-05-23 07:51:15.641
# 3                0           0          1.0 2022-05-23 07:51:15.641
# 4                0           0          1.0 2022-05-23 07:51:15.641
# ...            ...         ...          ...                     ...
# 1771             0          52          3.0 2022-06-06 07:00:15.739
# 1772             0          52          2.0 2022-06-06 09:37:19.093
# 1773             0          52          3.0 2022-06-06 09:37:19.093
# 1774             0          52         81.0 2022-06-06 09:37:19.093
# 1775             0          52          1.0 2022-06-06 09:37:19.093
#
# [1776 rows x 9 columns]

# %%
rename_dict = {'DateTimeMin':'datetime', 'tag':'reject cause', 
                               'Line_recipe':'line_recipe', 'DateTime':'start_time', 
                               'agile_flag':'agile_flag', 'project_flag':'project_flag'}

box_rejects_agg_df = box_rejects_agg_df.rename(columns = rename_dict)
box_rejects_agg_df
# Out:
#         site line            datetime  \
# 0     Urlati  L13 2022-05-23 07:30:00
# 1     Urlati  L13 2022-05-23 07:30:00
# 2     Urlati  L13 2022-05-23 07:30:00
# 3     Urlati  L13 2022-05-23 07:30:00
# 4     Urlati  L13 2022-05-23 07:30:00
# ...      ...  ...                 ...
# 1771  Urlati  L13 2022-06-06 07:00:00
# 1772  Urlati  L13 2022-06-06 09:30:00
# 1773  Urlati  L13 2022-06-06 09:30:00
# 1774  Urlati  L13 2022-06-06 09:30:00
# 1775  Urlati  L13 2022-06-06 09:30:00
#
#                                            reject cause  agile_flag  \
# 0      Extraction_Turret_CartonsNotExtracted_0_Actual_n           0
# 1           Former1_ExternalGlueCamera_Bad_0_Rejected_n           0
# 2           Former1_InternalGlueCamera_Bad_0_Rejected_n           0
# 3     Former1_InternalGlueCamera_NoFeedback_0_Reject...           0
# 4            Former1_RobotHead4_FlapCheck2_0_Rejected_n           0
# ...                                                 ...         ...
# 1771                    FC11_Dataman_Reads_Result_Bad_n           0
# 1772                 BoxCheckweigher_0_Extra_Rejected_n           0
# 1773                BoxCheckweigher_0_Zone_0_Rejected_n           0
# 1774                BoxCheckweigher_0_Zone_3_Rejected_n           0
# 1775                BoxCheckweigher_0_Zone_4_Rejected_n           0
#
#       project_flag line_recipe  rejects_qty              start_time
# 0                0           0         18.0 2022-05-23 07:51:15.641
# 1                0           0          2.0 2022-05-23 07:51:15.641
# 2                0           0          1.0 2022-05-23 07:51:15.641
# 3                0           0          1.0 2022-05-23 07:51:15.641
# 4                0           0          1.0 2022-05-23 07:51:15.641
# ...            ...         ...          ...                     ...
# 1771             0          52          3.0 2022-06-06 07:00:15.739
# 1772             0          52          2.0 2022-06-06 09:37:19.093
# 1773             0          52          3.0 2022-06-06 09:37:19.093
# 1774             0          52         81.0 2022-06-06 09:37:19.093
# 1775             0          52          1.0 2022-06-06 09:37:19.093
#
# [1776 rows x 9 columns]

# %%
box_rejects_agg_df.to_csv('..\data\initial loading\SUD_BOX_REJECT.csv')
