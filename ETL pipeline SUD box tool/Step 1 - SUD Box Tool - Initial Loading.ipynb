# %% [markdown]
# # SUD Box tool: Initial Data Loading

# %% [markdown]
# ## Goals:
# 1. Build the initial data model for the tool:
#     * Define key tables from the model and links between them
# 2. Perform the initial data load into the tables
# 3. Identify data-related issues and ways to address them

# %% [markdown]
# ### TODO
#
# 1.

# %% [markdown]
# ### Questions
# 1.

# %% [markdown]
# ## Setup

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import pyodbc as pyodbc

import logging
import queries

import sys
import os
import logging
import sys
import argparse
import pytz
from os.path import join, split 

from datetime import datetime, timedelta
from tomlkit import parse, dumps, loads
from typing import List, Tuple

import historian
from os import getcwd

from sud_tools import *
from sud_utils import *
from tool_utils import *

# %% [markdown]
# ### Reading in the configuration file

# %%
cfg_file_nm = 'etl_config.toml'
cfg_file_path = join(os.getcwd(), cfg_file_nm)
# checking if config file exists
if not os.path.isfile(cfg_file_path):
    raise ValueError(f'No config file was found at: {cfg_file_path}')
else:
    # reading in the config file
    cfg = loads(open(cfg_file_path).read())

# %%
tags_list_path = cfg['job']['path_to_tag_list']
print(f'Path to tag list table: {tags_list_path}')
# Out:
# ---------------------------------------------------------------------------
# NonExistentKey                            Traceback (most recent call last)
# <ipython-input-3-9ac01d283540> in <module>
# ----> 1 tags_list_path = cfg['job']['path_to_tag_list']
#       2 print(f'Path to tag list table: {tags_list_path}')
#
# ~\.conda\envs\sud_dev\lib\site-packages\tomlkit\items.py in __getitem__(self, key)
#    1016
#    1017     def __getitem__(self, key):  # type: (Union[Key, str]) -> Item
# -> 1018         return self._value[key]
#    1019
#    1020     def __setitem__(self, key, value):  # type: (Union[Key, str], Any) -> None
#
# ~\.conda\envs\sud_dev\lib\site-packages\tomlkit\container.py in __getitem__(self, key)
#     574         idx = self._map.get(key, None)
#     575         if idx is None:
# --> 576             raise NonExistentKey(key)
#     577
#     578         if isinstance(idx, tuple):
#
# NonExistentKey: 'Key "path_to_tag_list" does not exist.'

# %% [markdown]
# ### Setting up the connection to DatalabDB

# %%
# datalab integration
datalab_cfg = cfg['datalab_db'].copy()

# setting up run configuration with parameters from cfg file
datalab_db_conn = get_mssql_conn_string(**datalab_cfg['connection'])
datalab_db_access_url = r"{}".format(datalab_cfg['access_token_url']['access_token_url'])
datalab_db_access_token = get_azure_sql_db_access_token(datalab_db_access_url)
print(f'Datalab connection parameters: {datalab_db_conn}')

# %% [markdown]
# ## Designing data model
#
# >**FACT TABLES**
#
# **SUD_BOX_REJECT** - Fact table containning reject quatities for evary reject cause
# 1. site_id
# 2. line_id
# 3. datetime - 30 min granularity
# 4. line_recipe
# 5. line_state_id
# 6. agile_flag
# 7. project_flag
# 8. reject_cause_id
# 9. reject_qty
#
# **SUD_BOX_TOTALS** - Fact table containnig # boxes produced/extracted
# 1. site_id
# 2. line_id
# 3. datetime - 30 min granularity
# 4. recipe_id
# 5. line_state_id
# 6. agile_flag
# 7. project_flag
# 8. good_covers_qty (coming from "produced" tags)
# 9. good_bases_qty (coming from "produced" tags)
# 10. produced_covers_qty (coming from "extracted" tags)
# 11. produced_bases_qty (coming from "extracted" tags)
# <!-- 10. rejected_boxes_qty -->
#
# > **DIMENTION TABLES**
#
# 1. **SUD_SITES** - we have it in DATLAB_DB
# 2. **SUD_LINES** - we have it in DATLAB_DB
# 3. **SUD_LINE_STATE** - we have it in DATLAB_DB
# 4. **LINE_RECIPE_DIM** - line recipe dimention table. Extracted from sharepoint from Power BI. We need to emulate it for now, based on the table from the URD.
#     * line_recipe - value coming from the line recipe tag
#     * product_segment
#     * recipe_size_nm
#     * recipe_cd
#     * n_boxes_per_case
#     * n_cases_end_of_line
# 5. **BOX_SIZE_DIM** - box size dimention table. Going to be created in Power BI
#     * size_cd
#     * size_nm
#     * n_boxes_per_case
# 6. **REJECT_CAUSE_DIM** - we going to need to emulate this, by taking the data from the table in URD and creating csv/xlsx
#     * id
#     * tag_nm - is the name of the tag without LXXX_ part
#     * cause
#     * reason
#     * station
#     * type

# %% [markdown]
# ## Preparing LINE_RECIPIE_DIM

# %%
line_recipe_path = cfg['job']['path_to_line_recipe']
print(f'Path to line recipe table: {line_recipe_path}')

# cheking if the line recipe path exist
if not os.path.exists(line_recipe_path):
    print(f'INFO: Didn not find line recipe at {line_recipe_path}.')
    raise ValueError('Was not able to file tags list. Aborting...')
else:
    line_recipe_df = pd.read_excel(line_recipe_path)
    print(f'Shape of the line recipe table: {line_recipe_df.shape}')
# Out:
# Path to line recipe table: F:\Ecosystem Non-OneDrive\Development Area\MVP048 SUD Box tool\Data\Input\line_recipe.xlsx
# Shape of the line recipe table: (20, 6)

# %%
line_recipe_df.columns
# Out:
# Index(['line_recipe_id', 'product_segment', 'recipe_size_nm', 'recipe_cd',
#        'n_boxes_per_case', 'n_cases_end_of_line'],
#       dtype='object')

# %%
line_recipe_df = line_recipe_df.assign(line_recipe_id = line_recipe_df['line_recipe_id'].str.replace('\xa0',''),
                                        product_segment = line_recipe_df['product_segment'].str.replace('\xa0',''),
                                         recipe_size_nm = line_recipe_df['recipe_size_nm'].str.replace('\xa0',''),
                                         recipe_cd = line_recipe_df['recipe_cd'].str.replace('\xa0',''),
                                         n_boxes_per_case = line_recipe_df['n_boxes_per_case'].str.replace('\xa0',''),
                                         n_cases_end_of_line = line_recipe_df['n_cases_end_of_line'].str.replace('\xa0','')
                                        
                                        )
line_recipe_df
# Out:
#    line_recipe_id        product_segment recipe_size_nm recipe_cd  \
# 0               1  S100_CTray_4CC_Shrink           S100        S1
# 1               5         S100_Ttray_4CC           S100        S1
# 2               6         S100_Utray_8cc           S100        S1
# 3               7    S100_4CC_ShrinkOnly           S100        S1
# 4              11  S115_CTray_4CC_Shrink           S115        S2
# 5              13         S115_Ttray_4CC           S115        S2
# 6              14         S115_Utray_8cc           S115        S2
# 7              15    S115_4CC_ShrinkOnly           S115        S2
# 8              21  M115_CTray_4CC_Shrink           M115        M1
# 9              22         M115_Ttray_4CC           M115        M1
# 10             25    M115_4CC_ShrinkOnly           M115        M1
# 11             31  M135_CTray_4CC_Shrink           M135        M2
# 12             32         M135_Ttray_4CC           M135        M2
# 13             37    M135_4CC_ShrinkOnly           M135        M2
# 14             41  L115_CTray_4CC_Shrink           L115        L0
# 15             42         L115_Ttray_4CC           L115        L0
# 16             47    L115_4CC_ShrinkOnly           L115        L0
# 17             51  L135_CTray_4CC_Shrink           L135        L1
# 18             53         L135_Ttray_4CC           L135        L1
# 19             57    L135_4CC_ShrinkOnly           L135        L1
#
#    n_boxes_per_case n_cases_end_of_line
# 0                 4                 160
# 1                 4                 128
# 2                 8                 NaN
# 3                 4                 160
# 4                 4                 128
# 5                 4                 112
# 6                 8                 NaN
# 7                 4                 128
# 8                 4                 NaN
# 9                 4                  84
# 10                4                 NaN
# 11                4                  84
# 12                4                 NaN
# 13                4                  84
# 14                4                  72
# 15                4                  63
# 16                4                  72
# 17                4                  63
# 18                4                  54
# 19                4                  63

# %%
line_recipe_df = line_recipe_df.assign(line_recipe_id =(pd.to_numeric(line_recipe_df['line_recipe_id'])))
line_recipe_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   line_recipe_id       20 non-null     int64
#  1   product_segment      20 non-null     object
#  2   recipe_size_nm       20 non-null     object
#  3   recipe_cd            20 non-null     object
#  4   n_boxes_per_case     20 non-null     object
#  5   n_cases_end_of_line  15 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.1+ KB

# %%
line_recipe_df = line_recipe_df.assign(n_boxes_per_case =(pd.to_numeric(line_recipe_df['n_boxes_per_case'])))
line_recipe_df = line_recipe_df.assign(n_cases_end_of_line =(pd.to_numeric(line_recipe_df['n_cases_end_of_line'])))
line_recipe_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   line_recipe_id       20 non-null     int64
#  1   product_segment      20 non-null     object
#  2   recipe_size_nm       20 non-null     object
#  3   recipe_cd            20 non-null     object
#  4   n_boxes_per_case     20 non-null     int64
#  5   n_cases_end_of_line  15 non-null     float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 1.1+ KB

# %%
line_recipe_df.to_excel('..\Data\initial loading\LINE_RECIPE_DIM.xlsx', index=False)

# %% [markdown]
# ## prepaing REJECT_CAUSE_DIM

# %%
reject_cause_path = cfg['job']['path_to_reject_cause']
print(f'Path to reject cause table: {reject_cause_path}')

# cheking if the reject cause path exist
if not os.path.exists(reject_cause_path):
    print(f'INFO: Didn not find reject cause table at {reject_cause_path}.')
    raise ValueError('Was not able to find reject cause table. Aborting...')
else:
    reject_cause_df = pd.read_excel(reject_cause_path)
    print(f'Shape of the line recipe table: {reject_cause_df.shape}')
# Out:
# Path to reject cause table: F:\Ecosystem Non-OneDrive\Development Area\MVP048 SUD Box tool\Data\Input\reject_cause.xlsx
# Shape of the line recipe table: (96, 7)

# %%
reject_cause_df.head()
# Out:
#    id                                             tag_nm   type  \
# 0  1   LXXX_Cover_Extraction_Turret_CartonsNotExtract...  Cover
# 1  2   LXXX_Cover_TransportBelt_CheckExternal_0_0_Rej...  Cover
# 2  3   LXXX_Cover_TransportBelt_CheckInternal_0_0_Rej...  Cover
# 3  4   LXXX_Cover_TransportBelt_RobotTrack_Skipped_0_...  Cover
# 4  5   LXXX_Cover_Forming_PatchErectionCheck_Bad_Coun...  Cover
#
#          machine         station          reason  \
# 0  Cover machine  Transport Belt   Not extracted
# 1  Cover machine  Transport Belt  Transport belt
# 2  Cover machine  Transport Belt  Transport belt
# 3  Cover machine  Transport Belt  Transport belt
# 4  Cover machine   Patch Control    Patch reject
#
#                               cause
# 0                     Not extracted
# 1                    Check External
# 2                    Check Internal
# 3                       Robot track
# 4  Patch  Erection Check Bad Height

# %%
reject_cause_df.loc[reject_cause_df['id'] == 1]
# Out:
# Empty DataFrame
# Columns: [id, tag_nm, type, machine, station, reason, cause]
# Index: []

# %%
reject_cause_df.columns
# Out:
# Index(['id', 'tag_nm', 'type', 'machine', 'station', 'reason', 'cause'], dtype='object')

# %%
reject_cause_df.columns = reject_cause_df.columns.str.strip()
reject_cause_df.columns
# Out:
# Index(['id', 'tag_nm', 'type', 'machine', 'station', 'reason', 'cause'], dtype='object')

# %%
reject_cause_df = reject_cause_df.assign(tag_nm=(reject_cause_df['tag_nm'].str.split('_',n=1,expand=True)[1]))
reject_cause_df
# Out:
#        id                                             tag_nm        type  \
# 0      1   Cover_Extraction_Turret_CartonsNotExtracted_0_...       Cover
# 1      2    Cover_TransportBelt_CheckExternal_0_0_Rejected_n       Cover
# 2      3    Cover_TransportBelt_CheckInternal_0_0_Rejected_n       Cover
# 3      4   Cover_TransportBelt_RobotTrack_Skipped_0_Rejec...       Cover
# 4      5   Cover_Forming_PatchErectionCheck_Bad_Counter_R...       Cover
# ..    ...                                                ...         ...
# 91    92   Upack_CaseCheckweigher_Reject_Weight_NOKReject...  Cover+Base
# 92    93                  Upack_OLCP_1DCheck_0_NOKRejected_n  Cover+Base
# 93    94   Upack_CaseCheckweigher_Reject_LeakerCheck_0Rej...  Cover+Base
# 94  95     Base_Machine_Holder_Not_free_iTrak_Exit_Counte...        Base
# 95   96    Cover_Forming_PatchErectionCheck_Bad_on_Empty_...       Cover
#
#           machine            station           reason  \
# 0   Cover machine     Transport Belt    Not extracted
# 1   Cover machine     Transport Belt   Transport belt
# 2   Cover machine     Transport Belt   Transport belt
# 3   Cover machine     Transport Belt   Transport belt
# 4   Cover machine      Patch Control     Patch reject
# ..            ...                ...              ...
# 91        Phase 2  Case CheckWeigher          Minibea
# 92        Phase 2  Case CheckWeigher          Minibea
# 93        Phase 2  Case CheckWeigher          Minibea
# 94   Base machine          Station 1  Holder Not Free
# 95  Cover machine      Patch Control        Run Empty
#
#                                cause
# 0                      Not extracted
# 1                     Check External
# 2                     Check Internal
# 3                        Robot track
# 4   Patch  Erection Check Bad Height
# ..                               ...
# 91                        Weight NOK
# 92                       OLCP 1D NOK
# 93                               NaN
# 94                   Holder Not Free
# 95                         Run Empty
#
# [96 rows x 7 columns]

# %%
reject_cause_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       96 non-null     object
#  1   tag_nm   96 non-null     object
#  2   type     96 non-null     object
#  3   machine  96 non-null     object
#  4   station  96 non-null     object
#  5   reason   94 non-null     object
#  6   cause    95 non-null     object
# dtypes: object(7)
# memory usage: 5.4+ KB

# %%
reject_cause_df['tag_nm']
# Out:
# 0     Cover_Extraction_Turret_CartonsNotExtracted_0_...
# 1      Cover_TransportBelt_CheckExternal_0_0_Rejected_n
# 2      Cover_TransportBelt_CheckInternal_0_0_Rejected_n
# 3     Cover_TransportBelt_RobotTrack_Skipped_0_Rejec...
# 4     Cover_Forming_PatchErectionCheck_Bad_Counter_R...
#                             ...
# 92    Upack_CaseCheckweigher_Reject_Weight_NOKReject...
# 93                   Upack_OLCP_1DCheck_0_NOKRejected_n
# 94    Upack_CaseCheckweigher_Reject_LeakerCheck_0Rej...
# 95    Base_Machine_Holder_Not_free_iTrak_Exit_Counte...
# 96    Cover_Forming_PatchErectionCheck_Bad_on_Empty_...
# Name: tag_nm, Length: 97, dtype: object

# %%
reject_cause_df = reject_cause_df[['id', 'tag_nm','cause','reason','station','type','machine']]
reject_cause_df
# Out:
#        id                                             tag_nm  \
# 0      1   Cover_Extraction_Turret_CartonsNotExtracted_0_...
# 1      2    Cover_TransportBelt_CheckExternal_0_0_Rejected_n
# 2      3    Cover_TransportBelt_CheckInternal_0_0_Rejected_n
# 3      4   Cover_TransportBelt_RobotTrack_Skipped_0_Rejec...
# 4      5   Cover_Forming_PatchErectionCheck_Bad_Counter_R...
# ..    ...                                                ...
# 91    92   Upack_CaseCheckweigher_Reject_Weight_NOKReject...
# 92    93                  Upack_OLCP_1DCheck_0_NOKRejected_n
# 93    94   Upack_CaseCheckweigher_Reject_LeakerCheck_0Rej...
# 94  95     Base_Machine_Holder_Not_free_iTrak_Exit_Counte...
# 95   96    Cover_Forming_PatchErectionCheck_Bad_on_Empty_...
#
#                                cause           reason            station  \
# 0                      Not extracted    Not extracted     Transport Belt
# 1                     Check External   Transport belt     Transport Belt
# 2                     Check Internal   Transport belt     Transport Belt
# 3                        Robot track   Transport belt     Transport Belt
# 4   Patch  Erection Check Bad Height     Patch reject      Patch Control
# ..                               ...              ...                ...
# 91                        Weight NOK          Minibea  Case CheckWeigher
# 92                       OLCP 1D NOK          Minibea  Case CheckWeigher
# 93                               NaN          Minibea  Case CheckWeigher
# 94                   Holder Not Free  Holder Not Free          Station 1
# 95                         Run Empty        Run Empty      Patch Control
#
#           type        machine
# 0        Cover  Cover machine
# 1        Cover  Cover machine
# 2        Cover  Cover machine
# 3        Cover  Cover machine
# 4        Cover  Cover machine
# ..         ...            ...
# 91  Cover+Base        Phase 2
# 92  Cover+Base        Phase 2
# 93  Cover+Base        Phase 2
# 94        Base   Base machine
# 95       Cover  Cover machine
#
# [96 rows x 7 columns]

# %%
len(reject_cause_df['tag_nm'])
# Out:
# 96

# %%
len(reject_cause_df['tag_nm'])
# Out:
# 96

# %%
reject_cause_df['tag_nm'].tolist()
# Out:
# ['Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n',
#  'Cover_TransportBelt_CheckExternal_0_0_Rejected_n',
#  'Cover_TransportBelt_CheckInternal_0_0_Rejected_n',
#  'Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n',
#  'Cover_TransportBelt_HoleFlap_0_Check_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_ Glue_Dry _0_Rejected_n',
#  'Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_Glue_Dry_0_Rejected_n',
#  'Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n',
#  'Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n',
#  'Base_CameraTT_2Dcheck_0_NotRead_Rejected_n',
#  'Base_CameraTT_OCR_0_NOK_Rejected_n',
#  'Base_CameraTT_2Dcheck_NoFeedback_Rejected_n',
#  'Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_Forming_Base_Backflap_Open_Rejected_n',
#  'Base_FlapCheck_LowerGlue_Present_0_Rejected_n',
#  'Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n',
#  'Base_Forming_Glue_Dry_Bad_Rejected_n',
#  'Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n',
#  'Base_Merging_Base_0_NotPresent_Rejected_n',
#  'Base_Merging_00_CoverNotPresentOnBase_Rejected_n',
#  'Base_Merging_base_Merging_Deviation_Rejected_n',
#  'Base_Merging_base_Cover_NotPresent_ Rejected_n',
#  'Base_Merging_MergingEngage_cover_Notpresent_Rejected_n',
#  'Base_Merging_MergingInspection_DS_NOK_Rejected_n',
#  'Base_Merging_MergingInspection_OS_NOK_Rejected_n',
#  'Base_Merging_BackFlapInspection_0_NOK_Rejected_n',
#  'Base_Merging_LaserPrinter0Fail_Rejected_n',
#  'Base_Merging_Merging_External_Check_Rejected_n',
#  'Base_Merging_Merging_Internal_Check_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n',
#  'Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_0_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_3_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_4_Rejected_n',
#  'Upack_BoxCheckweigher_0_Extra_Rejected_n',
#  'Secondary_FC11_Dataman_Reads_Result_Bad_n',
#  'Secondary_FC11_Dataman_Reads_Result_Mismatch_n',
#  'Secondary_FC11_Minibea_Reads_Result_Bad_n',
#  'Secondary_FC11_Minibea_Reads_Result_Mismatch_n',
#  'Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n',
#  'Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n',
#  'Upack_OLCP_1DCheck_0_NOKRejected_n',
#  'Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n',
#  'Base_Machine_Holder_Not_free_iTrak_Exit_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_Bad_on_Empty_Counter_Rejected_n']

# %%
reject_cause_df['tag_nm'].str.replace('\xa0','').tolist()
# Out:
# ['Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n',
#  'Cover_TransportBelt_CheckExternal_0_0_Rejected_n',
#  'Cover_TransportBelt_CheckInternal_0_0_Rejected_n',
#  'Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n',
#  'Cover_TransportBelt_HoleFlap_0_Check_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former1_ Glue_Dry _0_Rejected_n',
#  'Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n',
#  'Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n',
#  'Cover_Former2_Glue_Dry_0_Rejected_n',
#  'Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n',
#  'Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n',
#  'Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n',
#  'Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n',
#  'Base_CameraTT_2Dcheck_0_NotRead_Rejected_n',
#  'Base_CameraTT_OCR_0_NOK_Rejected_n',
#  'Base_CameraTT_2Dcheck_NoFeedback_Rejected_n',
#  'Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n',
#  'Base_Forming_Base_Backflap_Open_Rejected_n',
#  'Base_FlapCheck_LowerGlue_Present_0_Rejected_n',
#  'Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n',
#  'Base_Forming_Glue_Dry_Bad_Rejected_n',
#  'Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n',
#  'Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n',
#  'Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n',
#  'Base_Merging_Base_0_NotPresent_Rejected_n',
#  'Base_Merging_00_CoverNotPresentOnBase_Rejected_n',
#  'Base_Merging_base_Merging_Deviation_Rejected_n',
#  'Base_Merging_base_Cover_NotPresent_ Rejected_n',
#  'Base_Merging_MergingEngage_cover_Notpresent_Rejected_n',
#  'Base_Merging_MergingInspection_DS_NOK_Rejected_n',
#  'Base_Merging_MergingInspection_OS_NOK_Rejected_n',
#  'Base_Merging_BackFlapInspection_0_NOK_Rejected_n',
#  'Base_Merging_LaserPrinter0Fail_Rejected_n',
#  'Base_Merging_Merging_External_Check_Rejected_n',
#  'Base_Merging_Merging_Internal_Check_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n',
#  'Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n',
#  'Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n',
#  'Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_0_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_3_Rejected_n',
#  'Upack_BoxCheckweigher_0_Zone_4_Rejected_n',
#  'Upack_BoxCheckweigher_0_Extra_Rejected_n',
#  'Secondary_FC11_Dataman_Reads_Result_Bad_n',
#  'Secondary_FC11_Dataman_Reads_Result_Mismatch_n',
#  'Secondary_FC11_Minibea_Reads_Result_Bad_n',
#  'Secondary_FC11_Minibea_Reads_Result_Mismatch_n',
#  'Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n',
#  'Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n',
#  'Upack_OLCP_1DCheck_0_NOKRejected_n',
#  'Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n',
#  'Base_Machine_Holder_Not_free_iTrak_Exit_Counter_Rejected_n',
#  'Cover_Forming_PatchErectionCheck_Bad_on_Empty_Counter_Rejected_n']

# %%
reject_cause_df['station'].tolist()
# Out:
# ['Transport Belt',
#  'Transport Belt',
#  'Transport Belt',
#  'Transport Belt',
#  'Patch Control',
#  'Patch Control',
#  'Patch Control',
#  'Transport Belt',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 1',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Former 2',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 1',
#  'Station 2',
#  'Station 2',
#  'Station 2',
#  'Station 2',
#  'Station 2',
#  'Station 2',
#  'Station 2',
#  'Station 2',
#  'Station 2',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Station 3',
#  'Box CheckWeigher',
#  'Box CheckWeigher',
#  'Box CheckWeigher',
#  'Box CheckWeigher',
#  'Case CheckWeigher',
#  'Case CheckWeigher',
#  'Case CheckWeigher',
#  'Case CheckWeigher',
#  'Case CheckWeigher',
#  'Case CheckWeigher',
#  'Case CheckWeigher',
#  'Case CheckWeigher',
#  'Station 1',
#  'Patch Control']

# %%
reject_cause_df = reject_cause_df.assign(tag_nm = reject_cause_df['tag_nm'].str.replace('\xa0',''),
                                        cause = reject_cause_df['cause'].str.replace('\xa0',''),
                                         reason = reject_cause_df['reason'].str.replace('\xa0',''),
                                         station = reject_cause_df['station'].str.replace('\xa0',''),
                                         type = reject_cause_df['type'].str.replace('\xa0',''),
                                         machine = reject_cause_df['machine'].str.replace('\xa0','')
                                        
                                        )
reject_cause_df
# Out:
#        id                                             tag_nm  \
# 0      1   Cover_Extraction_Turret_CartonsNotExtracted_0_...
# 1      2    Cover_TransportBelt_CheckExternal_0_0_Rejected_n
# 2      3    Cover_TransportBelt_CheckInternal_0_0_Rejected_n
# 3      4   Cover_TransportBelt_RobotTrack_Skipped_0_Rejec...
# 4      5   Cover_Forming_PatchErectionCheck_Bad_Counter_R...
# ..    ...                                                ...
# 91    92   Upack_CaseCheckweigher_Reject_Weight_NOKReject...
# 92    93                  Upack_OLCP_1DCheck_0_NOKRejected_n
# 93    94   Upack_CaseCheckweigher_Reject_LeakerCheck_0Rej...
# 94  95     Base_Machine_Holder_Not_free_iTrak_Exit_Counte...
# 95   96    Cover_Forming_PatchErectionCheck_Bad_on_Empty_...
#
#                                cause           reason            station  \
# 0                      Not extracted    Not extracted     Transport Belt
# 1                     Check External   Transport belt     Transport Belt
# 2                     Check Internal   Transport belt     Transport Belt
# 3                        Robot track   Transport belt     Transport Belt
# 4   Patch  Erection Check Bad Height     Patch reject      Patch Control
# ..                               ...              ...                ...
# 91                        Weight NOK          Minibea  Case CheckWeigher
# 92                       OLCP 1D NOK          Minibea  Case CheckWeigher
# 93                               NaN          Minibea  Case CheckWeigher
# 94                   Holder Not Free  Holder Not Free          Station 1
# 95                         Run Empty        Run Empty      Patch Control
#
#           type        machine
# 0        Cover  Cover machine
# 1        Cover  Cover machine
# 2        Cover  Cover machine
# 3        Cover  Cover machine
# 4        Cover  Cover machine
# ..         ...            ...
# 91  Cover+Base        Phase 2
# 92  Cover+Base        Phase 2
# 93  Cover+Base        Phase 2
# 94        Base   Base machine
# 95       Cover  Cover machine
#
# [96 rows x 7 columns]

# %%
reject_cause_df = reject_cause_df.assign(id = reject_cause_df['id'].str.replace('\xa0',''))
reject_cause_df
# Out:
#       id                                             tag_nm  \
# 0      1  Cover_Extraction_Turret_CartonsNotExtracted_0_...
# 1      2   Cover_TransportBelt_CheckExternal_0_0_Rejected_n
# 2      3   Cover_TransportBelt_CheckInternal_0_0_Rejected_n
# 3      4  Cover_TransportBelt_RobotTrack_Skipped_0_Rejec...
# 4      5  Cover_Forming_PatchErectionCheck_Bad_Counter_R...
# ..   ...                                                ...
# 91    92  Upack_CaseCheckweigher_Reject_Weight_NOKReject...
# 92    93                 Upack_OLCP_1DCheck_0_NOKRejected_n
# 93    94  Upack_CaseCheckweigher_Reject_LeakerCheck_0Rej...
# 94  95    Base_Machine_Holder_Not_free_iTrak_Exit_Counte...
# 95   96   Cover_Forming_PatchErectionCheck_Bad_on_Empty_...
#
#                                cause           reason            station  \
# 0                      Not extracted    Not extracted     Transport Belt
# 1                     Check External   Transport belt     Transport Belt
# 2                     Check Internal   Transport belt     Transport Belt
# 3                        Robot track   Transport belt     Transport Belt
# 4   Patch  Erection Check Bad Height     Patch reject      Patch Control
# ..                               ...              ...                ...
# 91                        Weight NOK          Minibea  Case CheckWeigher
# 92                       OLCP 1D NOK          Minibea  Case CheckWeigher
# 93                               NaN          Minibea  Case CheckWeigher
# 94                   Holder Not Free  Holder Not Free          Station 1
# 95                         Run Empty        Run Empty      Patch Control
#
#           type        machine
# 0        Cover  Cover machine
# 1        Cover  Cover machine
# 2        Cover  Cover machine
# 3        Cover  Cover machine
# 4        Cover  Cover machine
# ..         ...            ...
# 91  Cover+Base        Phase 2
# 92  Cover+Base        Phase 2
# 93  Cover+Base        Phase 2
# 94        Base   Base machine
# 95       Cover  Cover machine
#
# [96 rows x 7 columns]

# %%
#reject_cause_df.groupby('tag_nm').describe()

# %%
reject_cause_df = reject_cause_df.assign(id =(pd.to_numeric(reject_cause_df['id'])))
reject_cause_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       96 non-null     int64
#  1   tag_nm   96 non-null     object
#  2   cause    95 non-null     object
#  3   reason   94 non-null     object
#  4   station  96 non-null     object
#  5   type     96 non-null     object
#  6   machine  96 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 5.4+ KB

# %%
#line_recipe_df['recipe_size_nm'].tolist()

# %%
reject_cause_df.to_excel('..\Data\initial loading\REJECT_CAUSE_DIM.xlsx', index = False)

# %% [markdown]
# ### getting all tags list

# %%
### getting all tags lists

all_tags = cfg['job']['path_to_tag_list']
print(f'Path to all tag table: {all_tags}')

# cheking if the all tag path exist
if not os.path.exists(all_tags):
    print(f'INFO: Didn not find reject cause table at {all_tags}.')
    raise ValueError('Was not able to find reject cause table. Aborting...')
else:
    all_tags_df = pd.read_excel(all_tags)
    print(f'Shape of the line recipe table: {all_tags_df.shape}')
# Out:
# ---------------------------------------------------------------------------
# NonExistentKey                            Traceback (most recent call last)
# <ipython-input-18-2d298c23f49a> in <module>
#       1 ### getting all tags lists
#       2
# ----> 3 all_tags = cfg['job']['path_to_tag_list']
#       4 print(f'Path to all tag table: {all_tags}')
#       5
#
# ~\.conda\envs\sud_dev\lib\site-packages\tomlkit\items.py in __getitem__(self, key)
#    1016
#    1017     def __getitem__(self, key):  # type: (Union[Key, str]) -> Item
# -> 1018         return self._value[key]
#    1019
#    1020     def __setitem__(self, key, value):  # type: (Union[Key, str], Any) -> None
#
# ~\.conda\envs\sud_dev\lib\site-packages\tomlkit\container.py in __getitem__(self, key)
#     574         idx = self._map.get(key, None)
#     575         if idx is None:
# --> 576             raise NonExistentKey(key)
#     577
#     578         if isinstance(idx, tuple):
#
# NonExistentKey: 'Key "path_to_tag_list" does not exist.'

# %%
all_tags_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-11637adc8a8a> in <module>
# ----> 1 all_tags_df
#
# NameError: name 'all_tags_df' is not defined

# %%
all_tags_df.columns
# Out:
# Index(['Reject Station ', 'TagName ', 'site', 'enabled'], dtype='object')

# %%
all_tags_df.columns = all_tags_df.columns.str.strip()
all_tags_df.columns
# Out:
# Index(['Reject Station', 'TagName', 'site', 'enabled'], dtype='object')

# %%
all_tags_df['TagName'].tolist()
# Out:
# ['LXXX_Cover_General_ExtractedCartons_Total_Counter_Actual_n\xa0',
#  'LXXX_Cover_General_ProducedCovers_Total_Counter_Actual_n\xa0',
#  'LXXX_Cover_General_RejectedCovers_0_Counter_Actual_n\xa0',
#  'LXXX_Cover_Reshipper_good_inserted_n\xa0',
#  'LXXX_Cover_Reshipper_bad_rejected_n\xa0',
#  'LXXX_Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n\xa0',
#  'LXXX_Cover_TransportBelt_CheckExternal_0_0_Rejected_n\xa0',
#  'LXXX_Cover_TransportBelt_CheckInternal_0_0_Rejected_n\xa0',
#  'LXXX_Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n\xa0',
#  'LXXX_Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n\xa0',
#  'LXXX_Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n\xa0',
#  'LXXX_Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n\xa0',
#  'LXXX_Cover_Reshipper_BCR_NotRead_Rejected_n\xa0',
#  'LXXX_Cover_Reshipper_BCR_MisMatch_Rejected_n\xa0',
#  'LXXX_Cover_Reshipper_BCR_NoFeedback_Rejected_n\xa0',
#  'LXXX_Cover_TransportBelt_HoleFlap_0_Check_Rejected_n\xa0',
#  'LXXX_Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_Glue_Dry _0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_Glue_Dry_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Base_Machine_ExtractedCartons_0_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_ProducedBases_0_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_RejectedBases_Station1_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_RejectedBases_Station2_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_RejectedBases_Station3_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_RejectedBases_Total_NOT_Extracted_Betw_Holders_n\xa0',
#  'LXXX_Base_Reshipper_good_inserted_n\xa0',
#  'LXXX_Base_Reshipper_bad_rejected_n\xa0',
#  'LXXX_Base_Reshipper_BCR_NotRead_Rejected_n\xa0',
#  'LXXX_Base_Reshipper_BCR_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_Reshipper_BCR_NoFeedback_Rejected_n\xa0',
#  'LXXX_Base_Extraction_Turret_Arm1_CartonsNotExtracted_Actual_n\xa0',
#  'LXXX_Base_Extraction_Turret_Arm2_CartonsNotExtracted_Actual_n\xa0',
#  'LXXX_Base_Extraction_Turret_Arm3_CartonsNotExtracted_Actual_n\xa0',
#  'LXXX_Base_Extraction_Turret_Arm4_CartonsNotExtracted_Actual_n\xa0',
#  'LXXX_Base_Extraction_Bases_Betw_Holders_n\xa0',
#  'LXXX_Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n\xa0',
#  'LXXX_Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_CameraTT_2Dcheck_0_NotRead_Rejected_n\xa0',
#  'LXXX_Base_CameraTT_OCR_0_NOK_Rejected_n\xa0',
#  'LXXX_Base_CameraTT_2Dcheck_NoFeedback_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'LXXX_Base_Forming_Base_Backflap_Open_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_LowerGlue_Present_0_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n\xa0',
#  'LXXX_Base_Forming_Glue_Dry_Bad_Rejected_n\xa0',
#  'LXXX_Base_filling_Base_0_NotPresent_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n\xa0',
#  'LXXX_Base_Merging_Base_0_NotPresent_Rejected_n\xa0',
#  'LXXX_Base_Merging_00_CoverNotPresentOnBase_Rejected_n\xa0',
#  'LXXX_Base_Merging_base_Merging_Deviation_Rejected_n\xa0',
#  'LXXX_Base_Merging_base_Cover_NotPresent_ Rejected_n\xa0',
#  'LXXX_Base_Merging_MergingEngage_cover_Notpresent_Rejected_n\xa0',
#  'LXXX_Base_Merging_MergingInspection_DS_NOK_Rejected_n\xa0',
#  'LXXX_Base_Merging_MergingInspection_OS_NOK_Rejected_n\xa0',
#  'LXXX_Base_Merging_BackFlapInspection_0_NOK_Rejected_n\xa0',
#  'LXXX_Base_Merging_LaserPrinter0Fail_Rejected_n\xa0',
#  'LXXX_Base_Merging_Merging_External_Check_Rejected_n\xa0',
#  'LXXX_Base_Merging_Merging_Internal_Check_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_0_Rejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_1_NotRejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_2_NotRejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_3_Rejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_4_Rejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Extra_Rejected_n\xa0',
#  'LXXX_Secondary_FC11_Dataman_Reads_Result_Bad_n\xa0',
#  'LXXX_Secondary_FC11_Dataman_Reads_Result_Mismatch_n\xa0',
#  'LXXX_Secondary_FC11_Minibea_Reads_Result_Bad_n\xa0',
#  'LXXX_Secondary_FC11_Minibea_Reads_Result_Mismatch_n\xa0',
#  'LXXX_Secondary_FC11_Minibea_Reads_Result_Total_n\xa0',
#  'LXXX_Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n\xa0',
#  'LXXX_Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n\xa0',
#  'LXXX_Upack_OLCP_1DCheck_0_NOKRejected_n\xa0',
#  'LXXX_Upack_CaseCheckweigher_Reject_Case_Weight_Real\xa0',
#  'LXXX_Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n\xa0',
#  'LXXX_Palletizer_Pack_Counter_n\xa0',
#  'LXXX_Upack_Zone10_0_0_CurrentPO_Actual_nb\xa0',
#  'LXXX_Upack_Zone9_0_0_CurrentPO_Actual_nb\xa0',
#  'LXXX_Upack_Zone12_0_0_CurrentPO_Actual_nb\xa0',
#  'LXXX_Upack_Zone13_0_0_CurrentPO_Actual_nb\xa0',
#  'LXXX_UPack_For_Proficy_Produced_Cases\xa0',
#  'LXXX_Upack_LineRecipe',
#  'LXXX_Upack_Primary_General_Speed_AgileControl_State_ON',
#  'LXXX_Base_Machine_Holder_Not_free_iTrak_Exit_Counter_Rejected_n',
#  'LXXX_Cover_Forming_PatchErectionCheck_Bad_on_Empty_Counter_Rejected_n',
#  'LXXX_Cover_General_ExtractedCartons_Total_Counter_Actual_n\xa0',
#  'LXXX_Cover_General_ProducedCovers_Total_Counter_Actual_n\xa0',
#  'LXXX_Cover_General_RejectedCovers_0_Counter_Actual_n\xa0',
#  'LXXX_Cover_Reshipper_good_inserted_n\xa0',
#  'LXXX_Cover_Reshipper_bad_rejected_n\xa0',
#  'LXXX_Cover_Extraction_Turret_CartonsNotExtracted_0_Actual_n\xa0',
#  'LXXX_Cover_TransportBelt_CheckExternal_0_0_Rejected_n\xa0',
#  'LXXX_Cover_TransportBelt_CheckInternal_0_0_Rejected_n\xa0',
#  'LXXX_Cover_TransportBelt_RobotTrack_Skipped_0_Rejected_n\xa0',
#  'LXXX_Cover_Forming_PatchErectionCheck_Bad_Counter_Rejected_n\xa0',
#  'LXXX_Cover_Forming_PatchErectionCheck_BadAngle_Counter_Rejected_n\xa0',
#  'LXXX_Cover_Forming_PatchErectionCheck_NoFeedback_Counter_Rejected_n\xa0',
#  'LXXX_Cover_Reshipper_BCR_NotRead_Rejected_n\xa0',
#  'LXXX_Cover_Reshipper_BCR_MisMatch_Rejected_n\xa0',
#  'LXXX_Cover_Reshipper_BCR_NoFeedback_Rejected_n\xa0',
#  'LXXX_Cover_TransportBelt_HoleFlap_0_Check_Rejected_n\xa0',
#  'LXXX_Cover_Former1_ExternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_ExternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_InternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_InternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_Glue_Dry _0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_External_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_Internal_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead1_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead1_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead2_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead2_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead3_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead3_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead4_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former1_RobotHead4_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_ExternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_ExternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_InternalGlueCamera_Bad_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_InternalGlueCamera_NoFeedback_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_Glue_Dry_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_External_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_Internal_CoverNotSeenBeforeGlue_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead1_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead1_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead2_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead2_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead3_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead3_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead4_FlapCheck1_0_Rejected_n\xa0',
#  'LXXX_Cover_Former2_RobotHead4_FlapCheck2_0_Rejected_n\xa0',
#  'LXXX_Base_Machine_ExtractedCartons_0_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_ProducedBases_0_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_RejectedBases_Station1_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_RejectedBases_Station2_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_RejectedBases_Station3_Counter_Actual_n\xa0',
#  'LXXX_Base_Machine_RejectedBases_Total_NOT_Extracted_Betw_Holders_n\xa0',
#  'LXXX_Base_Reshipper_good_inserted_n\xa0',
#  'LXXX_Base_Reshipper_bad_rejected_n\xa0',
#  'LXXX_Base_Reshipper_BCR_NotRead_Rejected_n\xa0',
#  'LXXX_Base_Reshipper_BCR_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_Reshipper_BCR_NoFeedback_Rejected_n\xa0',
#  'LXXX_Base_Extraction_Turret_Arm1_CartonsNotExtracted_Actual_n\xa0',
#  'LXXX_Base_Extraction_Turret_Arm2_CartonsNotExtracted_Actual_n\xa0',
#  'LXXX_Base_Extraction_Turret_Arm3_CartonsNotExtracted_Actual_n\xa0',
#  'LXXX_Base_Extraction_Turret_Arm4_CartonsNotExtracted_Actual_n\xa0',
#  'LXXX_Base_Extraction_Bases_Betw_Holders_n\xa0',
#  'LXXX_Base_Extraction_Turret_0_BasesMissingOnEntryCarousel_Actual_n\xa0',
#  'LXXX_Base_CameraTT_2Dcheck_0_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_CameraTT_2Dcheck_0_NotRead_Rejected_n\xa0',
#  'LXXX_Base_CameraTT_OCR_0_NOK_Rejected_n\xa0',
#  'LXXX_Base_CameraTT_2Dcheck_NoFeedback_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_UpperInternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_UpperExternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_LowerInternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_LowerExternalFlap_BrokenOrMissing_NOK_Rejected_n\xa0',
#  'LXXX_Base_Forming_Base_Backflap_Open_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_LowerGlue_Present_0_Rejected_n\xa0',
#  'LXXX_Base_FlapCheck_BeforeLowerGlue_Present_0_Rejected_n\xa0',
#  'LXXX_Base_Forming_Glue_Dry_Bad_Rejected_n\xa0',
#  'LXXX_Base_filling_Base_0_NotPresent_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel1_WrongDoseDumped_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel2_WrongDoseDumped_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel3_WrongDoseDumped_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel4_WrongDoseDumped_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel1_CycleNotConfirmed_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel2_CycleNotConfirmed_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel3_CycleNotConfirmed_Rejected_n\xa0',
#  'LXXX_Base_Filling_Ishida_Channel4_CycleNotConfirmed_Rejected_n\xa0',
#  'LXXX_Base_Merging_Base_0_NotPresent_Rejected_n\xa0',
#  'LXXX_Base_Merging_00_CoverNotPresentOnBase_Rejected_n\xa0',
#  'LXXX_Base_Merging_base_Merging_Deviation_Rejected_n\xa0',
#  'LXXX_Base_Merging_base_Cover_NotPresent_ Rejected_n\xa0',
#  'LXXX_Base_Merging_MergingEngage_cover_Notpresent_Rejected_n\xa0',
#  'LXXX_Base_Merging_MergingInspection_DS_NOK_Rejected_n\xa0',
#  'LXXX_Base_Merging_MergingInspection_OS_NOK_Rejected_n\xa0',
#  'LXXX_Base_Merging_BackFlapInspection_0_NOK_Rejected_n\xa0',
#  'LXXX_Base_Merging_LaserPrinter0Fail_Rejected_n\xa0',
#  'LXXX_Base_Merging_Merging_External_Check_Rejected_n\xa0',
#  'LXXX_Base_Merging_Merging_Internal_Check_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Cover_2Dcheck_NotRead_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Cover_2Dcheck_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Cover_2Dcheck_TimeOut_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Base_2Dcheck_NotRead_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Base_2Dcheck_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Base _2Dcheck_TimeOut_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Tamper_2Dcheck_NotRead_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Tamper_2Dcheck_MisMatch_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Tamper_2Dcheck_TimeOut_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Washcount_Check_NotPresent_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Washcount_2Dcheck_TimeOut_Rejected_n\xa0',
#  'LXXX_Base_Checkweigher_Washcount_Check_WrongPosition_Rejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_0_Rejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_1_NotRejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_2_NotRejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_3_Rejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Zone_4_Rejected_n\xa0',
#  'LXXX_Upack_BoxCheckweigher_0_Extra_Rejected_n\xa0',
#  'LXXX_Secondary_FC11_Dataman_Reads_Result_Bad_n\xa0',
#  'LXXX_Secondary_FC11_Dataman_Reads_Result_Mismatch_n\xa0',
#  'LXXX_Secondary_FC11_Minibea_Reads_Result_Bad_n\xa0',
#  'LXXX_Secondary_FC11_Minibea_Reads_Result_Mismatch_n\xa0',
#  'LXXX_Secondary_FC11_Minibea_Reads_Result_Total_n\xa0',
#  'LXXX_Upack_CaseCheckweigher_Reject_ExternalReason_0Rejected_n\xa0',
#  'LXXX_Upack_CaseCheckweigher_Reject_Weight_NOKRejected_n\xa0',
#  'LXXX_Upack_OLCP_1DCheck_0_NOKRejected_n\xa0',
#  'LXXX_Upack_CaseCheckweigher_Reject_Case_Weight_Real\xa0',
#  'LXXX_Upack_CaseCheckweigher_Reject_LeakerCheck_0Rejected_n\xa0',
#  'LXXX_Palletizer_Pack_Counter_n\xa0',
#  'LXXX_Upack_Zone10_0_0_CurrentPO_Actual_nb\xa0',
#  'LXXX_Upack_Zone9_0_0_CurrentPO_Actual_nb\xa0',
#  'LXXX_Upack_Zone12_0_0_CurrentPO_Actual_nb\xa0',
#  'LXXX_Upack_Zone13_0_0_CurrentPO_Actual_nb\xa0',
#  'LXXX_UPack_For_Proficy_Produced_Cases\xa0',
#  'LXXX_Upack_LineRecipe',
#  'LXXX_Upack_Primary_General_Speed_AgileControl_State_ON',
#  'LXXX_Base_Machine_Holder_Not_free_iTrak_Exit_Counter_Rejected_n',
#  'LXXX_Cover_Forming_PatchErectionCheck_Bad_on_Empty_Counter_Rejected_n']

# %%
all_tags_df = all_tags_df.assign(TagName = all_tags_df['TagName'].str.replace('\xa0',''))
all_tags_df
# Out:
#              Reject Station  \
# 0    Total Cover Extracted
# 1     Total Cover Produced
# 2     Total Cover Rejected
# 3          Cover reshipper
# 4          Cover reshipper
# ..                      ...
# 261         Pack Counter 2
# 262              LineRecipe
# 263            AgileControl
# 264               Station 1
# 265           Patch Control
#
#                                                TagName    site  enabled
# 0    LXXX_Cover_General_ExtractedCartons_Total_Coun...  Urlati        1
# 1    LXXX_Cover_General_ProducedCovers_Total_Counte...  Urlati        1
# 2    LXXX_Cover_General_RejectedCovers_0_Counter_Ac...  Urlati        1
# 3                 LXXX_Cover_Reshipper_good_inserted_n  Urlati        0
# 4                  LXXX_Cover_Reshipper_bad_rejected_n  Urlati        0
# ..                                                 ...     ...      ...
# 261              LXXX_UPack_For_Proficy_Produced_Cases  Amiens        1
# 262                              LXXX_Upack_LineRecipe  Amiens        1
# 263  LXXX_Upack_Primary_General_Speed_AgileControl_...  Amiens        1
# 264  LXXX_Base_Machine_Holder_Not_free_iTrak_Exit_C...  Amiens        1
# 265  LXXX_Cover_Forming_PatchErectionCheck_Bad_on_E...  Amiens        1
#
# [266 rows x 4 columns]

# %%
all_tags_df =all_tags_df[['TagName', 'site', 'enabled']]
all_tags_df
# Out:
#                                                TagName    site  enabled
# 0    LXXX_Cover_General_ExtractedCartons_Total_Coun...  Urlati        1
# 1    LXXX_Cover_General_ProducedCovers_Total_Counte...  Urlati        1
# 2    LXXX_Cover_General_RejectedCovers_0_Counter_Ac...  Urlati        1
# 3                 LXXX_Cover_Reshipper_good_inserted_n  Urlati        0
# 4                  LXXX_Cover_Reshipper_bad_rejected_n  Urlati        0
# ..                                                 ...     ...      ...
# 261              LXXX_UPack_For_Proficy_Produced_Cases  Amiens        1
# 262                              LXXX_Upack_LineRecipe  Amiens        1
# 263  LXXX_Upack_Primary_General_Speed_AgileControl_...  Amiens        1
# 264  LXXX_Base_Machine_Holder_Not_free_iTrak_Exit_C...  Amiens        1
# 265  LXXX_Cover_Forming_PatchErectionCheck_Bad_on_E...  Amiens        1
#
# [266 rows x 3 columns]

# %%
path_to_file = join(split(getcwd())[0], 'Data', 'Input', 'all_tag_list.xlsx')
all_tags_df.to_excel(path_to_file, index=False)
